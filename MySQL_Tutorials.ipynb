# %% [markdown]
# #MySQL Tutorials <br>
#
#
# 1.   https://www.mysqltutorial.org/
# 2.   https://www.mysqltutorial.org/basic-mysql-tutorial.aspx

# %%
#!cat /proc/cpuinfo
#!cat /proc/meminfo
#!ls /proc/*info

# %% [markdown]
# #Section 1 : Getting started with MySQL

# %% [markdown]
# ##Install MySQL in local Colab VM

# %%
# this will take some time and show an error. 
# dont worry, just carry on 
# !apt install -y mysql-server > /dev/null
#!ls /etc/init.d
# !/etc/init.d/mysql restart
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  * Stopping MySQL database server mysqld
#    ...done.
#  * Starting MySQL database server mysqld
# No directory, logging in with HOME=/
#    ...done.

# %% [markdown]
# ## Download Sample Database - Classicmodels <br>
# Create Tables <br>
# https://www.mysqltutorial.org/mysql-sample-database.aspx

# %%
#!gdown https://drive.google.com/uc?id=1Ik3QuYTd52M5qI9D4aOCfGcQ7v2AB9wx
#!wget https://sp.mysqltutorial.org/wp-content/uploads/2018/03/mysqlsampledatabase.zip
#!wget https://github.com/Praxis-QR/RDWH/raw/main/mysqlsampledatabase.zip

# !wget -q https://github.com/Praxis-QR/RDWH/raw/main/data/mysqlsampledatabase.zip
# !unzip mysqlsampledatabase.zip
#!cat /content/mysqlsampledatabase.sql
# !head /content/mysqlsampledatabase.sql
# Out:
# Archive:  mysqlsampledatabase.zip
# replace mysqlsampledatabase.sql? [y]es, [n]o, [A]ll, [N]one, [r]ename: /*
# *********************************************************************
# http://www.mysqltutorial.org
# *********************************************************************
# Name: MySQL Sample Database classicmodels
# Link: http://www.mysqltutorial.org/mysql-sample-database.aspx
# Version 3.1
# + changed data type from DOUBLE to DECIMAL for amount columns
# Version 3.0
# + changed DATETIME to DATE for some colunmns

# %% [markdown]
# ## Loading Sample Database into MySQL server

# %%
#https://www.mysqltutorial.org/how-to-load-sample-database-into-mysql-database-server.aspx
# !mysql --table < mysqlsampledatabase.sql
#New database classicmodels has been created
# !mysql -e 'show databases'
# Out:
# +--------------------+
# | Database           |
# +--------------------+
# | information_schema |
# | classicmodels      |
# | mysql              |
# | performance_schema |
# | sys                |
# +--------------------+

# %% [markdown]
# ###Check contents of sample database - Classicmodels

# %%
# !mysql classicmodels -e 'show tables'
# Out:
# +-------------------------+
# | Tables_in_classicmodels |
# +-------------------------+
# | customers               |
# | employees               |
# | offices                 |
# | orderdetails            |
# | orders                  |
# | payments                |
# | productlines            |
# | products                |
# +-------------------------+

# %% [markdown]
# This is what the database looks like : <br><br>
# ![alt text](https://www.mysqltutorial.org/wp-content/uploads/2009/12/MySQL-Sample-Database-Schema.png)<br>

# %%
# !mysql classicmodels -e 'select * from employees'
# Out:
# +----------------+-----------+-----------+-----------+---------------------------------+------------+-----------+----------------------+
# | employeeNumber | lastName  | firstName | extension | email                           | officeCode | reportsTo | jobTitle             |
# +----------------+-----------+-----------+-----------+---------------------------------+------------+-----------+----------------------+
# |           1002 | Murphy    | Diane     | x5800     | dmurphy@classicmodelcars.com    | 1          |      NULL | President            |
# |           1056 | Patterson | Mary      | x4611     | mpatterso@classicmodelcars.com  | 1          |      1002 | VP Sales             |
# |           1076 | Firrelli  | Jeff      | x9273     | jfirrelli@classicmodelcars.com  | 1          |      1002 | VP Marketing         |
# |           1088 | Patterson | William   | x4871     | wpatterson@classicmodelcars.com | 6          |      1056 | Sales Manager (APAC) |
# |           1102 | Bondur    | Gerard    | x5408     | gbondur@classicmodelcars.com    | 4          |      1056 | Sale Manager (EMEA)  |
# |           1143 | Bow       | Anthony   | x5428     | abow@classicmodelcars.com       | 1          |      1056 | Sales Manager (NA)   |
# |           1165 | Jennings  | Leslie    | x3291     | ljennings@classicmodelcars.com  | 1          |      1143 | Sales Rep            |
# |           1166 | Thompson  | Leslie    | x4065     | lthompson@classicmodelcars.com  | 1          |      1143 | Sales Rep            |
# |           1188 | Firrelli  | Julie     | x2173     | jfirrelli@classicmodelcars.com  | 2          |      1143 | Sales Rep            |
# |           1216 | Patterson | Steve     | x4334     | spatterson@classicmodelcars.com | 2          |      1143 | Sales Rep            |
# |           1286 | Tseng     | Foon Yue  | x2248     | ftseng@classicmodelcars.com     | 3          |      1143 | Sales Rep            |
# |           1323 | Vanauf    | George    | x4102     | gvanauf@classicmodelcars.com    | 3          |      1143 | Sales Rep            |
# |           1337 | Bondur    | Loui      | x6493     | lbondur@classicmodelcars.com    | 4          |      1102 | Sales Rep            |
# |           1370 | Hernandez | Gerard    | x2028     | ghernande@classicmodelcars.com  | 4          |      1102 | Sales Rep            |
# |           1401 | Castillo  | Pamela    | x2759     | pcastillo@classicmodelcars.com  | 4          |      1102 | Sales Rep            |
# |           1501 | Bott      | Larry     | x2311     | lbott@classicmodelcars.com      | 7          |      1102 | Sales Rep            |
# |           1504 | Jones     | Barry     | x102      | bjones@classicmodelcars.com     | 7          |      1102 | Sales Rep            |
# |           1611 | Fixter    | Andy      | x101      | afixter@classicmodelcars.com    | 6          |      1088 | Sales Rep            |
# |           1612 | Marsh     | Peter     | x102      | pmarsh@classicmodelcars.com     | 6          |      1088 | Sales Rep            |
# |           1619 | King      | Tom       | x103      | tking@classicmodelcars.com      | 6          |      1088 | Sales Rep            |
# |           1621 | Nishi     | Mami      | x101      | mnishi@classicmodelcars.com     | 5          |      1056 | Sales Rep            |
# |           1625 | Kato      | Yoshimi   | x102      | ykato@classicmodelcars.com      | 5          |      1621 | Sales Rep            |
# |           1702 | Gerard    | Martin    | x2312     | mgerard@classicmodelcars.com    | 4          |      1102 | Sales Rep            |
# +----------------+-----------+-----------+-----------+---------------------------------+------------+-----------+----------------------+

# %% [markdown]
# ##Install Python Client <br>

# %%
# !apt install libmysqlclient-dev > /dev/null
# !pip -q install mysqlclient 
import pandas as pd
import MySQLdb
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
#To run any non-SELECT SQL command
def runCMD (DDL):
    #DBConn= MySQLdb.connect(hostName,userName,passWord,dbName)
    DBConn= MySQLdb.connect(db='classicmodels')  # since local MySQL server, userid, password not needed
    myCursor = DBConn.cursor()
    retcode = myCursor.execute(DDL) 
    print (retcode)
    DBConn.commit()
    DBConn.close()

#To run any SELECT SQL command
def runSELECT (CMD):
    #DBConn= MySQLdb.connect(hostName,userName,passWord,dbName)
    DBConn= MySQLdb.connect(db='classicmodels') # since local MySQL server, userid, password not needed
    df_mysql = pd.read_sql(CMD, con=DBConn)    
    DBConn.close()
    return df_mysql

# %%
# Set the location to whichever Database you need to access
#
# --------------------------------
#
#location = 'localDB'
location = 'remoteDB'

# %% [markdown]
# ###Check out all tables

# %%
# !mysql classicmodels -e 'show tables'
# Out:
# +-------------------------+
# | Tables_in_classicmodels |
# +-------------------------+
# | customers               |
# | employees               |
# | offices                 |
# | orderdetails            |
# | orders                  |
# | payments                |
# | productlines            |
# | products                |
# +-------------------------+

# %%
runSELECT('select * from customers limit 5')
# Out:
#    customerNumber                customerName contactLastName  \
# 0             103           Atelier graphique         Schmitt
# 1             112          Signal Gift Stores            King
# 2             114  Australian Collectors, Co.        Ferguson
# 3             119           La Rochelle Gifts         Labrune
# 4             121          Baane Mini Imports      Bergulfsen
#
#   contactFirstName         phone                  addressLine1 addressLine2  \
# 0          Carine     40.32.2555                54, rue Royale         None
# 1             Jean    7025551838               8489 Strong St.         None
# 2            Peter  03 9520 4555             636 St Kilda Road      Level 3
# 3          Janine     40.67.8555  67, rue des Cinquante Otages         None
# 4           Jonas     07-98 9555        Erling Skakkes gate 78         None
#
#         city     state postalCode    country  salesRepEmployeeNumber  \
# 0     Nantes      None      44000     France                    1370
# 1  Las Vegas        NV      83030        USA                    1166
# 2  Melbourne  Victoria       3004  Australia                    1611
# 3     Nantes      None      44000     France                    1370
# 4    Stavern      None       4110     Norway                    1504
#
#    creditLimit
# 0      21000.0
# 1      71800.0
# 2     117300.0
# 3     118200.0
# 4      81700.0

# %%
runSELECT('select * from employees limit 5')
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1002     Murphy     Diane     x5800
# 1            1056  Patterson      Mary     x4611
# 2            1076   Firrelli      Jeff     x9273
# 3            1088  Patterson   William     x4871
# 4            1102     Bondur    Gerard     x5408
#
#                              email officeCode  reportsTo              jobTitle
# 0     dmurphy@classicmodelcars.com          1        NaN             President
# 1   mpatterso@classicmodelcars.com          1     1002.0              VP Sales
# 2   jfirrelli@classicmodelcars.com          1     1002.0          VP Marketing
# 3  wpatterson@classicmodelcars.com          6     1056.0  Sales Manager (APAC)
# 4     gbondur@classicmodelcars.com          4     1056.0   Sale Manager (EMEA)

# %%
runSELECT('select * from offices limit 5')
# Out:
#   officeCode           city            phone              addressLine1  \
# 0          1  San Francisco  +1 650 219 4782         100 Market Street
# 1          2         Boston  +1 215 837 0825          1550 Court Place
# 2          3            NYC  +1 212 555 3000      523 East 53rd Street
# 3          4          Paris  +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          5          Tokyo  +81 33 224 5000               4-1 Kioicho
#
#   addressLine2       state country postalCode territory
# 0    Suite 300          CA     USA      94080        NA
# 1    Suite 102          MA     USA      02107        NA
# 2      apt. 5A          NY     USA      10022        NA
# 3         None        None  France      75017      EMEA
# 4         None  Chiyoda-Ku   Japan   102-8578     Japan

# %%
runSELECT('select * from orderdetails limit 5')
# Out:
#    orderNumber productCode  quantityOrdered  priceEach  orderLineNumber
# 0        10100    S18_1749               30     136.00                3
# 1        10100    S18_2248               50      55.09                2
# 2        10100    S18_4409               22      75.46                4
# 3        10100    S24_3969               49      35.29                1
# 4        10101    S18_2325               25     108.06                4

# %%
runSELECT('select * from orders limit 5')
# Out:
#    orderNumber   orderDate requiredDate shippedDate   status  \
# 0        10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1        10101  2003-01-09   2003-01-18  2003-01-11  Shipped
# 2        10102  2003-01-10   2003-01-18  2003-01-14  Shipped
# 3        10103  2003-01-29   2003-02-07  2003-02-02  Shipped
# 4        10104  2003-01-31   2003-02-09  2003-02-01  Shipped
#
#                  comments  customerNumber
# 0                    None             363
# 1  Check on availability.             128
# 2                    None             181
# 3                    None             121
# 4                    None             141

# %%
runSELECT('select * from payments limit 5')
# Out:
#    customerNumber checkNumber paymentDate    amount
# 0             103    HQ336336  2004-10-19   6066.78
# 1             103    JM555205  2003-06-05  14571.44
# 2             103    OM314933  2004-12-18   1676.14
# 3             112    BO864823  2004-12-17  14191.12
# 4             112     HQ55022  2003-06-06  32641.98

# %%
runSELECT('select * from productlines limit 5')
# Out:
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1   Motorcycles  Our motorcycles are state of the art replicas ...
# 2        Planes  Unique, diecast airplane and helicopter replic...
# 3         Ships  The perfect holiday or anniversary gift for ex...
# 4        Trains  Model trains are a rewarding hobby for enthusi...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None

# %%
runSELECT('select * from products limit 5')
# Out:
#   productCode                            productName   productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1    S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2    S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3    S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4    S10_4757                    1972 Alfa Romeo GTA  Classic Cars
#
#   productScale             productVendor  \
# 0         1:10           Min Lin Diecast
# 1         1:10   Classic Metal Creations
# 2         1:10  Highway 66 Mini Classics
# 3         1:10         Red Start Diecast
# 4         1:10   Motor City Art Classics
#
#                                   productDescription  quantityInStock  \
# 0  This replica features working kickstand, front...             7933
# 1  Turnable front wheels; steering function; deta...             7305
# 2  Official Moto Guzzi logos and insignias, saddl...             6625
# 3  Model features, official Harley Davidson logos...             5582
# 4  Features include: Turnable front wheels; steer...             3252
#
#    buyPrice    MSRP
# 0     48.81   95.70
# 1     98.58  214.30
# 2     68.99  118.94
# 3     91.02  193.66
# 4     85.68  136.00

# %% [markdown]
# #Section 1 : Querying Data

# %% [markdown]
# Select From

# %%
runSELECT("SELECT lastName FROM employees")
# Out:
#      lastName
# 0      Murphy
# 1   Patterson
# 2    Firrelli
# 3   Patterson
# 4      Bondur
# 5         Bow
# 6    Jennings
# 7    Thompson
# 8    Firrelli
# 9   Patterson
# 10      Tseng
# 11     Vanauf
# 12     Bondur
# 13  Hernandez
# 14   Castillo
# 15       Bott
# 16      Jones
# 17     Fixter
# 18      Marsh
# 19       King
# 20      Nishi
# 21       Kato
# 22     Gerard

# %%
runSELECT("SELECT lastName, firstName,jobTitle FROM employees")
# Out:
#      lastName firstName              jobTitle
# 0      Murphy     Diane             President
# 1   Patterson      Mary              VP Sales
# 2    Firrelli      Jeff          VP Marketing
# 3   Patterson   William  Sales Manager (APAC)
# 4      Bondur    Gerard   Sale Manager (EMEA)
# 5         Bow   Anthony    Sales Manager (NA)
# 6    Jennings    Leslie             Sales Rep
# 7    Thompson    Leslie             Sales Rep
# 8    Firrelli     Julie             Sales Rep
# 9   Patterson     Steve             Sales Rep
# 10      Tseng  Foon Yue             Sales Rep
# 11     Vanauf    George             Sales Rep
# 12     Bondur      Loui             Sales Rep
# 13  Hernandez    Gerard             Sales Rep
# 14   Castillo    Pamela             Sales Rep
# 15       Bott     Larry             Sales Rep
# 16      Jones     Barry             Sales Rep
# 17     Fixter      Andy             Sales Rep
# 18      Marsh     Peter             Sales Rep
# 19       King       Tom             Sales Rep
# 20      Nishi      Mami             Sales Rep
# 21       Kato   Yoshimi             Sales Rep
# 22     Gerard    Martin             Sales Rep

# %%
runSELECT("SELECT employeeNumber,lastName,firstName,extension,email,officeCode,reportsTo,jobTitle FROM   employees")
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# 18            1612      Marsh     Peter      x102
# 19            1619       King       Tom      x103
# 20            1621      Nishi      Mami      x101
# 21            1625       Kato   Yoshimi      x102
# 22            1702     Gerard    Martin     x2312
#
#                               email officeCode  reportsTo  \
# 0      dmurphy@classicmodelcars.com          1        NaN
# 1    mpatterso@classicmodelcars.com          1     1002.0
# 2    jfirrelli@classicmodelcars.com          1     1002.0
# 3   wpatterson@classicmodelcars.com          6     1056.0
# 4      gbondur@classicmodelcars.com          4     1056.0
# 5         abow@classicmodelcars.com          1     1056.0
# 6    ljennings@classicmodelcars.com          1     1143.0
# 7    lthompson@classicmodelcars.com          1     1143.0
# 8    jfirrelli@classicmodelcars.com          2     1143.0
# 9   spatterson@classicmodelcars.com          2     1143.0
# 10      ftseng@classicmodelcars.com          3     1143.0
# 11     gvanauf@classicmodelcars.com          3     1143.0
# 12     lbondur@classicmodelcars.com          4     1102.0
# 13   ghernande@classicmodelcars.com          4     1102.0
# 14   pcastillo@classicmodelcars.com          4     1102.0
# 15       lbott@classicmodelcars.com          7     1102.0
# 16      bjones@classicmodelcars.com          7     1102.0
# 17     afixter@classicmodelcars.com          6     1088.0
# 18      pmarsh@classicmodelcars.com          6     1088.0
# 19       tking@classicmodelcars.com          6     1088.0
# 20      mnishi@classicmodelcars.com          5     1056.0
# 21       ykato@classicmodelcars.com          5     1621.0
# 22     mgerard@classicmodelcars.com          4     1102.0
#
#                 jobTitle
# 0              President
# 1               VP Sales
# 2           VP Marketing
# 3   Sales Manager (APAC)
# 4    Sale Manager (EMEA)
# 5     Sales Manager (NA)
# 6              Sales Rep
# 7              Sales Rep
# 8              Sales Rep
# 9              Sales Rep
# 10             Sales Rep
# 11             Sales Rep
# 12             Sales Rep
# 13             Sales Rep
# 14             Sales Rep
# 15             Sales Rep
# 16             Sales Rep
# 17             Sales Rep
# 18             Sales Rep
# 19             Sales Rep
# 20             Sales Rep
# 21             Sales Rep
# 22             Sales Rep

# %%
runSELECT("SELECT * FROM employees")
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# 18            1612      Marsh     Peter      x102
# 19            1619       King       Tom      x103
# 20            1621      Nishi      Mami      x101
# 21            1625       Kato   Yoshimi      x102
# 22            1702     Gerard    Martin     x2312
#
#                               email officeCode  reportsTo  \
# 0      dmurphy@classicmodelcars.com          1        NaN
# 1    mpatterso@classicmodelcars.com          1     1002.0
# 2    jfirrelli@classicmodelcars.com          1     1002.0
# 3   wpatterson@classicmodelcars.com          6     1056.0
# 4      gbondur@classicmodelcars.com          4     1056.0
# 5         abow@classicmodelcars.com          1     1056.0
# 6    ljennings@classicmodelcars.com          1     1143.0
# 7    lthompson@classicmodelcars.com          1     1143.0
# 8    jfirrelli@classicmodelcars.com          2     1143.0
# 9   spatterson@classicmodelcars.com          2     1143.0
# 10      ftseng@classicmodelcars.com          3     1143.0
# 11     gvanauf@classicmodelcars.com          3     1143.0
# 12     lbondur@classicmodelcars.com          4     1102.0
# 13   ghernande@classicmodelcars.com          4     1102.0
# 14   pcastillo@classicmodelcars.com          4     1102.0
# 15       lbott@classicmodelcars.com          7     1102.0
# 16      bjones@classicmodelcars.com          7     1102.0
# 17     afixter@classicmodelcars.com          6     1088.0
# 18      pmarsh@classicmodelcars.com          6     1088.0
# 19       tking@classicmodelcars.com          6     1088.0
# 20      mnishi@classicmodelcars.com          5     1056.0
# 21       ykato@classicmodelcars.com          5     1621.0
# 22     mgerard@classicmodelcars.com          4     1102.0
#
#                 jobTitle
# 0              President
# 1               VP Sales
# 2           VP Marketing
# 3   Sales Manager (APAC)
# 4    Sale Manager (EMEA)
# 5     Sales Manager (NA)
# 6              Sales Rep
# 7              Sales Rep
# 8              Sales Rep
# 9              Sales Rep
# 10             Sales Rep
# 11             Sales Rep
# 12             Sales Rep
# 13             Sales Rep
# 14             Sales Rep
# 15             Sales Rep
# 16             Sales Rep
# 17             Sales Rep
# 18             Sales Rep
# 19             Sales Rep
# 20             Sales Rep
# 21             Sales Rep
# 22             Sales Rep

# %% [markdown]
# Select

# %%
runSELECT("SELECT 1 + 1")
# Out:
#    1 + 1
# 0      2

# %%
runSELECT("SELECT NOW()")
# Out:
#                 NOW()
# 0 2022-04-09 15:01:16

# %%
runSELECT("SELECT CONCAT('John',' ','Doe')")
# Out:
#   CONCAT('John',' ','Doe')
# 0                 John Doe

# %%
runSELECT("SELECT CONCAT('John',' ','Doe') AS name")
# Out:
#        name
# 0  John Doe

# %%
runSELECT("SELECT CONCAT('Jane',' ','Doe') AS 'Full name'")
# Out:
#   Full name
# 0  Jane Doe

# %% [markdown]
# #Section 2 - Sorting Data

# %% [markdown]
# Order By

# %%
runSELECT("SELECT contactLastname,contactFirstname FROM customers ORDER BY contactLastname")
# Out:
#     contactLastname contactFirstname
# 0           Accorti           Paolo
# 1       Altagar,G M           Raanan
# 2          Andersen              Mel
# 3             Anton           Carmen
# 4          Ashworth           Rachel
# ..              ...              ...
# 117         Yoshido             Juri
# 118           Young             Jeff
# 119           Young            Julie
# 120           Young             Mary
# 121           Young          Dorothy
#
# [122 rows x 2 columns]

# %%
runSELECT("SELECT contactLastname,contactFirstname FROM customers ORDER BY contactLastname DESC")
# Out:
#     contactLastname contactFirstname
# 0             Young             Jeff
# 1             Young            Julie
# 2             Young             Mary
# 3             Young          Dorothy
# 4           Yoshido             Juri
# ..              ...              ...
# 117        Ashworth           Rachel
# 118           Anton           Carmen
# 119        Andersen              Mel
# 120     Altagar,G M           Raanan
# 121         Accorti           Paolo
#
# [122 rows x 2 columns]

# %%
runSELECT("SELECT contactLastname, contactFirstname FROM customers ORDER BY contactLastname DESC , contactFirstname ASC")
# Out:
#     contactLastname contactFirstname
# 0             Young          Dorothy
# 1             Young             Jeff
# 2             Young            Julie
# 3             Young             Mary
# 4           Yoshido             Juri
# ..              ...              ...
# 117        Ashworth           Rachel
# 118           Anton           Carmen
# 119        Andersen              Mel
# 120     Altagar,G M           Raanan
# 121         Accorti           Paolo
#
# [122 rows x 2 columns]

# %%
runSELECT("SELECT orderNumber, orderlinenumber, quantityOrdered * priceEach FROM orderdetails ORDER BY quantityOrdered * priceEach DESC")
# Out:
#       orderNumber  orderlinenumber  quantityOrdered * priceEach
# 0           10403                9                     11503.14
# 1           10405                5                     11170.52
# 2           10407                2                     10723.60
# 3           10404                3                     10460.16
# 4           10312                3                     10286.40
# ...           ...              ...                          ...
# 2991        10425                6                       553.52
# 2992        10407                3                       546.66
# 2993        10322                3                       531.00
# 2994        10420                3                       529.35
# 2995        10419                7                       481.50
#
# [2996 rows x 3 columns]

# %%
runSELECT("SELECT orderNumber,orderLineNumber,quantityOrdered * priceEach AS subtotal FROM orderdetails ORDER BY subtotal DESC")
# Out:
#       orderNumber  orderLineNumber  subtotal
# 0           10403                9  11503.14
# 1           10405                5  11170.52
# 2           10407                2  10723.60
# 3           10404                3  10460.16
# 4           10312                3  10286.40
# ...           ...              ...       ...
# 2991        10425                6    553.52
# 2992        10407                3    546.66
# 2993        10322                3    531.00
# 2994        10420                3    529.35
# 2995        10419                7    481.50
#
# [2996 rows x 3 columns]

# %%
runSELECT("SELECT FIELD('A', 'A', 'B','C')")
# Out:
#    FIELD('A', 'A', 'B','C')
# 0                         1

# %%
runSELECT("SELECT FIELD('B', 'A','B','C')")
# Out:
#    FIELD('B', 'A','B','C')
# 0                        2

# %%
runSELECT("SELECT orderNumber, status FROM orders ORDER BY FIELD(status,'In Process','On Hold','Cancelled','Resolved','Disputed','Shipped')")
# Out:
#      orderNumber      status
# 0          10420  In Process
# 1          10421  In Process
# 2          10422  In Process
# 3          10423  In Process
# 4          10424  In Process
# ..           ...         ...
# 321        10412     Shipped
# 322        10413     Shipped
# 323        10416     Shipped
# 324        10418     Shipped
# 325        10419     Shipped
#
# [326 rows x 2 columns]

# %%
runSELECT("SELECT firstName, lastName, reportsTo FROM employees ORDER BY reportsTo")
# Out:
#    firstName   lastName  reportsTo
# 0      Diane     Murphy        NaN
# 1       Mary  Patterson     1002.0
# 2       Jeff   Firrelli     1002.0
# 3    William  Patterson     1056.0
# 4     Gerard     Bondur     1056.0
# 5    Anthony        Bow     1056.0
# 6       Mami      Nishi     1056.0
# 7        Tom       King     1088.0
# 8      Peter      Marsh     1088.0
# 9       Andy     Fixter     1088.0
# 10    Martin     Gerard     1102.0
# 11     Barry      Jones     1102.0
# 12     Larry       Bott     1102.0
# 13    Pamela   Castillo     1102.0
# 14    Gerard  Hernandez     1102.0
# 15      Loui     Bondur     1102.0
# 16    George     Vanauf     1143.0
# 17  Foon Yue      Tseng     1143.0
# 18     Steve  Patterson     1143.0
# 19     Julie   Firrelli     1143.0
# 20    Leslie   Thompson     1143.0
# 21    Leslie   Jennings     1143.0
# 22   Yoshimi       Kato     1621.0

# %%
runSELECT("SELECT firstName, lastName, reportsTo FROM employees ORDER BY reportsTo DESC")
# Out:
#    firstName   lastName  reportsTo
# 0    Yoshimi       Kato     1621.0
# 1     Leslie   Jennings     1143.0
# 2     Leslie   Thompson     1143.0
# 3      Julie   Firrelli     1143.0
# 4      Steve  Patterson     1143.0
# 5   Foon Yue      Tseng     1143.0
# 6     George     Vanauf     1143.0
# 7     Martin     Gerard     1102.0
# 8      Barry      Jones     1102.0
# 9      Larry       Bott     1102.0
# 10    Pamela   Castillo     1102.0
# 11    Gerard  Hernandez     1102.0
# 12      Loui     Bondur     1102.0
# 13      Andy     Fixter     1088.0
# 14     Peter      Marsh     1088.0
# 15       Tom       King     1088.0
# 16   Anthony        Bow     1056.0
# 17    Gerard     Bondur     1056.0
# 18   William  Patterson     1056.0
# 19      Mami      Nishi     1056.0
# 20      Jeff   Firrelli     1002.0
# 21      Mary  Patterson     1002.0
# 22     Diane     Murphy        NaN

# %% [markdown]
# # Section 3: Filtering Data

# %% [markdown]
# Where

# %%
runSELECT("SELECT lastname, firstname, jobtitle FROM employees WHERE jobtitle = 'Sales Rep'")
# Out:
#      lastname firstname   jobtitle
# 0    Jennings    Leslie  Sales Rep
# 1    Thompson    Leslie  Sales Rep
# 2    Firrelli     Julie  Sales Rep
# 3   Patterson     Steve  Sales Rep
# 4       Tseng  Foon Yue  Sales Rep
# 5      Vanauf    George  Sales Rep
# 6      Bondur      Loui  Sales Rep
# 7   Hernandez    Gerard  Sales Rep
# 8    Castillo    Pamela  Sales Rep
# 9        Bott     Larry  Sales Rep
# 10      Jones     Barry  Sales Rep
# 11     Fixter      Andy  Sales Rep
# 12      Marsh     Peter  Sales Rep
# 13       King       Tom  Sales Rep
# 14      Nishi      Mami  Sales Rep
# 15       Kato   Yoshimi  Sales Rep
# 16     Gerard    Martin  Sales Rep

# %%
runSELECT("SELECT lastname, firstname, jobtitle,officeCode FROM employees WHERE jobtitle = 'Sales Rep' AND officeCode = 1")
# Out:
#    lastname firstname   jobtitle officeCode
# 0  Jennings    Leslie  Sales Rep          1
# 1  Thompson    Leslie  Sales Rep          1

# %%
runSELECT("SELECT lastName, firstName, jobTitle, officeCode FROM employees WHERE jobtitle = 'Sales Rep' OR officeCode = 1 ORDER BY officeCode , jobTitle")
# Out:
#      lastName firstName            jobTitle officeCode
# 0      Murphy     Diane           President          1
# 1         Bow   Anthony  Sales Manager (NA)          1
# 2    Jennings    Leslie           Sales Rep          1
# 3    Thompson    Leslie           Sales Rep          1
# 4    Firrelli      Jeff        VP Marketing          1
# 5   Patterson      Mary            VP Sales          1
# 6    Firrelli     Julie           Sales Rep          2
# 7   Patterson     Steve           Sales Rep          2
# 8       Tseng  Foon Yue           Sales Rep          3
# 9      Vanauf    George           Sales Rep          3
# 10     Gerard    Martin           Sales Rep          4
# 11   Castillo    Pamela           Sales Rep          4
# 12  Hernandez    Gerard           Sales Rep          4
# 13     Bondur      Loui           Sales Rep          4
# 14      Nishi      Mami           Sales Rep          5
# 15       Kato   Yoshimi           Sales Rep          5
# 16     Fixter      Andy           Sales Rep          6
# 17      Marsh     Peter           Sales Rep          6
# 18       King       Tom           Sales Rep          6
# 19       Bott     Larry           Sales Rep          7
# 20      Jones     Barry           Sales Rep          7

# %%
runSELECT("SELECT firstName, lastName, officeCode FROM employees WHERE officeCode BETWEEN 1 AND 3 ORDER BY officeCode")
# Out:
#   firstName   lastName officeCode
# 0     Diane     Murphy          1
# 1      Mary  Patterson          1
# 2      Jeff   Firrelli          1
# 3   Anthony        Bow          1
# 4    Leslie   Jennings          1
# 5    Leslie   Thompson          1
# 6     Julie   Firrelli          2
# 7     Steve  Patterson          2
# 8  Foon Yue      Tseng          3
# 9    George     Vanauf          3

# %%
runSELECT("SELECT firstName, lastName FROM employees WHERE lastName LIKE '%son' ORDER BY firstName")
# Out:
#   firstName   lastName
# 0    Leslie   Thompson
# 1      Mary  Patterson
# 2     Steve  Patterson
# 3   William  Patterson

# %%
runSELECT("SELECT firstName, lastName, officeCode FROM employees WHERE officeCode IN (1 , 2, 3) ORDER BY officeCode")
# Out:
#   firstName   lastName officeCode
# 0     Diane     Murphy          1
# 1      Mary  Patterson          1
# 2      Jeff   Firrelli          1
# 3   Anthony        Bow          1
# 4    Leslie   Jennings          1
# 5    Leslie   Thompson          1
# 6     Julie   Firrelli          2
# 7     Steve  Patterson          2
# 8  Foon Yue      Tseng          3
# 9    George     Vanauf          3

# %%
runSELECT("SELECT lastName, firstName, reportsTo FROM employees WHERE reportsTo IS NULL")
# Out:
#   lastName firstName reportsTo
# 0   Murphy     Diane      None

# %%
runSELECT("SELECT lastname, firstname, jobtitle FROM employees WHERE jobtitle <> 'Sales Rep'")
# Out:
#     lastname firstname              jobtitle
# 0     Murphy     Diane             President
# 1  Patterson      Mary              VP Sales
# 2   Firrelli      Jeff          VP Marketing
# 3  Patterson   William  Sales Manager (APAC)
# 4     Bondur    Gerard   Sale Manager (EMEA)
# 5        Bow   Anthony    Sales Manager (NA)

# %%
runSELECT("SELECT lastname, firstname, officeCode FROM employees WHERE officecode > 5")
# Out:
#     lastname firstname officeCode
# 0  Patterson   William          6
# 1       Bott     Larry          7
# 2      Jones     Barry          7
# 3     Fixter      Andy          6
# 4      Marsh     Peter          6
# 5       King       Tom          6

# %%
runSELECT("SELECT lastname, firstname, officeCode FROM employees WHERE officecode <= 4")
# Out:
#      lastname firstname officeCode
# 0      Murphy     Diane          1
# 1   Patterson      Mary          1
# 2    Firrelli      Jeff          1
# 3      Bondur    Gerard          4
# 4         Bow   Anthony          1
# 5    Jennings    Leslie          1
# 6    Thompson    Leslie          1
# 7    Firrelli     Julie          2
# 8   Patterson     Steve          2
# 9       Tseng  Foon Yue          3
# 10     Vanauf    George          3
# 11     Bondur      Loui          4
# 12  Hernandez    Gerard          4
# 13   Castillo    Pamela          4
# 14     Gerard    Martin          4

# %% [markdown]
# Select Distinct

# %%
runSELECT("SELECT lastname FROM employees ORDER BY lastname")
# Out:
#      lastname
# 0      Bondur
# 1      Bondur
# 2        Bott
# 3         Bow
# 4    Castillo
# 5    Firrelli
# 6    Firrelli
# 7      Fixter
# 8      Gerard
# 9   Hernandez
# 10   Jennings
# 11      Jones
# 12       Kato
# 13       King
# 14      Marsh
# 15     Murphy
# 16      Nishi
# 17  Patterson
# 18  Patterson
# 19  Patterson
# 20   Thompson
# 21      Tseng
# 22     Vanauf

# %%
runSELECT("SELECT DISTINCT lastname FROM employees ORDER BY lastname")
# Out:
#      lastname
# 0      Bondur
# 1        Bott
# 2         Bow
# 3    Castillo
# 4    Firrelli
# 5      Fixter
# 6      Gerard
# 7   Hernandez
# 8    Jennings
# 9       Jones
# 10       Kato
# 11       King
# 12      Marsh
# 13     Murphy
# 14      Nishi
# 15  Patterson
# 16   Thompson
# 17      Tseng
# 18     Vanauf

# %%
runSELECT("SELECT DISTINCT state\
 FROM customers")
# Out:
#             state
# 0            None
# 1              NV
# 2        Victoria
# 3              CA
# 4              NY
# 5              PA
# 6              CT
# 7              MA
# 8           Osaka
# 9              BC
# 10         Québec
# 11  Isle of Wight
# 12            NSW
# 13             NJ
# 14     Queensland
# 15       Co. Cork
# 16       Pretoria
# 17             NH
# 18          Tokyo

# %%
runSELECT("SELECT DISTINCT state, city FROM customers WHERE state IS NOT NULL ORDER BY state, city")
# Out:
#             state            city
# 0              BC       Tsawassen
# 1              BC       Vancouver
# 2              CA        Brisbane
# 3              CA         Burbank
# 4              CA      Burlingame
# 5              CA        Glendale
# 6              CA     Los Angeles
# 7              CA        Pasadena
# 8              CA       San Diego
# 9              CA   San Francisco
# 10             CA        San Jose
# 11             CA      San Rafael
# 12       Co. Cork            Cork
# 13             CT     Bridgewater
# 14             CT        Glendale
# 15             CT       New Haven
# 16  Isle of Wight           Cowes
# 17             MA          Boston
# 18             MA      Brickhaven
# 19             MA       Cambridge
# 20             MA     New Bedford
# 21             NH          Nashua
# 22             NJ          Newark
# 23            NSW       Chatswood
# 24            NSW    North Sydney
# 25             NV       Las Vegas
# 26             NY             NYC
# 27             NY    White Plains
# 28          Osaka         Kita-ku
# 29             PA       Allentown
# 30             PA    Philadelphia
# 31       Pretoria        Hatfield
# 32         Québec        Montréal
# 33     Queensland  South Brisbane
# 34          Tokyo       Minato-ku
# 35       Victoria    Glen Waverly
# 36       Victoria       Melbourne

# %%
runSELECT("SELECT state, city FROM customers WHERE state IS NOT NULL ORDER BY state , city")
# Out:
#             state            city
# 0              BC       Tsawassen
# 1              BC       Vancouver
# 2              CA        Brisbane
# 3              CA         Burbank
# 4              CA      Burlingame
# 5              CA        Glendale
# 6              CA     Los Angeles
# 7              CA        Pasadena
# 8              CA       San Diego
# 9              CA   San Francisco
# 10             CA   San Francisco
# 11             CA        San Jose
# 12             CA      San Rafael
# 13       Co. Cork            Cork
# 14             CT     Bridgewater
# 15             CT        Glendale
# 16             CT       New Haven
# 17             CT       New Haven
# 18  Isle of Wight           Cowes
# 19             MA          Boston
# 20             MA          Boston
# 21             MA      Brickhaven
# 22             MA      Brickhaven
# 23             MA      Brickhaven
# 24             MA       Cambridge
# 25             MA       Cambridge
# 26             MA     New Bedford
# 27             MA     New Bedford
# 28             NH          Nashua
# 29             NJ          Newark
# 30            NSW       Chatswood
# 31            NSW    North Sydney
# 32             NV       Las Vegas
# 33             NY             NYC
# 34             NY             NYC
# 35             NY             NYC
# 36             NY             NYC
# 37             NY             NYC
# 38             NY    White Plains
# 39          Osaka         Kita-ku
# 40             PA       Allentown
# 41             PA    Philadelphia
# 42             PA    Philadelphia
# 43       Pretoria        Hatfield
# 44         Québec        Montréal
# 45     Queensland  South Brisbane
# 46          Tokyo       Minato-ku
# 47       Victoria    Glen Waverly
# 48       Victoria       Melbourne

# %% [markdown]
# AND

# %%
runSELECT("SELECT 1 AND 1")
# Out:
#    1 AND 1
# 0        1

# %%
runSELECT("SELECT 1 AND 0, 0 AND 1, 0 AND 0, 0 AND NULL")
# Out:
#    1 AND 0  0 AND 1  0 AND 0  0 AND NULL
# 0        0        0        0           0

# %%
runSELECT("SELECT 1 AND NULL, NULL AND NULL")
# Out:
#   1 AND NULL NULL AND NULL
# 0       None          None

# %%
runSELECT("SELECT 1 = 0 AND 1 / 0 ")
# Out:
#    1 = 0 AND 1 / 0
# 0                0

# %%
runSELECT("SELECT customername, country, state FROM customers WHERE country = 'USA' AND state = 'CA'")
# Out:
#                     customername country state
# 0   Mini Gifts Distributors Ltd.     USA    CA
# 1                Mini Wheels Co.     USA    CA
# 2           Technics Stores Inc.     USA    CA
# 3              Toys4GrownUps.com     USA    CA
# 4              Boards & Toys Co.     USA    CA
# 5   Collectable Mini Designs Co.     USA    CA
# 6       Corporate Gift Ideas Co.     USA    CA
# 7     Men 'R' US Retailers, Ltd.     USA    CA
# 8      The Sharp Gifts Warehouse     USA    CA
# 9    West Coast Collectables Co.     USA    CA
# 10      Signal Collectibles Ltd.     USA    CA

# %%
runSELECT("SELECT customername, country, state, creditlimit FROM customers WHERE country = 'USA' AND state = 'CA' AND creditlimit > 100000")
# Out:
#                    customername country state  creditlimit
# 0  Mini Gifts Distributors Ltd.     USA    CA     210500.0
# 1  Collectable Mini Designs Co.     USA    CA     105000.0
# 2      Corporate Gift Ideas Co.     USA    CA     105000.0

# %% [markdown]
# OR

# %%
runSELECT("SELECT 1 OR 1, 1 OR 0, 0 OR 1")
# Out:
#    1 OR 1  1 OR 0  0 OR 1
# 0       1       1       1

# %%
runSELECT("SELECT 0 OR 0")
# Out:
#    0 OR 0
# 0       0

# %%
runSELECT("SELECT 1 OR NULL, 0 OR NULL, NULL or NULL")
# Out:
#    1 OR NULL 0 OR NULL NULL or NULL
# 0          1      None         None

# %%
runSELECT("SELECT 1 = 1 OR 1 / 0")
# Out:
#    1 = 1 OR 1 / 0
# 0               1

# %%
runSELECT("SELECT 1 OR 0 AND 0")
# Out:
#    1 OR 0 AND 0
# 0             1

# %%
runSELECT("SELECT (1 OR 0) AND 0")
# Out:
#    (1 OR 0) AND 0
# 0               0

# %%
runSELECT("SELECT customername, country FROM customers WHERE country = 'USA' OR country = 'France'")
# Out:
#                     customername country
# 0              Atelier graphique  France
# 1             Signal Gift Stores     USA
# 2              La Rochelle Gifts  France
# 3   Mini Gifts Distributors Ltd.     USA
# 4                Mini Wheels Co.     USA
# 5              Land of Toys Inc.     USA
# 6         Saveley & Henriot, Co.  France
# 7             Muscle Machine Inc     USA
# 8          Diecast Classics Inc.     USA
# 9           Technics Stores Inc.     USA
# 10        American Souvenirs Inc     USA
# 11      Daedalus Designs Imports  France
# 12     La Corne D'abondance, Co.  France
# 13    Cambridge Collectables Co.     USA
# 14               Gift Depot Inc.     USA
# 15               Vitachrome Inc.     USA
# 16       Auto-Moto Classics Inc.     USA
# 17      Online Mini Collectables     USA
# 18             Toys4GrownUps.com     USA
# 19                   Mini Caravy  France
# 20             Boards & Toys Co.     USA
# 21  Collectable Mini Designs Co.     USA
# 22                  Alpha Cognac  France
# 23               Lyon Souveniers  France
# 24          Auto Associés & Cie.  France
# 25          Marta's Replicas Co.     USA
# 26                 Mini Classics     USA
# 27           Mini Creations Ltd.     USA
# 28      Corporate Gift Ideas Co.     USA
# 29       Tekni Collectables Inc.     USA
# 30       Classic Gift Ideas, Inc     USA
# 31    Men 'R' US Retailers, Ltd.     USA
# 32          Marseille Mini Autos  France
# 33            Reims Collectables  France
# 34             Gifts4AllAges.com     USA
# 35  Online Diecast Creations Co.     USA
# 36    Collectables For Less Inc.     USA
# 37             Auto Canal+ Petit  France
# 38          Classic Legends Inc.     USA
# 39              Gift Ideas Corp.     USA
# 40     The Sharp Gifts Warehouse     USA
# 41              Super Scale Inc.     USA
# 42               Microscale Inc.     USA
# 43              FunGiftIdeas.com     USA
# 44   West Coast Collectables Co.     USA
# 45  Motor Mint Distributors Inc.     USA
# 46      Signal Collectibles Ltd.     USA
# 47          Diecast Collectables     USA

# %%
runSELECT("SELECT customername, country, creditLimit FROM customers WHERE(country = 'USA'OR country = 'France') AND creditlimit > 100000")
# Out:
#                     customername country  creditLimit
# 0              La Rochelle Gifts  France     118200.0
# 1   Mini Gifts Distributors Ltd.     USA     210500.0
# 2              Land of Toys Inc.     USA     114900.0
# 3         Saveley & Henriot, Co.  France     123900.0
# 4             Muscle Machine Inc     USA     138500.0
# 5          Diecast Classics Inc.     USA     100600.0
# 6   Collectable Mini Designs Co.     USA     105000.0
# 7           Marta's Replicas Co.     USA     123700.0
# 8                  Mini Classics     USA     102700.0
# 9       Corporate Gift Ideas Co.     USA     105000.0
# 10  Online Diecast Creations Co.     USA     114200.0

# %% [markdown]
# IN

# %%
runSELECT("SELECT customername, country, creditLimit FROM customers WHERE country = 'USA' OR country = 'France' AND creditlimit > 100000")
# Out:
#                     customername country  creditLimit
# 0             Signal Gift Stores     USA      71800.0
# 1              La Rochelle Gifts  France     118200.0
# 2   Mini Gifts Distributors Ltd.     USA     210500.0
# 3                Mini Wheels Co.     USA      64600.0
# 4              Land of Toys Inc.     USA     114900.0
# 5         Saveley & Henriot, Co.  France     123900.0
# 6             Muscle Machine Inc     USA     138500.0
# 7          Diecast Classics Inc.     USA     100600.0
# 8           Technics Stores Inc.     USA      84600.0
# 9         American Souvenirs Inc     USA          0.0
# 10    Cambridge Collectables Co.     USA      43400.0
# 11               Gift Depot Inc.     USA      84300.0
# 12               Vitachrome Inc.     USA      76400.0
# 13       Auto-Moto Classics Inc.     USA      23000.0
# 14      Online Mini Collectables     USA      68700.0
# 15             Toys4GrownUps.com     USA      90700.0
# 16             Boards & Toys Co.     USA      11000.0
# 17  Collectable Mini Designs Co.     USA     105000.0
# 18          Marta's Replicas Co.     USA     123700.0
# 19                 Mini Classics     USA     102700.0
# 20           Mini Creations Ltd.     USA      94500.0
# 21      Corporate Gift Ideas Co.     USA     105000.0
# 22       Tekni Collectables Inc.     USA      43000.0
# 23       Classic Gift Ideas, Inc     USA      81100.0
# 24    Men 'R' US Retailers, Ltd.     USA      57700.0
# 25             Gifts4AllAges.com     USA      41900.0
# 26  Online Diecast Creations Co.     USA     114200.0
# 27    Collectables For Less Inc.     USA      70700.0
# 28          Classic Legends Inc.     USA      67500.0
# 29              Gift Ideas Corp.     USA      49700.0
# 30     The Sharp Gifts Warehouse     USA      77600.0
# 31              Super Scale Inc.     USA      95400.0
# 32               Microscale Inc.     USA      39800.0
# 33              FunGiftIdeas.com     USA      85800.0
# 34   West Coast Collectables Co.     USA      55400.0
# 35  Motor Mint Distributors Inc.     USA      72600.0
# 36      Signal Collectibles Ltd.     USA      60300.0
# 37          Diecast Collectables     USA      85100.0

# %%
runSELECT("SELECT NULL IN (1,2,3)")
# Out:
#   NULL IN (1,2,3)
# 0            None

# %%
runSELECT("SELECT 0 IN (1 , 2, 3, NULL)")
# Out:
#   0 IN (1 , 2, 3, NULL)
# 0                  None

# %%
runSELECT("SELECT NULL IN (1 , 2, 3, NULL)")
# Out:
#   NULL IN (1 , 2, 3, NULL)
# 0                     None

# %%
runSELECT("SELECT officeCode, city, phone, country FROM offices WHERE country IN ('USA' , 'France')")
# Out:
#   officeCode           city            phone country
# 0          1  San Francisco  +1 650 219 4782     USA
# 1          2         Boston  +1 215 837 0825     USA
# 2          3            NYC  +1 212 555 3000     USA
# 3          4          Paris  +33 14 723 4404  France

# %%
runSELECT("SELECT officeCode, city, phone FROM offices WHERE country = 'USA' OR country = 'France'")
# Out:
#   officeCode           city            phone
# 0          1  San Francisco  +1 650 219 4782
# 1          2         Boston  +1 215 837 0825
# 2          3            NYC  +1 212 555 3000
# 3          4          Paris  +33 14 723 4404

# %% [markdown]
# NOT IN

# %%
runSELECT("SELECT 1 NOT IN (1,2,3)")
# Out:
#    1 NOT IN (1,2,3)
# 0                 0

# %%
runSELECT("SELECT 0 NOT IN (1,2,3)")
# Out:
#    0 NOT IN (1,2,3)
# 0                 1

# %%
runSELECT("SELECT NULL NOT IN (1,2,3)")
# Out:
#   NULL NOT IN (1,2,3)
# 0                None

# %%
runSELECT("SELECT officeCode, city, phone FROM offices WHERE country NOT IN ('USA' , 'France') ORDER BY city")
# Out:
#   officeCode    city             phone
# 0          7  London  +44 20 7877 2041
# 1          6  Sydney   +61 2 9264 2451
# 2          5   Tokyo   +81 33 224 5000

# %% [markdown]
# BETWEEN

# %%
runSELECT("SELECT 15 BETWEEN 10 AND 20")
# Out:
#    15 BETWEEN 10 AND 20
# 0                     1

# %%
runSELECT("SELECT 15 BETWEEN 20 AND 30")
# Out:
#    15 BETWEEN 20 AND 30
# 0                     0

# %%
runSELECT("SELECT 15 NOT BETWEEN 10 AND 20")
# Out:
#    15 NOT BETWEEN 10 AND 20
# 0                         0

# %%
runSELECT("SELECT productCode, productName, buyPrice FROM products WHERE buyPrice BETWEEN 90 AND 100")
# Out:
#   productCode                           productName  buyPrice
# 0    S10_1949              1952 Alpine Renault 1300     98.58
# 1    S10_4698  2003 Harley-Davidson Eagle Drag Bike     91.02
# 2    S12_1099                     1968 Ford Mustang     95.34
# 3    S12_1108                     2001 Ferrari Enzo     95.59
# 4    S18_1984                      1995 Honda Civic     93.89
# 5    S18_4027                 1970 Triumph Spitfire     91.92
# 6    S24_3856               1956 Porsche 356A Coupe     98.30

# %%
runSELECT("SELECT productCode, productName, buyPrice FROM products WHERE buyPrice >= 90 AND buyPrice <= 100")
# Out:
#   productCode                           productName  buyPrice
# 0    S10_1949              1952 Alpine Renault 1300     98.58
# 1    S10_4698  2003 Harley-Davidson Eagle Drag Bike     91.02
# 2    S12_1099                     1968 Ford Mustang     95.34
# 3    S12_1108                     2001 Ferrari Enzo     95.59
# 4    S18_1984                      1995 Honda Civic     93.89
# 5    S18_4027                 1970 Triumph Spitfire     91.92
# 6    S24_3856               1956 Porsche 356A Coupe     98.30

# %%
runSELECT("SELECT productCode, productName, buyPrice FROM products WHERE buyPrice NOT BETWEEN 20 AND 100")
# Out:
#   productCode                          productName  buyPrice
# 0    S10_4962               1962 LanciaA Delta 16V    103.42
# 1    S18_2238       1998 Chrysler Plymouth Prowler    101.51
# 2    S24_2840  1958 Chevy Corvette Limited Edition     15.91
# 3    S24_2972              1982 Lamborghini Diablo     16.24

# %%
runSELECT("SELECT productCode, productName, buyPrice FROM products WHERE buyPrice < 20 OR buyPrice > 100")
# Out:
#   productCode                          productName  buyPrice
# 0    S10_4962               1962 LanciaA Delta 16V    103.42
# 1    S18_2238       1998 Chrysler Plymouth Prowler    101.51
# 2    S24_2840  1958 Chevy Corvette Limited Edition     15.91
# 3    S24_2972              1982 Lamborghini Diablo     16.24

# %%
runSELECT("SELECT orderNumber, requiredDate, status FROM orders WHERE requireddate BETWEEN CAST('2003-01-01' AS DATE) AND CAST('2003-01-31' AS DATE)")
# Out:
#    orderNumber requiredDate   status
# 0        10100   2003-01-13  Shipped
# 1        10101   2003-01-18  Shipped
# 2        10102   2003-01-18  Shipped

# %% [markdown]
# LIKE

# %%
runSELECT("SELECT employeeNumber, lastName, firstName FROM employees WHERE firstName LIKE 'a%'")
# Out:
#    employeeNumber lastName firstName
# 0            1143      Bow   Anthony
# 1            1611   Fixter      Andy

# %%
runSELECT("SELECT employeeNumber, lastName, firstName FROM employees WHERE lastName LIKE '%on'")
# Out:
#    employeeNumber   lastName firstName
# 0            1056  Patterson      Mary
# 1            1088  Patterson   William
# 2            1166   Thompson    Leslie
# 3            1216  Patterson     Steve

# %%
runSELECT("SELECT employeeNumber, lastName, firstName FROM employees WHERE lastname LIKE '%on%'")
# Out:
#    employeeNumber   lastName firstName
# 0            1056  Patterson      Mary
# 1            1088  Patterson   William
# 2            1102     Bondur    Gerard
# 3            1166   Thompson    Leslie
# 4            1216  Patterson     Steve
# 5            1337     Bondur      Loui
# 6            1504      Jones     Barry

# %%
runSELECT("SELECT employeeNumber, lastName, firstName FROM employees WHERE firstname LIKE 'T_m'")
# Out:
#    employeeNumber lastName firstName
# 0            1619     King       Tom

# %%
runSELECT("SELECT employeeNumber, lastName, firstName FROM employees WHERE lastName NOT LIKE 'B%'")
# Out:
#     employeeNumber   lastName firstName
# 0             1002     Murphy     Diane
# 1             1056  Patterson      Mary
# 2             1076   Firrelli      Jeff
# 3             1088  Patterson   William
# 4             1165   Jennings    Leslie
# 5             1166   Thompson    Leslie
# 6             1188   Firrelli     Julie
# 7             1216  Patterson     Steve
# 8             1286      Tseng  Foon Yue
# 9             1323     Vanauf    George
# 10            1370  Hernandez    Gerard
# 11            1401   Castillo    Pamela
# 12            1504      Jones     Barry
# 13            1611     Fixter      Andy
# 14            1612      Marsh     Peter
# 15            1619       King       Tom
# 16            1621      Nishi      Mami
# 17            1625       Kato   Yoshimi
# 18            1702     Gerard    Martin

# %%
runSELECT("SELECT productCode, productName FROM products WHERE productCode LIKE '%\_20%'")
# Out:
#   productCode                                productName
# 0    S10_2016                      1996 Moto Guzzi 1100i
# 1    S24_2000                   1960 BSA Gold Star DBD34
# 2    S24_2011                      18th century schooner
# 3    S24_2022  1938 Cadillac V-16 Presidential Limousine
# 4   S700_2047                                 HMS Bounty

# %%
runSELECT("SELECT productCode, productName FROM products WHERE productCode LIKE '%$_20%' ESCAPE '$'")
# Out:
#   productCode                                productName
# 0    S10_2016                      1996 Moto Guzzi 1100i
# 1    S24_2000                   1960 BSA Gold Star DBD34
# 2    S24_2011                      18th century schooner
# 3    S24_2022  1938 Cadillac V-16 Presidential Limousine
# 4   S700_2047                                 HMS Bounty

# %% [markdown]
# LIMIT

# %%
runSELECT("SELECT customerNumber, customerName, creditLimit FROM customers ORDER BY creditLimit DESC LIMIT 5;")
# Out:
#    customerNumber                  customerName  creditLimit
# 0             141        Euro+ Shopping Channel     227600.0
# 1             124  Mini Gifts Distributors Ltd.     210500.0
# 2             298               Vida Sport, Ltd     141300.0
# 3             151            Muscle Machine Inc     138500.0
# 4             187                AV Stores, Co.     136800.0

# %%
runSELECT("SELECT customerNumber, customerName, creditLimit FROM customers ORDER BY creditLimit LIMIT 5;")
# Out:
#    customerNumber                customerName  creditLimit
# 0             223             Natürlich Autos          0.0
# 1             168      American Souvenirs Inc          0.0
# 2             169           Porto Imports Co.          0.0
# 3             206  Asian Shopping Network, Co          0.0
# 4             125          Havel & Zbyszek Co          0.0

# %%
runSELECT("SELECT customerNumber, customerName, creditLimit FROM customers ORDER BY creditLimit, customerNumber LIMIT 5;")
# Out:
#    customerNumber                customerName  creditLimit
# 0             125          Havel & Zbyszek Co          0.0
# 1             168      American Souvenirs Inc          0.0
# 2             169           Porto Imports Co.          0.0
# 3             206  Asian Shopping Network, Co          0.0
# 4             223             Natürlich Autos          0.0

# %%
runSELECT("SELECT COUNT(*) FROM customers;")
# Out:
#    COUNT(*)
# 0       122

# %%
runSELECT("SELECT customerNumber, customerName FROM customers ORDER BY customerName LIMIT 10;")
# Out:
#    customerNumber                  customerName
# 0             242                  Alpha Cognac
# 1             168        American Souvenirs Inc
# 2             249            Amica Models & Co.
# 3             237                 ANG Resellers
# 4             276       Anna's Decorations, Ltd
# 5             465           Anton Designs, Ltd.
# 6             206    Asian Shopping Network, Co
# 7             348         Asian Treasures, Inc.
# 8             103             Atelier graphique
# 9             471  Australian Collectables, Ltd

# %%
runSELECT("SELECT customerNumber, customerName FROM customers ORDER BY customerName LIMIT 10, 10;")
# Out:
#    customerNumber                        customerName
# 0             114          Australian Collectors, Co.
# 1             333         Australian Gift Network, Co
# 2             256                Auto Associés & Cie.
# 3             406                   Auto Canal+ Petit
# 4             198             Auto-Moto Classics Inc.
# 5             187                      AV Stores, Co.
# 6             121                  Baane Mini Imports
# 7             415  Bavarian Collectables Imports, Co.
# 8             293                   BG&E Collectables
# 9             128                Blauer See Auto, Co.

# %%
runSELECT("SELECT customerName, creditLimit FROM customers ORDER BY creditLimit DESC LIMIT 1,1;")
# Out:
#                    customerName  creditLimit
# 0  Mini Gifts Distributors Ltd.     210500.0

# %%
runSELECT("SELECT customerName, creditLimit FROM customers ORDER BY creditLimit DESC;")
# Out:
#                      customerName  creditLimit
# 0          Euro+ Shopping Channel     227600.0
# 1    Mini Gifts Distributors Ltd.     210500.0
# 2                 Vida Sport, Ltd     141300.0
# 3              Muscle Machine Inc     138500.0
# 4                  AV Stores, Co.     136800.0
# ..                            ...          ...
# 117              Warburg Exchange          0.0
# 118           Anton Designs, Ltd.          0.0
# 119           Mit Vergnügen & Co.          0.0
# 120     Kremlin Collectables, Co.          0.0
# 121            Raanan Stores, Inc          0.0
#
# [122 rows x 2 columns]

# %%
runSELECT("SELECT DISTINCT state FROM customers WHERE state IS NOT NULL LIMIT 5;")
# Out:
#       state
# 0        NV
# 1  Victoria
# 2        CA
# 3        NY
# 4        PA

# %% [markdown]
# IS NULL

# %%
runSELECT("SELECT customerName, country, salesrepemployeenumber FROM customers WHERE salesrepemployeenumber IS NULL ORDER BY customerName;")
# Out:
#                       customerName       country salesrepemployeenumber
# 0                    ANG Resellers         Spain                   None
# 1              Anton Designs, Ltd.         Spain                   None
# 2       Asian Shopping Network, Co     Singapore                   None
# 3            Asian Treasures, Inc.       Ireland                   None
# 4                BG&E Collectables   Switzerland                   None
# 5        Cramer Spezialitäten, Ltd       Germany                   None
# 6                 Der Hund Imports       Germany                   None
# 7         Feuer Online Stores, Inc       Germany                   None
# 8                Franken Gifts, Co       Germany                   None
# 9               Havel & Zbyszek Co        Poland                   None
# 10                 Kommission Auto       Germany                   None
# 11       Kremlin Collectables, Co.        Russia                   None
# 12          Lisboa Souveniers, Inc      Portugal                   None
# 13        Messner Shopping Network       Germany                   None
# 14             Mit Vergnügen & Co.       Germany                   None
# 15                 Natürlich Autos       Germany                   None
# 16               Porto Imports Co.      Portugal                   None
# 17              Raanan Stores, Inc        Israel                   None
# 18            SAR Distributors, Co  South Africa                   None
# 19                Schuyler Imports   Netherlands                   None
# 20  Stuttgart Collectable Exchange       Germany                   None
# 21                Warburg Exchange       Germany                   None

# %%
runSELECT("SELECT customerName, country, salesrepemployeenumber FROM customers WHERE salesrepemployeenumber IS NOT NULL ORDER BY customerName;")
# Out:
#                    customerName      country  salesrepemployeenumber
# 0                  Alpha Cognac       France                    1370
# 1        American Souvenirs Inc          USA                    1286
# 2            Amica Models & Co.        Italy                    1401
# 3       Anna's Decorations, Ltd    Australia                    1611
# 4             Atelier graphique       France                    1370
# ..                          ...          ...                     ...
# 95        UK Collectables, Ltd.           UK                    1501
# 96              Vida Sport, Ltd  Switzerland                    1702
# 97              Vitachrome Inc.          USA                    1286
# 98     Volvo Model Replicas, Co       Sweden                    1504
# 99  West Coast Collectables Co.          USA                    1166
#
# [100 rows x 3 columns]

# %%
runCMD("SELECT customerName, country, salesrepemployeenumber FROM customers WHERE salesrepemployeenumber IS NOT NULL ORDER BY customerName")
# Out:
# 100

# %%
runCMD("CREATE TABLE IF NOT EXISTS projects (\
    id INT AUTO_INCREMENT,\
    title VARCHAR(255),\
    begin_date DATE NOT NULL,\
    complete_date DATE NOT NULL,\
    PRIMARY KEY(id));")
# Out:
# 0

# %%
runCMD("INSERT INTO projects(title,begin_date, complete_date)\
VALUES('New CRM','2020-01-01','2030-01-01'),\
      ('ERP Future','2020-01-01','2030-01-01'),\
      ('VR','2020-01-01','2030-01-01');")
# Out:
# 3

# %%
runSELECT("SELECT * FROM projects WHERE complete_date IS NULL;")
# Out:
# Empty DataFrame
# Columns: [id, title, begin_date, complete_date]
# Index: []

# %%
runCMD("INSERT INTO projects(title,begin_date, complete_date)\
VALUES('MRP III','2010-01-01','2020-12-31');")
# Out:
# 1

# %%
runSELECT("SELECT id FROM projects WHERE id IS NULL;")
# Out:
# Empty DataFrame
# Columns: [id]
# Index: []

# %% [markdown]
# # SECTION 4: JOINING TABLES

# %% [markdown]
# Table and Column Aliases

# %%
runSELECT("SELECT CONCAT_WS(', ', lastName, firstname) FROM employees;")
# Out:
#    CONCAT_WS(', ', lastName, firstname)
# 0                         Murphy, Diane
# 1                       Patterson, Mary
# 2                        Firrelli, Jeff
# 3                    Patterson, William
# 4                        Bondur, Gerard
# 5                          Bow, Anthony
# 6                      Jennings, Leslie
# 7                      Thompson, Leslie
# 8                       Firrelli, Julie
# 9                      Patterson, Steve
# 10                      Tseng, Foon Yue
# 11                       Vanauf, George
# 12                         Bondur, Loui
# 13                    Hernandez, Gerard
# 14                     Castillo, Pamela
# 15                          Bott, Larry
# 16                         Jones, Barry
# 17                         Fixter, Andy
# 18                         Marsh, Peter
# 19                            King, Tom
# 20                          Nishi, Mami
# 21                        Kato, Yoshimi
# 22                       Gerard, Martin

# %%
runSELECT("SELECT CONCAT_WS(', ', lastName, firstname) AS `Full name` FROM employees;")
# Out:
#              Full name
# 0        Murphy, Diane
# 1      Patterson, Mary
# 2       Firrelli, Jeff
# 3   Patterson, William
# 4       Bondur, Gerard
# 5         Bow, Anthony
# 6     Jennings, Leslie
# 7     Thompson, Leslie
# 8      Firrelli, Julie
# 9     Patterson, Steve
# 10     Tseng, Foon Yue
# 11      Vanauf, George
# 12        Bondur, Loui
# 13   Hernandez, Gerard
# 14    Castillo, Pamela
# 15         Bott, Larry
# 16        Jones, Barry
# 17        Fixter, Andy
# 18        Marsh, Peter
# 19           King, Tom
# 20         Nishi, Mami
# 21       Kato, Yoshimi
# 22      Gerard, Martin

# %%
runSELECT("SELECT CONCAT_WS(', ', lastName, firstname) `Full name` FROM employees ORDER BY `Full name`;")
# Out:
#              Full name
# 0       Bondur, Gerard
# 1         Bondur, Loui
# 2          Bott, Larry
# 3         Bow, Anthony
# 4     Castillo, Pamela
# 5       Firrelli, Jeff
# 6      Firrelli, Julie
# 7         Fixter, Andy
# 8       Gerard, Martin
# 9    Hernandez, Gerard
# 10    Jennings, Leslie
# 11        Jones, Barry
# 12       Kato, Yoshimi
# 13           King, Tom
# 14        Marsh, Peter
# 15       Murphy, Diane
# 16         Nishi, Mami
# 17     Patterson, Mary
# 18    Patterson, Steve
# 19  Patterson, William
# 20    Thompson, Leslie
# 21     Tseng, Foon Yue
# 22      Vanauf, George

# %%
runSELECT("SELECT orderNumber `Order no.`, SUM(priceEach * quantityOrdered) Total FROM orderdetails GROUP BY `Order no.` HAVING total > 60000;")
# Out:
#    Order no.     Total
# 0      10165  67392.85
# 1      10287  61402.00
# 2      10310  61234.67

# %%
runSELECT("SELECT * FROM employees e;")
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# 18            1612      Marsh     Peter      x102
# 19            1619       King       Tom      x103
# 20            1621      Nishi      Mami      x101
# 21            1625       Kato   Yoshimi      x102
# 22            1702     Gerard    Martin     x2312
#
#                               email officeCode  reportsTo  \
# 0      dmurphy@classicmodelcars.com          1        NaN
# 1    mpatterso@classicmodelcars.com          1     1002.0
# 2    jfirrelli@classicmodelcars.com          1     1002.0
# 3   wpatterson@classicmodelcars.com          6     1056.0
# 4      gbondur@classicmodelcars.com          4     1056.0
# 5         abow@classicmodelcars.com          1     1056.0
# 6    ljennings@classicmodelcars.com          1     1143.0
# 7    lthompson@classicmodelcars.com          1     1143.0
# 8    jfirrelli@classicmodelcars.com          2     1143.0
# 9   spatterson@classicmodelcars.com          2     1143.0
# 10      ftseng@classicmodelcars.com          3     1143.0
# 11     gvanauf@classicmodelcars.com          3     1143.0
# 12     lbondur@classicmodelcars.com          4     1102.0
# 13   ghernande@classicmodelcars.com          4     1102.0
# 14   pcastillo@classicmodelcars.com          4     1102.0
# 15       lbott@classicmodelcars.com          7     1102.0
# 16      bjones@classicmodelcars.com          7     1102.0
# 17     afixter@classicmodelcars.com          6     1088.0
# 18      pmarsh@classicmodelcars.com          6     1088.0
# 19       tking@classicmodelcars.com          6     1088.0
# 20      mnishi@classicmodelcars.com          5     1056.0
# 21       ykato@classicmodelcars.com          5     1621.0
# 22     mgerard@classicmodelcars.com          4     1102.0
#
#                 jobTitle
# 0              President
# 1               VP Sales
# 2           VP Marketing
# 3   Sales Manager (APAC)
# 4    Sale Manager (EMEA)
# 5     Sales Manager (NA)
# 6              Sales Rep
# 7              Sales Rep
# 8              Sales Rep
# 9              Sales Rep
# 10             Sales Rep
# 11             Sales Rep
# 12             Sales Rep
# 13             Sales Rep
# 14             Sales Rep
# 15             Sales Rep
# 16             Sales Rep
# 17             Sales Rep
# 18             Sales Rep
# 19             Sales Rep
# 20             Sales Rep
# 21             Sales Rep
# 22             Sales Rep

# %%
runSELECT("SELECT e.firstName, e.lastName FROM employees e ORDER BY e.firstName;")
# Out:
#    firstName   lastName
# 0       Andy     Fixter
# 1    Anthony        Bow
# 2      Barry      Jones
# 3      Diane     Murphy
# 4   Foon Yue      Tseng
# 5     George     Vanauf
# 6     Gerard     Bondur
# 7     Gerard  Hernandez
# 8       Jeff   Firrelli
# 9      Julie   Firrelli
# 10     Larry       Bott
# 11    Leslie   Jennings
# 12    Leslie   Thompson
# 13      Loui     Bondur
# 14      Mami      Nishi
# 15    Martin     Gerard
# 16      Mary  Patterson
# 17    Pamela   Castillo
# 18     Peter      Marsh
# 19     Steve  Patterson
# 20       Tom       King
# 21   William  Patterson
# 22   Yoshimi       Kato

# %%
runSELECT("SELECT customerName, COUNT(o.orderNumber) total FROM customers c INNER JOIN orders o ON c.customerNumber = o.customerNumber GROUP BY customerName ORDER BY total DESC")
# Out:
#                           customerName  total
# 0               Euro+ Shopping Channel     26
# 1         Mini Gifts Distributors Ltd.     17
# 2             Danish Wholesale Imports      5
# 3                   Reims Collectables      5
# 4              Dragon Souveniers, Ltd.      5
# ..                                 ...    ...
# 93         King Kong Collectables, Co.      2
# 94                  Amica Models & Co.      2
# 95   Royal Canadian Collectables, Ltd.      2
# 96                Marta's Replicas Co.      2
# 97  Bavarian Collectables Imports, Co.      1
#
# [98 rows x 2 columns]

# %%
runSELECT("SELECT customers.customerName, COUNT(orders.orderNumber) total FROM customers INNER JOIN orders ON customers.customerNumber = orders.customerNumber GROUP BY customerName ORDER BY total DESC")
# Out:
#                           customerName  total
# 0               Euro+ Shopping Channel     26
# 1         Mini Gifts Distributors Ltd.     17
# 2           Australian Collectors, Co.      5
# 3           Down Under Souveniers, Inc      5
# 4             Danish Wholesale Imports      5
# ..                                 ...    ...
# 93                Heintze Collectables      2
# 94             Toms Spezialitäten, Ltd      2
# 95          Men 'R' US Retailers, Ltd.      2
# 96                    Super Scale Inc.      2
# 97  Bavarian Collectables Imports, Co.      1
#
# [98 rows x 2 columns]

# %% [markdown]
# Joins

# %%
runCMD("CREATE TABLE IF NOT EXISTS members (\
    member_id INT AUTO_INCREMENT,\
    name VARCHAR(100),\
    PRIMARY KEY (member_id)\
);")
# Out:
# 0

# %%
runCMD("CREATE TABLE IF NOT EXISTS committees (\
    committee_id INT AUTO_INCREMENT,\
    name VARCHAR(100),\
    PRIMARY KEY (committee_id) );")
# Out:
# 0

# %%
runCMD("INSERT INTO members(name)\
VALUES('John'),('Jane'),('Mary'),('David'),('Amelia');")
# Out:
# 5

# %%
runCMD("INSERT INTO committees(name)\
VALUES('John'),('Mary'),('Amelia'),('Joe');")
# Out:
# 4

# %%
runSELECT("SELECT * FROM members;")
# Out:
#    member_id    name
# 0          1    John
# 1          2    Jane
# 2          3    Mary
# 3          4   David
# 4          5  Amelia
# 5          6    John
# 6          7    Jane
# 7          8    Mary
# 8          9   David
# 9         10  Amelia

# %%
runSELECT("SELECT * FROM committees;")
# Out:
#    committee_id    name
# 0             1    John
# 1             2    Mary
# 2             3  Amelia
# 3             4     Joe
# 4             5    John
# 5             6    Mary
# 6             7  Amelia
# 7             8     Joe

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m INNER JOIN committees c ON c.name = m.name;")
# Out:
#     member_id  member  committee_id committee
# 0           1    John             1      John
# 1           1    John             5      John
# 2           3    Mary             2      Mary
# 3           3    Mary             6      Mary
# 4           5  Amelia             3    Amelia
# 5           5  Amelia             7    Amelia
# 6           6    John             1      John
# 7           6    John             5      John
# 8           8    Mary             2      Mary
# 9           8    Mary             6      Mary
# 10         10  Amelia             3    Amelia
# 11         10  Amelia             7    Amelia

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m INNER JOIN committees c USING(name);")
# Out:
#     member_id  member  committee_id committee
# 0           1    John             1      John
# 1           1    John             5      John
# 2           3    Mary             2      Mary
# 3           3    Mary             6      Mary
# 4           5  Amelia             3    Amelia
# 5           5  Amelia             7    Amelia
# 6           6    John             1      John
# 7           6    John             5      John
# 8           8    Mary             2      Mary
# 9           8    Mary             6      Mary
# 10         10  Amelia             3    Amelia
# 11         10  Amelia             7    Amelia

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m LEFT JOIN committees c USING(name);")
# Out:
#     member_id  member  committee_id committee
# 0           1    John           1.0      John
# 1           6    John           1.0      John
# 2           3    Mary           2.0      Mary
# 3           8    Mary           2.0      Mary
# 4           5  Amelia           3.0    Amelia
# 5          10  Amelia           3.0    Amelia
# 6           1    John           5.0      John
# 7           6    John           5.0      John
# 8           3    Mary           6.0      Mary
# 9           8    Mary           6.0      Mary
# 10          5  Amelia           7.0    Amelia
# 11         10  Amelia           7.0    Amelia
# 12          2    Jane           NaN      None
# 13          4   David           NaN      None
# 14          7    Jane           NaN      None
# 15          9   David           NaN      None

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m LEFT JOIN committees c USING(name);")
# Out:
#     member_id  member  committee_id committee
# 0           1    John           1.0      John
# 1           6    John           1.0      John
# 2           3    Mary           2.0      Mary
# 3           8    Mary           2.0      Mary
# 4           5  Amelia           3.0    Amelia
# 5          10  Amelia           3.0    Amelia
# 6           1    John           5.0      John
# 7           6    John           5.0      John
# 8           3    Mary           6.0      Mary
# 9           8    Mary           6.0      Mary
# 10          5  Amelia           7.0    Amelia
# 11         10  Amelia           7.0    Amelia
# 12          2    Jane           NaN      None
# 13          4   David           NaN      None
# 14          7    Jane           NaN      None
# 15          9   David           NaN      None

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m LEFT JOIN committees c USING(name) WHERE c.committee_id IS NULL;")
# Out:
#    member_id member committee_id committee
# 0          2   Jane         None      None
# 1          4  David         None      None
# 2          7   Jane         None      None
# 3          9  David         None      None

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m RIGHT JOIN committees c on c.name = m.name;")
# Out:
#     member_id  member  committee_id committee
# 0         1.0    John             1      John
# 1         1.0    John             5      John
# 2         3.0    Mary             2      Mary
# 3         3.0    Mary             6      Mary
# 4         5.0  Amelia             3    Amelia
# 5         5.0  Amelia             7    Amelia
# 6         6.0    John             1      John
# 7         6.0    John             5      John
# 8         8.0    Mary             2      Mary
# 9         8.0    Mary             6      Mary
# 10       10.0  Amelia             3    Amelia
# 11       10.0  Amelia             7    Amelia
# 12        NaN    None             4       Joe
# 13        NaN    None             8       Joe

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m RIGHT JOIN committees c USING(name);")
# Out:
#     member_id  member  committee_id committee
# 0         1.0    John             1      John
# 1         1.0    John             5      John
# 2         3.0    Mary             2      Mary
# 3         3.0    Mary             6      Mary
# 4         5.0  Amelia             3    Amelia
# 5         5.0  Amelia             7    Amelia
# 6         6.0    John             1      John
# 7         6.0    John             5      John
# 8         8.0    Mary             2      Mary
# 9         8.0    Mary             6      Mary
# 10       10.0  Amelia             3    Amelia
# 11       10.0  Amelia             7    Amelia
# 12        NaN    None             4       Joe
# 13        NaN    None             8       Joe

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m RIGHT JOIN committees c USING(name) WHERE m.member_id IS NULL;")
# Out:
#   member_id member  committee_id committee
# 0      None   None             4       Joe
# 1      None   None             8       Joe

# %%
runSELECT('SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m RIGHT JOIN committees c USING(name) WHERE m.member_id IS NULL;')
# Out:
#   member_id member  committee_id committee
# 0      None   None             4       Joe
# 1      None   None             8       Joe

# %%
runSELECT("SELECT m.member_id, m.name AS member, c.committee_id, c.name AS committee FROM members m CROSS JOIN committees c;")
# Out:
#     member_id  member  committee_id committee
# 0           1    John             1      John
# 1           1    John             2      Mary
# 2           1    John             3    Amelia
# 3           1    John             4       Joe
# 4           1    John             5      John
# ..        ...     ...           ...       ...
# 75         10  Amelia             4       Joe
# 76         10  Amelia             5      John
# 77         10  Amelia             6      Mary
# 78         10  Amelia             7    Amelia
# 79         10  Amelia             8       Joe
#
# [80 rows x 4 columns]

# %% [markdown]
# INNER JOIN

# %%
runSELECT("SELECT productCode, productName, textDescription FROM products T1 INNER JOIN productlines T2 ON T1.productline = T2.productline;")
# Out:
#     productCode                       productName  \
# 0      S10_1949          1952 Alpine Renault 1300
# 1      S10_4757               1972 Alfa Romeo GTA
# 2      S10_4962            1962 LanciaA Delta 16V
# 3      S12_1099                 1968 Ford Mustang
# 4      S12_1108                 2001 Ferrari Enzo
# ..          ...                               ...
# 105    S24_3816          1940 Ford Delivery Sedan
# 106    S24_3969  1936 Mercedes Benz 500k Roadster
# 107    S24_4258             1936 Chrysler Airflow
# 108    S32_4289          1928 Ford Phaeton Deluxe
# 109    S50_1341      1930 Buick Marquette Phaeton
#
#                                        textDescription
# 0    Attention car enthusiasts: Make your wildest c...
# 1    Attention car enthusiasts: Make your wildest c...
# 2    Attention car enthusiasts: Make your wildest c...
# 3    Attention car enthusiasts: Make your wildest c...
# 4    Attention car enthusiasts: Make your wildest c...
# ..                                                 ...
# 105  Our Vintage Car models realistically portray a...
# 106  Our Vintage Car models realistically portray a...
# 107  Our Vintage Car models realistically portray a...
# 108  Our Vintage Car models realistically portray a...
# 109  Our Vintage Car models realistically portray a...
#
# [110 rows x 3 columns]

# %%
runSELECT("SELECT productCode, productName, textDescription FROM products INNER JOIN productlines USING (productline);")
# Out:
#     productCode                       productName  \
# 0      S10_1949          1952 Alpine Renault 1300
# 1      S10_4757               1972 Alfa Romeo GTA
# 2      S10_4962            1962 LanciaA Delta 16V
# 3      S12_1099                 1968 Ford Mustang
# 4      S12_1108                 2001 Ferrari Enzo
# ..          ...                               ...
# 105    S24_3816          1940 Ford Delivery Sedan
# 106    S24_3969  1936 Mercedes Benz 500k Roadster
# 107    S24_4258             1936 Chrysler Airflow
# 108    S32_4289          1928 Ford Phaeton Deluxe
# 109    S50_1341      1930 Buick Marquette Phaeton
#
#                                        textDescription
# 0    Attention car enthusiasts: Make your wildest c...
# 1    Attention car enthusiasts: Make your wildest c...
# 2    Attention car enthusiasts: Make your wildest c...
# 3    Attention car enthusiasts: Make your wildest c...
# 4    Attention car enthusiasts: Make your wildest c...
# ..                                                 ...
# 105  Our Vintage Car models realistically portray a...
# 106  Our Vintage Car models realistically portray a...
# 107  Our Vintage Car models realistically portray a...
# 108  Our Vintage Car models realistically portray a...
# 109  Our Vintage Car models realistically portray a...
#
# [110 rows x 3 columns]

# %%
runSELECT("SELECT T1.orderNumber, status, SUM(quantityOrdered * priceEach) total FROM orders AS T1 INNER JOIN orderdetails AS T2 ON T1.orderNumber = T2.orderNumber GROUP BY orderNumber;")
# Out:
#      orderNumber      status     total
# 0          10100     Shipped  10223.83
# 1          10101     Shipped  10549.01
# 2          10102     Shipped   5494.78
# 3          10103     Shipped  50218.95
# 4          10104     Shipped  40206.20
# ..           ...         ...       ...
# 321        10421  In Process   7639.10
# 322        10422  In Process   5849.44
# 323        10423  In Process   8597.73
# 324        10424  In Process  29310.30
# 325        10425  In Process  41623.44
#
# [326 rows x 3 columns]

# %%
runSELECT("SELECT orderNumber,status, SUM(quantityOrdered * priceEach) total FROM orders INNER JOIN orderdetails USING (orderNumber) GROUP BY orderNumber;")
# Out:
#      orderNumber      status     total
# 0          10100     Shipped  10223.83
# 1          10101     Shipped  10549.01
# 2          10102     Shipped   5494.78
# 3          10103     Shipped  50218.95
# 4          10104     Shipped  40206.20
# ..           ...         ...       ...
# 321        10421  In Process   7639.10
# 322        10422  In Process   5849.44
# 323        10423  In Process   8597.73
# 324        10424  In Process  29310.30
# 325        10425  In Process  41623.44
#
# [326 rows x 3 columns]

# %%
runSELECT("SELECT orderNumber,orderDate,orderLineNumber,productName,quantityOrdered, priceEach FROM orders INNER JOIN orderdetails USING (orderNumber) INNER JOIN products USING (productCode) ORDER BY orderNumber, orderLineNumber;")
# Out:
#       orderNumber   orderDate  orderLineNumber  \
# 0           10100  2003-01-06                1
# 1           10100  2003-01-06                2
# 2           10100  2003-01-06                3
# 3           10100  2003-01-06                4
# 4           10101  2003-01-09                1
# ...           ...         ...              ...
# 2991        10425  2005-05-31                9
# 2992        10425  2005-05-31               10
# 2993        10425  2005-05-31               11
# 2994        10425  2005-05-31               12
# 2995        10425  2005-05-31               13
#
#                               productName  quantityOrdered  priceEach
# 0        1936 Mercedes Benz 500k Roadster               49      35.29
# 1                      1911 Ford Town Car               50      55.09
# 2                1917 Grand Touring Sedan               30     136.00
# 3     1932 Alfa Romeo 8C2300 Spider Sport               22      75.46
# 4                  1928 Mercedes-Benz SSK               26     167.06
# ...                                   ...              ...        ...
# 2991             1962 Volkswagen Microbus               49     127.79
# 2992                1926 Ford Fire Engine               19      48.62
# 2993          1980’s GM Manhattan Express               41      83.79
# 2994               1962 LanciaA Delta 16V               38     131.49
# 2995                     1940s Ford truck               38     107.76
#
# [2996 rows x 6 columns]

# %%
runSELECT("SELECT orderNumber,orderDate,customerName,orderLineNumber,productName,quantityOrdered,priceEach FROM orders INNER JOIN orderdetails USING (orderNumber) INNER JOIN products USING (productCode) INNER JOIN customers USING (customerNumber) ORDER BY orderNumber, orderLineNumber;")
# Out:
#       orderNumber   orderDate                  customerName  orderLineNumber  \
# 0           10100  2003-01-06  Online Diecast Creations Co.                1
# 1           10100  2003-01-06  Online Diecast Creations Co.                2
# 2           10100  2003-01-06  Online Diecast Creations Co.                3
# 3           10100  2003-01-06  Online Diecast Creations Co.                4
# 4           10101  2003-01-09          Blauer See Auto, Co.                1
# ...           ...         ...                           ...              ...
# 2991        10425  2005-05-31             La Rochelle Gifts                9
# 2992        10425  2005-05-31             La Rochelle Gifts               10
# 2993        10425  2005-05-31             La Rochelle Gifts               11
# 2994        10425  2005-05-31             La Rochelle Gifts               12
# 2995        10425  2005-05-31             La Rochelle Gifts               13
#
#                               productName  quantityOrdered  priceEach
# 0        1936 Mercedes Benz 500k Roadster               49      35.29
# 1                      1911 Ford Town Car               50      55.09
# 2                1917 Grand Touring Sedan               30     136.00
# 3     1932 Alfa Romeo 8C2300 Spider Sport               22      75.46
# 4                  1928 Mercedes-Benz SSK               26     167.06
# ...                                   ...              ...        ...
# 2991             1962 Volkswagen Microbus               49     127.79
# 2992                1926 Ford Fire Engine               19      48.62
# 2993          1980’s GM Manhattan Express               41      83.79
# 2994               1962 LanciaA Delta 16V               38     131.49
# 2995                     1940s Ford truck               38     107.76
#
# [2996 rows x 7 columns]

# %%
runSELECT("SELECT orderNumber, productName, msrp, priceEach FROM products p INNER JOIN orderdetails o ON p.productcode = o.productcode AND p.msrp > o.priceEach WHERE p.productcode = 'S10_1678';")
# Out:
#     orderNumber                            productName  msrp  priceEach
# 0         10107  1969 Harley Davidson Ultimate Chopper  95.7      81.35
# 1         10121  1969 Harley Davidson Ultimate Chopper  95.7      86.13
# 2         10134  1969 Harley Davidson Ultimate Chopper  95.7      90.92
# 3         10145  1969 Harley Davidson Ultimate Chopper  95.7      76.56
# 4         10159  1969 Harley Davidson Ultimate Chopper  95.7      81.35
# 5         10168  1969 Harley Davidson Ultimate Chopper  95.7      94.74
# 6         10180  1969 Harley Davidson Ultimate Chopper  95.7      76.56
# 7         10201  1969 Harley Davidson Ultimate Chopper  95.7      82.30
# 8         10211  1969 Harley Davidson Ultimate Chopper  95.7      90.92
# 9         10223  1969 Harley Davidson Ultimate Chopper  95.7      80.39
# 10        10237  1969 Harley Davidson Ultimate Chopper  95.7      91.87
# 11        10251  1969 Harley Davidson Ultimate Chopper  95.7      93.79
# 12        10263  1969 Harley Davidson Ultimate Chopper  95.7      89.00
# 13        10275  1969 Harley Davidson Ultimate Chopper  95.7      81.35
# 14        10299  1969 Harley Davidson Ultimate Chopper  95.7      76.56
# 15        10309  1969 Harley Davidson Ultimate Chopper  95.7      94.74
# 16        10318  1969 Harley Davidson Ultimate Chopper  95.7      84.22
# 17        10329  1969 Harley Davidson Ultimate Chopper  95.7      80.39
# 18        10341  1969 Harley Davidson Ultimate Chopper  95.7      84.22
# 19        10354  1969 Harley Davidson Ultimate Chopper  95.7      84.22
# 20        10361  1969 Harley Davidson Ultimate Chopper  95.7      92.83
# 21        10375  1969 Harley Davidson Ultimate Chopper  95.7      76.56
# 22        10388  1969 Harley Davidson Ultimate Chopper  95.7      80.39
# 23        10399  1969 Harley Davidson Ultimate Chopper  95.7      77.52
# 24        10403  1969 Harley Davidson Ultimate Chopper  95.7      85.17
# 25        10417  1969 Harley Davidson Ultimate Chopper  95.7      79.43

# %% [markdown]
# LEFT JOIN

# %%
runSELECT("SELECT customers.customerNumber, customerName, orderNumber, status FROM customers LEFT JOIN orders ON orders.customerNumber = customers.customerNumber;")
# Out:
#      customerNumber          customerName  orderNumber     status
# 0               103     Atelier graphique      10123.0    Shipped
# 1               103     Atelier graphique      10298.0    Shipped
# 2               103     Atelier graphique      10345.0    Shipped
# 3               112    Signal Gift Stores      10124.0    Shipped
# 4               112    Signal Gift Stores      10278.0    Shipped
# ..              ...                   ...          ...        ...
# 345             495  Diecast Collectables      10243.0    Shipped
# 346             496     Kelly's Gift Shop      10138.0    Shipped
# 347             496     Kelly's Gift Shop      10179.0  Cancelled
# 348             496     Kelly's Gift Shop      10360.0    Shipped
# 349             496     Kelly's Gift Shop      10399.0    Shipped
#
# [350 rows x 4 columns]

# %%
runSELECT("SELECT c.customerNumber,customerName,orderNumber,status FROM customers c LEFT JOIN orders o ON c.customerNumber = o.customerNumber;")
# Out:
#      customerNumber          customerName  orderNumber     status
# 0               103     Atelier graphique      10123.0    Shipped
# 1               103     Atelier graphique      10298.0    Shipped
# 2               103     Atelier graphique      10345.0    Shipped
# 3               112    Signal Gift Stores      10124.0    Shipped
# 4               112    Signal Gift Stores      10278.0    Shipped
# ..              ...                   ...          ...        ...
# 345             495  Diecast Collectables      10243.0    Shipped
# 346             496     Kelly's Gift Shop      10138.0    Shipped
# 347             496     Kelly's Gift Shop      10179.0  Cancelled
# 348             496     Kelly's Gift Shop      10360.0    Shipped
# 349             496     Kelly's Gift Shop      10399.0    Shipped
#
# [350 rows x 4 columns]

# %%
runSELECT("SELECT customerNumber,customerName,orderNumber,status FROM customers LEFT JOIN orders USING (customerNumber);")
# Out:
#      customerNumber          customerName  orderNumber     status
# 0               103     Atelier graphique      10123.0    Shipped
# 1               103     Atelier graphique      10298.0    Shipped
# 2               103     Atelier graphique      10345.0    Shipped
# 3               112    Signal Gift Stores      10124.0    Shipped
# 4               112    Signal Gift Stores      10278.0    Shipped
# ..              ...                   ...          ...        ...
# 345             495  Diecast Collectables      10243.0    Shipped
# 346             496     Kelly's Gift Shop      10138.0    Shipped
# 347             496     Kelly's Gift Shop      10179.0  Cancelled
# 348             496     Kelly's Gift Shop      10360.0    Shipped
# 349             496     Kelly's Gift Shop      10399.0    Shipped
#
# [350 rows x 4 columns]

# %%
runSELECT("SELECT c.customerNumber, c.customerName, o.orderNumber, o.status FROM customers c LEFT JOIN orders o ON c.customerNumber = o.customerNumber WHERE orderNumber IS NULL;")
# Out:
#     customerNumber                    customerName orderNumber status
# 0              125              Havel & Zbyszek Co        None   None
# 1              168          American Souvenirs Inc        None   None
# 2              169               Porto Imports Co.        None   None
# 3              206      Asian Shopping Network, Co        None   None
# 4              223                 Natürlich Autos        None   None
# 5              237                   ANG Resellers        None   None
# 6              247        Messner Shopping Network        None   None
# 7              273               Franken Gifts, Co        None   None
# 8              293               BG&E Collectables        None   None
# 9              303                Schuyler Imports        None   None
# 10             307                Der Hund Imports        None   None
# 11             335       Cramer Spezialitäten, Ltd        None   None
# 12             348           Asian Treasures, Inc.        None   None
# 13             356            SAR Distributors, Co        None   None
# 14             361                 Kommission Auto        None   None
# 15             369          Lisboa Souveniers, Inc        None   None
# 16             376           Precious Collectables        None   None
# 17             409  Stuttgart Collectable Exchange        None   None
# 18             443        Feuer Online Stores, Inc        None   None
# 19             459                Warburg Exchange        None   None
# 20             465             Anton Designs, Ltd.        None   None
# 21             477             Mit Vergnügen & Co.        None   None
# 22             480       Kremlin Collectables, Co.        None   None
# 23             481              Raanan Stores, Inc        None   None

# %%
runSELECT("SELECT lastName, firstName, customerName, checkNumber, amount FROM employees LEFT JOIN customers ON employeeNumber = salesRepEmployeeNumber LEFT JOIN payments ON payments.customerNumber = customers.customerNumber ORDER BY customerName, checkNumber;")
# Out:
#       lastName firstName                 customerName checkNumber    amount
# 0       Murphy     Diane                         None        None       NaN
# 1          Bow   Anthony                         None        None       NaN
# 2         King       Tom                         None        None       NaN
# 3       Bondur    Gerard                         None        None       NaN
# 4    Patterson   William                         None        None       NaN
# ..         ...       ...                          ...         ...       ...
# 278      Tseng  Foon Yue              Vitachrome Inc.    OH367219  44400.50
# 279      Jones     Barry     Volvo Model Replicas, Co    IR846303  36005.71
# 280      Jones     Barry     Volvo Model Replicas, Co    LA685678   7674.94
# 281   Thompson    Leslie  West Coast Collectables Co.    JP113227   7678.25
# 282   Thompson    Leslie  West Coast Collectables Co.    PB951268  36070.47
#
# [283 rows x 5 columns]

# %%
runSELECT("SELECT o.orderNumber, customerNumber, productCode FROM orders o LEFT JOIN products ON orderNumber WHERE orderNumber = 10123;")
# Out:
#      orderNumber  customerNumber productCode
# 0          10123             103    S10_1949
# 1          10123             103    S10_4757
# 2          10123             103    S10_4962
# 3          10123             103    S12_1099
# 4          10123             103    S12_1108
# ..           ...             ...         ...
# 105        10123             103    S24_3816
# 106        10123             103    S24_3969
# 107        10123             103    S24_4258
# 108        10123             103    S32_4289
# 109        10123             103    S50_1341
#
# [110 rows x 3 columns]

# %%
runSELECT("SELECT o.orderNumber, customerNumber, productCode FROM orders o LEFT JOIN products d ON orderNumber AND o.orderNumber = 10123;")
# Out:
#      orderNumber  customerNumber productCode
# 0          10123             103    S10_1949
# 1          10123             103    S10_4757
# 2          10123             103    S10_4962
# 3          10123             103    S12_1099
# 4          10123             103    S12_1108
# ..           ...             ...         ...
# 430        10243             495        None
# 431        10138             496        None
# 432        10179             496        None
# 433        10360             496        None
# 434        10399             496        None
#
# [435 rows x 3 columns]

# %% [markdown]
# RIGHT JOIN

# %%
runSELECT("SELECT employeeNumber, customerNumber FROM customers RIGHT JOIN employees ON salesRepEmployeeNumber = employeeNumber ORDER BY employeeNumber;")
# Out:
#      employeeNumber  customerNumber
# 0              1002             NaN
# 1              1056             NaN
# 2              1076             NaN
# 3              1088             NaN
# 4              1102             NaN
# ..              ...             ...
# 103            1702           298.0
# 104            1702           344.0
# 105            1702           376.0
# 106            1702           458.0
# 107            1702           484.0
#
# [108 rows x 2 columns]

# %%
runSELECT("SELECT employeeNumber, customerNumber FROM customers RIGHT JOIN employees ON salesRepEmployeeNumber = employeeNumber WHERE customerNumber is NULL ORDER BY employeeNumber;")
# Out:
#    employeeNumber customerNumber
# 0            1002           None
# 1            1056           None
# 2            1076           None
# 3            1088           None
# 4            1102           None
# 5            1143           None
# 6            1619           None
# 7            1625           None

# %% [markdown]
# CROSS JOIN

# %%
runCMD("CREATE DATABASE IF NOT EXISTS salesdb;")
# Out:
# 1

# %%
runCMD("USE salesdb;")
# Out:
# 0

# %%
runCMD("CREATE TABLE IF NOT EXISTS products (\
    id INT PRIMARY KEY AUTO_INCREMENT,\
    product_name VARCHAR(100),\
    price DECIMAL(13,2 )\
);")
# Out:
# 0

# %%
runCMD("CREATE TABLE stores (\
    id INT PRIMARY KEY AUTO_INCREMENT,\
    store_name VARCHAR(100)\
);")
# Out:
# 0

# %%
runCMD("CREATE TABLE sales1 (product_id INT,store_id INT,quantity DECIMAL(13,2) NOT NULL,sales_date DATE NOT NULL,PRIMARY KEY (product_id , store_id),FOREIGN KEY (product_id) REFERENCES products (id) ON DELETE CASCADE ON UPDATE CASCADE,FOREIGN KEY (store_id) REFERENCES stores (id) ON DELETE CASCADE ON UPDATE CASCADE);")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-452-0e52b89b1f4a> in <module>()
# ----> 1 runCMD("CREATE TABLE sales1 (product_id INT,store_id INT,quantity DECIMAL(13,2) NOT NULL,sales_date DATE NOT NULL,PRIMARY KEY (product_id , store_id),FOREIGN KEY (product_id) REFERENCES products (id) ON DELETE CASCADE ON UPDATE CASCADE,FOREIGN KEY (store_id) REFERENCES stores (id) ON DELETE CASCADE ON UPDATE CASCADE);")
#
# <ipython-input-18-d9b7a40ed863> in runCMD(DDL)
#       4     DBConn= MySQLdb.connect(db='classicmodels')  # since local MySQL server, userid, password not needed
#       5     myCursor = DBConn.cursor()
# ----> 6     retcode = myCursor.execute(DDL)
#       7     print (retcode)
#       8     DBConn.commit()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     317         db = self._get_db()
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#     321         self._post_get_result()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     252         if isinstance(query, bytearray):
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#     256     def _bytes_literal(self, bs):
#
# IntegrityError: (1215, 'Cannot add foreign key constraint')

# %%
runCMD("INSERT INTO products(productCode,productName, buyPrice)\
VALUES(S10_1678,'iPhone', 699),\
      ('S10_1679',iPad',599),\
      ('S10_1678','Macbook Pro',1299);")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-182-2d7e59a42960> in <module>()
# ----> 1 runCMD("INSERT INTO products(productCode,productName, buyPrice)VALUES(S10_1678,'iPhone', 699),      ('S10_1679',iPad',599),      ('S10_1678','Macbook Pro',1299);")
#
# <ipython-input-18-d9b7a40ed863> in runCMD(DDL)
#       4     DBConn= MySQLdb.connect(db='classicmodels')  # since local MySQL server, userid, password not needed
#       5     myCursor = DBConn.cursor()
# ----> 6     retcode = myCursor.execute(DDL)
#       7     print (retcode)
#       8     DBConn.commit()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     317         db = self._get_db()
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#     321         self._post_get_result()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     252         if isinstance(query, bytearray):
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#     256     def _bytes_literal(self, bs):
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '',599),      ('S10_1678','Macbook Pro',1299)' at line 1")

# %%
runCMD("INSERT INTO stores(store_name)\
VALUES('North'),\
      ('South');")
# Out:
# 2

# %%
runCMD("INSERT INTO sales(store_id,product_id,quantity,sales_date)\
VALUES(1,1,20,'2017-01-02'),\
      (1,2,15,'2017-01-05'),\
      (1,3,25,'2017-01-05'),\
      (2,1,30,'2017-01-02'),\
      (2,2,35,'2017-01-05');")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-451-7bc3214149c1> in <module>()
# ----> 1 runCMD("INSERT INTO sales(store_id,product_id,quantity,sales_date)VALUES(1,1,20,'2017-01-02'),      (1,2,15,'2017-01-05'),      (1,3,25,'2017-01-05'),      (2,1,30,'2017-01-02'),      (2,2,35,'2017-01-05');")
#
# <ipython-input-18-d9b7a40ed863> in runCMD(DDL)
#       4     DBConn= MySQLdb.connect(db='classicmodels')  # since local MySQL server, userid, password not needed
#       5     myCursor = DBConn.cursor()
# ----> 6     retcode = myCursor.execute(DDL)
#       7     print (retcode)
#       8     DBConn.commit()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     317         db = self._get_db()
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#     321         self._post_get_result()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     252         if isinstance(query, bytearray):
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#     256     def _bytes_literal(self, bs):
#
# OperationalError: (1054, "Unknown column 'store_id' in 'field list'")

# %%
runSELECT("SELECT\
    store_name,\
    product_name,\
    SUM(quantity * price) AS revenue\
FROM\
    sales\
        INNER JOIN\
    products ON products.id = sales.product_id\
        INNER JOIN\
    stores ON stores.id = sales.store_id\
    GROUP BY store_name , product_name;")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'sales        INNER JOIN    products ON products.id = sales.product_id        INN' at line 1")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-185-8fdcc2db6722> in <module>()
# ----> 1 runSELECT("SELECT    store_name,    product_name,    SUM(quantity * price) AS revenueFROM    sales        INNER JOIN    products ON products.id = sales.product_id        INNER JOIN    stores ON stores.id = sales.store_id    GROUP BY store_name , product_name;")
#
# <ipython-input-18-d9b7a40ed863> in runSELECT(CMD)
#      13     #DBConn= MySQLdb.connect(hostName,userName,passWord,dbName)
#      14     DBConn= MySQLdb.connect(db='classicmodels') # since local MySQL server, userid, password not needed
# ---> 15     df_mysql = pd.read_sql(CMD, con=DBConn)
#      16     DBConn.close()
#      17     return df_mysql
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     606             coerce_float=coerce_float,
#     607             parse_dates=parse_dates,
# --> 608             chunksize=chunksize,
#     609         )
#     610
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2114
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT    store_name,    product_name,    SUM(quantity * price) AS revenueFROM    sales        INNER JOIN    products ON products.id = sales.product_id        INNER JOIN    stores ON stores.id = sales.store_id    GROUP BY store_name , product_name;': (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'sales        INNER JOIN    products ON products.id = sales.product_id        INN' at line 1")

# %%
runSELECT("SELECT store_name, productName FROM stores AS a CROSS JOIN products AS b;")
# Out:
#     store_name                            productName
# 0        North  1969 Harley Davidson Ultimate Chopper
# 1        South  1969 Harley Davidson Ultimate Chopper
# 2        North               1952 Alpine Renault 1300
# 3        South               1952 Alpine Renault 1300
# 4        North                  1996 Moto Guzzi 1100i
# ..         ...                                    ...
# 215      South              American Airlines: MD-11S
# 216      North                       Boeing X-32A JSF
# 217      South                       Boeing X-32A JSF
# 218      North                             Pont Yacht
# 219      South                             Pont Yacht
#
# [220 rows x 2 columns]

# %%
runSELECT("SELECT b.store_name,\
    a.product_name,\
    IFNULL(c.revenue, 0) AS revenue\
FROM\
    products AS a\
        CROSS JOIN\
    stores AS b\
        LEFT JOIN\
    (SELECT\
        stores.id AS store_id,\
        products.id AS product_id,\
        store_name,\
            product_name,\
            ROUND(SUM(quantity * price), 0) AS revenue\
    FROM\
        sales\
    INNER JOIN products ON products.id = sales.product_id\
    INNER JOIN stores ON stores.id = sales.store_id\
    GROUP BY stores.id, products.id, store_name , product_name) AS c ON c.store_id = b.id\
        AND c.product_id= a.id\
ORDER BY b.store_name;")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'products AS a        CROSS JOIN    stores AS b        LEFT JOIN    (SELECT      ' at line 1")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-447-08790469da22> in <module>()
# ----> 1 runSELECT("SELECT b.store_name,    a.product_name,    IFNULL(c.revenue, 0) AS revenueFROM    products AS a        CROSS JOIN    stores AS b        LEFT JOIN    (SELECT        stores.id AS store_id,        products.id AS product_id,        store_name,            product_name,            ROUND(SUM(quantity * price), 0) AS revenue    FROM        sales    INNER JOIN products ON products.id = sales.product_id    INNER JOIN stores ON stores.id = sales.store_id    GROUP BY stores.id, products.id, store_name , product_name) AS c ON c.store_id = b.id        AND c.product_id= a.idORDER BY b.store_name;")
#
# <ipython-input-18-d9b7a40ed863> in runSELECT(CMD)
#      13     #DBConn= MySQLdb.connect(hostName,userName,passWord,dbName)
#      14     DBConn= MySQLdb.connect(db='classicmodels') # since local MySQL server, userid, password not needed
# ---> 15     df_mysql = pd.read_sql(CMD, con=DBConn)
#      16     DBConn.close()
#      17     return df_mysql
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     606             coerce_float=coerce_float,
#     607             parse_dates=parse_dates,
# --> 608             chunksize=chunksize,
#     609         )
#     610
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2114
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT b.store_name,    a.product_name,    IFNULL(c.revenue, 0) AS revenueFROM    products AS a        CROSS JOIN    stores AS b        LEFT JOIN    (SELECT        stores.id AS store_id,        products.id AS product_id,        store_name,            product_name,            ROUND(SUM(quantity * price), 0) AS revenue    FROM        sales    INNER JOIN products ON products.id = sales.product_id    INNER JOIN stores ON stores.id = sales.store_id    GROUP BY stores.id, products.id, store_name , product_name) AS c ON c.store_id = b.id        AND c.product_id= a.idORDER BY b.store_name;': (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'products AS a        CROSS JOIN    stores AS b        LEFT JOIN    (SELECT      ' at line 1")

# %% [markdown]
# SELF JOIN

# %%
runSELECT("SELECT CONCAT(m.lastname,', ',m.firstname) AS 'Manager', CONCAT(e.lastname,', ',e.firstname) AS 'Direct report' FROM employees e INNER JOIN employees m ON m.employeeNumber = e.reportsto ORDER BY manager")
# Out:
#                Manager       Direct report
# 0       Bondur, Gerard        Bondur, Loui
# 1       Bondur, Gerard      Gerard, Martin
# 2       Bondur, Gerard        Jones, Barry
# 3       Bondur, Gerard         Bott, Larry
# 4       Bondur, Gerard    Castillo, Pamela
# 5       Bondur, Gerard   Hernandez, Gerard
# 6         Bow, Anthony    Jennings, Leslie
# 7         Bow, Anthony      Vanauf, George
# 8         Bow, Anthony     Tseng, Foon Yue
# 9         Bow, Anthony    Patterson, Steve
# 10        Bow, Anthony     Firrelli, Julie
# 11        Bow, Anthony    Thompson, Leslie
# 12       Murphy, Diane     Patterson, Mary
# 13       Murphy, Diane      Firrelli, Jeff
# 14         Nishi, Mami       Kato, Yoshimi
# 15     Patterson, Mary        Bow, Anthony
# 16     Patterson, Mary      Bondur, Gerard
# 17     Patterson, Mary         Nishi, Mami
# 18     Patterson, Mary  Patterson, William
# 19  Patterson, William        Fixter, Andy
# 20  Patterson, William           King, Tom
# 21  Patterson, William        Marsh, Peter

# %%
runSELECT("SELECT IFNULL(CONCAT(m.lastname, ', ', m.firstname), 'Top Manager') AS 'Manager', CONCAT(e.lastname, ', ', e.firstname) AS 'Direct report' FROM employees e LEFT JOIN employees m ON m.employeeNumber = e.reportsto ORDER BY manager DESC")
# Out:
#                Manager       Direct report
# 0          Top Manager       Murphy, Diane
# 1   Patterson, William           King, Tom
# 2   Patterson, William        Marsh, Peter
# 3   Patterson, William        Fixter, Andy
# 4      Patterson, Mary        Bow, Anthony
# 5      Patterson, Mary         Nishi, Mami
# 6      Patterson, Mary      Bondur, Gerard
# 7      Patterson, Mary  Patterson, William
# 8          Nishi, Mami       Kato, Yoshimi
# 9        Murphy, Diane      Firrelli, Jeff
# 10       Murphy, Diane     Patterson, Mary
# 11        Bow, Anthony    Jennings, Leslie
# 12        Bow, Anthony      Vanauf, George
# 13        Bow, Anthony     Tseng, Foon Yue
# 14        Bow, Anthony    Patterson, Steve
# 15        Bow, Anthony     Firrelli, Julie
# 16        Bow, Anthony    Thompson, Leslie
# 17      Bondur, Gerard      Gerard, Martin
# 18      Bondur, Gerard        Jones, Barry
# 19      Bondur, Gerard         Bott, Larry
# 20      Bondur, Gerard    Castillo, Pamela
# 21      Bondur, Gerard   Hernandez, Gerard
# 22      Bondur, Gerard        Bondur, Loui

# %%
runSELECT("SELECT c1.city, c1.customerName, c2.customerName FROM customers c1 INNER JOIN customers c2 ON c1.city = c2.city AND c1.customername <> c2.customerName ORDER BY c1.city;")
# Out:
#           city                customerName                customerName
# 0     Auckland             GiftsForHim.com  Down Under Souveniers, Inc
# 1   Auckland    Down Under Souveniers, Inc             GiftsForHim.com
# 2     Auckland             GiftsForHim.com           Kelly's Gift Shop
# 3   Auckland             Kelly's Gift Shop  Down Under Souveniers, Inc
# 4   Auckland             Kelly's Gift Shop             GiftsForHim.com
# ..         ...                         ...                         ...
# 81   Singapore  Asian Shopping Network, Co     Dragon Souveniers, Ltd.
# 82   Singapore     Dragon Souveniers, Ltd.            Handji Gifts& Co
# 83   Singapore            Handji Gifts& Co  Asian Shopping Network, Co
# 84   Singapore            Handji Gifts& Co     Dragon Souveniers, Ltd.
# 85   Singapore     Dragon Souveniers, Ltd.  Asian Shopping Network, Co
#
# [86 rows x 3 columns]

# %% [markdown]
# # SECTION 5: GROUPING DATA

# %% [markdown]
# GROUP BY

# %%
runSELECT("SELECT status FROM orders GROUP BY status;")
# Out:
#        status
# 0   Cancelled
# 1    Disputed
# 2  In Process
# 3     On Hold
# 4    Resolved
# 5     Shipped

# %%
runSELECT("SELECT DISTINCT status FROM orders;")
# Out:
#        status
# 0     Shipped
# 1    Resolved
# 2   Cancelled
# 3     On Hold
# 4    Disputed
# 5  In Process

# %%
runSELECT("SELECT status, COUNT(*) FROM orders GROUP BY status;")
# Out:
#        status  COUNT(*)
# 0   Cancelled         6
# 1    Disputed         3
# 2  In Process         6
# 3     On Hold         4
# 4    Resolved         4
# 5     Shipped       303

# %%
runSELECT("SELECT status, SUM(quantityOrdered * priceEach) AS amount FROM orders INNER JOIN orderdetails USING(orderNumber) GROUP BY status;")
# Out:
#        status      amount
# 0   Cancelled   238854.18
# 1    Disputed    61158.78
# 2  In Process   135271.52
# 3     On Hold   169575.61
# 4    Resolved   134235.88
# 5     Shipped  8865094.64

# %%
runSELECT("SELECT orderNumber, SUM(quantityOrdered * priceEach) AS total FROM orderdetails GROUP BY orderNumber;")
# Out:
#      orderNumber     total
# 0          10100  10223.83
# 1          10101  10549.01
# 2          10102   5494.78
# 3          10103  50218.95
# 4          10104  40206.20
# ..           ...       ...
# 321        10421   7639.10
# 322        10422   5849.44
# 323        10423   8597.73
# 324        10424  29310.30
# 325        10425  41623.44
#
# [326 rows x 2 columns]

# %%
runSELECT("SELECT YEAR(orderDate) AS year, SUM(quantityOrdered * priceEach) AS total FROM orders INNER JOIN orderdetails USING(orderNumber) WHERE status = 'Shipped' GROUP BY YEAR(orderDate);")
# Out:
#    year       total
# 0  2003  3223095.80
# 1  2004  4300602.99
# 2  2005  1341395.85

# %%
runSELECT("SELECT YEAR(orderDate) AS year, SUM(quantityOrdered * priceEach) AS total FROM orders INNER JOIN orderdetails USING(orderNumber) WHERE status = 'Shipped' GROUP BY year HAVING year > 2003;")
# Out:
#    year       total
# 0  2004  4300602.99
# 1  2005  1341395.85

# %%
runSELECT("SELECT YEAR(orderDate) AS year, COUNT(orderNumber) FROM orders GROUP BY year;")
# Out:
#    year  COUNT(orderNumber)
# 0  2003                 111
# 1  2004                 151
# 2  2005                  64

# %%
runSELECT("SELECT status, COUNT(*) FROM orders GROUP BY status DESC;")
# Out:
#        status  COUNT(*)
# 0     Shipped       303
# 1    Resolved         4
# 2     On Hold         4
# 3  In Process         6
# 4    Disputed         3
# 5   Cancelled         6

# %%
runSELECT("SELECT state FROM customers GROUP BY state;")
# Out:
#             state
# 0            None
# 1              BC
# 2              CA
# 3        Co. Cork
# 4              CT
# 5   Isle of Wight
# 6              MA
# 7              NH
# 8              NJ
# 9             NSW
# 10             NV
# 11             NY
# 12          Osaka
# 13             PA
# 14       Pretoria
# 15         Québec
# 16     Queensland
# 17          Tokyo
# 18       Victoria

# %%
runSELECT("SELECT DISTINCT state FROM customers;")
# Out:
#             state
# 0            None
# 1              NV
# 2        Victoria
# 3              CA
# 4              NY
# 5              PA
# 6              CT
# 7              MA
# 8           Osaka
# 9              BC
# 10         Québec
# 11  Isle of Wight
# 12            NSW
# 13             NJ
# 14     Queensland
# 15       Co. Cork
# 16       Pretoria
# 17             NH
# 18          Tokyo

# %%
runSELECT("SELECT DISTINCT state FROM customers ORDER BY state;")
# Out:
#             state
# 0            None
# 1              BC
# 2              CA
# 3        Co. Cork
# 4              CT
# 5   Isle of Wight
# 6              MA
# 7              NH
# 8              NJ
# 9             NSW
# 10             NV
# 11             NY
# 12          Osaka
# 13             PA
# 14       Pretoria
# 15         Québec
# 16     Queensland
# 17          Tokyo
# 18       Victoria

# %% [markdown]
# HAVING

# %%
runSELECT("SELECT ordernumber, SUM(quantityOrdered) AS itemsCount, SUM(quantityOrdered*priceeach) AS total FROM orderdetails GROUP BY ordernumber;")
# Out:
#      ordernumber  itemsCount     total
# 0          10100       151.0  10223.83
# 1          10101       142.0  10549.01
# 2          10102        80.0   5494.78
# 3          10103       541.0  50218.95
# 4          10104       443.0  40206.20
# ..           ...         ...       ...
# 321        10421        75.0   7639.10
# 322        10422        76.0   5849.44
# 323        10423       111.0   8597.73
# 324        10424       269.0  29310.30
# 325        10425       427.0  41623.44
#
# [326 rows x 3 columns]

# %%
runSELECT("SELECT ordernumber, SUM(quantityOrdered) AS itemsCount, SUM(quantityOrdered*priceeach) AS total FROM orderdetails GROUP BY ordernumber HAVING total > 1000;")
# Out:
#      ordernumber  itemsCount     total
# 0          10100       151.0  10223.83
# 1          10101       142.0  10549.01
# 2          10102        80.0   5494.78
# 3          10103       541.0  50218.95
# 4          10104       443.0  40206.20
# ..           ...         ...       ...
# 320        10421        75.0   7639.10
# 321        10422        76.0   5849.44
# 322        10423       111.0   8597.73
# 323        10424       269.0  29310.30
# 324        10425       427.0  41623.44
#
# [325 rows x 3 columns]

# %%
runSELECT("SELECT ordernumber, SUM(quantityOrdered) AS itemsCount, SUM(quantityOrdered*priceeach) AS total FROM orderdetails GROUP BY ordernumber HAVING total > 1000 AND itemsCount > 600;")
# Out:
#     ordernumber  itemsCount     total
# 0         10106       675.0  52151.81
# 1         10126       617.0  57131.92
# 2         10135       607.0  55601.84
# 3         10165       670.0  67392.85
# 4         10168       642.0  50743.65
# 5         10204       619.0  58793.53
# 6         10207       615.0  59265.14
# 7         10212       612.0  59830.55
# 8         10222       717.0  56822.65
# 9         10262       605.0  47065.36
# 10        10275       601.0  47924.19
# 11        10310       619.0  61234.67
# 12        10312       601.0  55639.66
# 13        10316       623.0  46788.14
# 14        10332       621.0  47159.11
# 15        10339       614.0  48927.64
# 16        10360       620.0  52166.00
# 17        10373       605.0  46770.52
# 18        10386       650.0  46968.52
# 19        10390       603.0  55902.50
# 20        10398       629.0  46656.94
# 21        10414       609.0  50806.85

# %%
runSELECT("SELECT a.ordernumber, status, SUM(priceeach*quantityOrdered) total FROM orderdetails a INNER JOIN orders b ON b.ordernumber = a.ordernumber GROUP BY ordernumber, status HAVING status = 'Shipped' AND total > 1500;")
# Out:
#      ordernumber   status     total
# 0          10100  Shipped  10223.83
# 1          10101  Shipped  10549.01
# 2          10102  Shipped   5494.78
# 3          10103  Shipped  50218.95
# 4          10104  Shipped  40206.20
# ..           ...      ...       ...
# 295        10412  Shipped  46895.48
# 296        10413  Shipped  28500.78
# 297        10416  Shipped  35362.26
# 298        10418  Shipped  23627.44
# 299        10419  Shipped  52420.07
#
# [300 rows x 3 columns]

# %% [markdown]
# ROLLUP

# %%
runCMD("CREATE TABLE IF NOT EXISTS sales SELECT productLine,YEAR(orderDate) orderYear,SUM(quantityOrdered * priceEach) orderValue FROM orderdetails INNER JOIN orders USING (orderNumber) INNER JOIN products USING (productCode) GROUP BY productLine,YEAR(orderDate);")
# Out:
# 21

# %%
runSELECT("SELECT * FROM sales;")
# Out:
#          productLine  orderYear  orderValue
# 0       Classic Cars       2003  1374832.22
# 1       Classic Cars       2004  1763136.73
# 2       Classic Cars       2005   715953.54
# 3        Motorcycles       2003   348909.24
# 4        Motorcycles       2004   527243.84
# 5        Motorcycles       2005   245273.04
# 6             Planes       2003   309784.20
# 7             Planes       2004   471971.46
# 8             Planes       2005   172881.88
# 9              Ships       2003   222182.08
# 10             Ships       2004   337326.10
# 11             Ships       2005   104490.16
# 12            Trains       2003    65822.05
# 13            Trains       2004    96285.53
# 14            Trains       2005    26425.34
# 15  Trucks and Buses       2003   376657.12
# 16  Trucks and Buses       2004   465390.00
# 17  Trucks and Buses       2005   182066.45
# 18      Vintage Cars       2003   619161.48
# 19      Vintage Cars       2004   854551.85
# 20      Vintage Cars       2005   323846.30

# %%
runSELECT("SELECT productline,SUM(orderValue) totalOrderValue FROM sales GROUP BY productline;")
# Out:
#         productline  totalOrderValue
# 0      Classic Cars       3853922.49
# 1       Motorcycles       1121426.12
# 2            Planes        954637.54
# 3             Ships        663998.34
# 4            Trains        188532.92
# 5  Trucks and Buses       1024113.57
# 6      Vintage Cars       1797559.63

# %%
runSELECT("SELECT SUM(orderValue) totalOrderValue FROM sales;")
# Out:
#    totalOrderValue
# 0       9604190.61

# %%
runSELECT("SELECT productline, SUM(orderValue) totalOrderValue FROM sales GROUP BY productline UNION ALL SELECT NULL, SUM(orderValue) totalOrderValue FROM sales;")
# Out:
#         productline  totalOrderValue
# 0      Classic Cars       3853922.49
# 1       Motorcycles       1121426.12
# 2            Planes        954637.54
# 3             Ships        663998.34
# 4            Trains        188532.92
# 5  Trucks and Buses       1024113.57
# 6      Vintage Cars       1797559.63
# 7              None       9604190.61

# %%
runSELECT("SELECT productLine,SUM(orderValue) totalOrderValue FROM sales GROUP BY productline WITH ROLLUP;")
# Out:
#         productLine  totalOrderValue
# 0      Classic Cars       3853922.49
# 1       Motorcycles       1121426.12
# 2            Planes        954637.54
# 3             Ships        663998.34
# 4            Trains        188532.92
# 5  Trucks and Buses       1024113.57
# 6      Vintage Cars       1797559.63
# 7              None       9604190.61

# %%
runSELECT("SELECT productLine, orderYear,SUM(orderValue) totalOrderValue FROM sales GROUP BY productline, orderYear WITH ROLLUP;")
# Out:
#          productLine  orderYear  totalOrderValue
# 0       Classic Cars     2003.0       1374832.22
# 1       Classic Cars     2004.0       1763136.73
# 2       Classic Cars     2005.0        715953.54
# 3       Classic Cars        NaN       3853922.49
# 4        Motorcycles     2003.0        348909.24
# 5        Motorcycles     2004.0        527243.84
# 6        Motorcycles     2005.0        245273.04
# 7        Motorcycles        NaN       1121426.12
# 8             Planes     2003.0        309784.20
# 9             Planes     2004.0        471971.46
# 10            Planes     2005.0        172881.88
# 11            Planes        NaN        954637.54
# 12             Ships     2003.0        222182.08
# 13             Ships     2004.0        337326.10
# 14             Ships     2005.0        104490.16
# 15             Ships        NaN        663998.34
# 16            Trains     2003.0         65822.05
# 17            Trains     2004.0         96285.53
# 18            Trains     2005.0         26425.34
# 19            Trains        NaN        188532.92
# 20  Trucks and Buses     2003.0        376657.12
# 21  Trucks and Buses     2004.0        465390.00
# 22  Trucks and Buses     2005.0        182066.45
# 23  Trucks and Buses        NaN       1024113.57
# 24      Vintage Cars     2003.0        619161.48
# 25      Vintage Cars     2004.0        854551.85
# 26      Vintage Cars     2005.0        323846.30
# 27      Vintage Cars        NaN       1797559.63
# 28              None        NaN       9604190.61

# %%
runSELECT("SELECT orderYear,productLine,SUM(orderValue) totalOrderValue FROM sales GROUP BY orderYear, productline WITH ROLLUP;")
# Out:
#     orderYear       productLine  totalOrderValue
# 0      2003.0      Classic Cars       1374832.22
# 1      2003.0       Motorcycles        348909.24
# 2      2003.0            Planes        309784.20
# 3      2003.0             Ships        222182.08
# 4      2003.0            Trains         65822.05
# 5      2003.0  Trucks and Buses        376657.12
# 6      2003.0      Vintage Cars        619161.48
# 7      2003.0              None       3317348.39
# 8      2004.0      Classic Cars       1763136.73
# 9      2004.0       Motorcycles        527243.84
# 10     2004.0            Planes        471971.46
# 11     2004.0             Ships        337326.10
# 12     2004.0            Trains         96285.53
# 13     2004.0  Trucks and Buses        465390.00
# 14     2004.0      Vintage Cars        854551.85
# 15     2004.0              None       4515905.51
# 16     2005.0      Classic Cars        715953.54
# 17     2005.0       Motorcycles        245273.04
# 18     2005.0            Planes        172881.88
# 19     2005.0             Ships        104490.16
# 20     2005.0            Trains         26425.34
# 21     2005.0  Trucks and Buses        182066.45
# 22     2005.0      Vintage Cars        323846.30
# 23     2005.0              None       1770936.71
# 24        NaN              None       9604190.61

# %%
runSELECT("SELECT orderYear,productLine, SUM(orderValue) totalOrderValue,GROUPING(orderYear),GROUPING(productLine) FROM sales GROUP BY orderYear,productline WITH ROLLUP;")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#
# OperationalError: (1305, 'FUNCTION classicmodels.GROUPING does not exist')
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-445-13628185c42b> in <module>()
# ----> 1 runSELECT("SELECT orderYear,productLine, SUM(orderValue) totalOrderValue,GROUPING(orderYear),GROUPING(productLine) FROM sales GROUP BY orderYear,productline WITH ROLLUP;")
#
# <ipython-input-18-d9b7a40ed863> in runSELECT(CMD)
#      13     #DBConn= MySQLdb.connect(hostName,userName,passWord,dbName)
#      14     DBConn= MySQLdb.connect(db='classicmodels') # since local MySQL server, userid, password not needed
# ---> 15     df_mysql = pd.read_sql(CMD, con=DBConn)
#      16     DBConn.close()
#      17     return df_mysql
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     606             coerce_float=coerce_float,
#     607             parse_dates=parse_dates,
# --> 608             chunksize=chunksize,
#     609         )
#     610
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2114
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT orderYear,productLine, SUM(orderValue) totalOrderValue,GROUPING(orderYear),GROUPING(productLine) FROM sales GROUP BY orderYear,productline WITH ROLLUP;': (1305, 'FUNCTION classicmodels.GROUPING does not exist')

# %%
runSELECT("SELECT IF(GROUPING(orderYear),'All Years',orderYear) orderYear,IF(GROUPING(productLine),'All Product Lines',productLine) productLine,SUM(orderValue) totalOrderValue FROM sales GROUP BY orderYear , productline WITH ROLLUP;")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#
# OperationalError: (1305, 'FUNCTION classicmodels.GROUPING does not exist')
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-444-05cf6e0a7dce> in <module>()
# ----> 1 runSELECT("SELECT IF(GROUPING(orderYear),'All Years',orderYear) orderYear,IF(GROUPING(productLine),'All Product Lines',productLine) productLine,SUM(orderValue) totalOrderValue FROM sales GROUP BY orderYear , productline WITH ROLLUP;")
#
# <ipython-input-18-d9b7a40ed863> in runSELECT(CMD)
#      13     #DBConn= MySQLdb.connect(hostName,userName,passWord,dbName)
#      14     DBConn= MySQLdb.connect(db='classicmodels') # since local MySQL server, userid, password not needed
# ---> 15     df_mysql = pd.read_sql(CMD, con=DBConn)
#      16     DBConn.close()
#      17     return df_mysql
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     606             coerce_float=coerce_float,
#     607             parse_dates=parse_dates,
# --> 608             chunksize=chunksize,
#     609         )
#     610
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2114
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT IF(GROUPING(orderYear),'All Years',orderYear) orderYear,IF(GROUPING(productLine),'All Product Lines',productLine) productLine,SUM(orderValue) totalOrderValue FROM sales GROUP BY orderYear , productline WITH ROLLUP;': (1305, 'FUNCTION classicmodels.GROUPING does not exist')

# %% [markdown]
# # Section 6: Subqueries

# %% [markdown]
# SUBQUERY

# %%
runSELECT("SELECT lastName, firstName FROM  employees WHERE officeCode IN (SELECT officeCode FROM offices WHERE country = 'USA');")
# Out:
#     lastName firstName
# 0     Murphy     Diane
# 1  Patterson      Mary
# 2   Firrelli      Jeff
# 3        Bow   Anthony
# 4   Jennings    Leslie
# 5   Thompson    Leslie
# 6   Firrelli     Julie
# 7  Patterson     Steve
# 8      Tseng  Foon Yue
# 9     Vanauf    George

# %%
runSELECT("SELECT customerNumber, checkNumber, amount FROM payments WHERE amount =( SELECT MAX(amount) FROM payments);")
# Out:
#    customerNumber checkNumber     amount
# 0             141    JE105477  120166.58

# %%
runSELECT("SELECT customerNumber, checkNumber, amount FROM payments WHERE amount >( SELECT AVG(amount) FROM payments);")
# Out:
#      customerNumber checkNumber    amount
# 0               112     HQ55022  32641.98
# 1               112    ND748579  33347.88
# 2               114     GG31455  45864.03
# 3               114    MA765515  82261.22
# 4               114     NR27552  44894.74
# ..              ...         ...       ...
# 129             475    PB951268  36070.47
# 130             484    JH546765  47513.19
# 131             486     HS86661  45994.07
# 132             495    BH167026  59265.14
# 133             496     MN89921  52166.00
#
# [134 rows x 3 columns]

# %%
runSELECT("SELECT customername FROM customers WHERE customerNumber NOT IN( SELECT DISTINCT customernumber FROM orders);")
# Out:
#                       customername
# 0               Havel & Zbyszek Co
# 1           American Souvenirs Inc
# 2                Porto Imports Co.
# 3       Asian Shopping Network, Co
# 4                  Natürlich Autos
# 5                    ANG Resellers
# 6         Messner Shopping Network
# 7                Franken Gifts, Co
# 8                BG&E Collectables
# 9                 Schuyler Imports
# 10                Der Hund Imports
# 11       Cramer Spezialitäten, Ltd
# 12           Asian Treasures, Inc.
# 13            SAR Distributors, Co
# 14                 Kommission Auto
# 15          Lisboa Souveniers, Inc
# 16           Precious Collectables
# 17  Stuttgart Collectable Exchange
# 18        Feuer Online Stores, Inc
# 19                Warburg Exchange
# 20             Anton Designs, Ltd.
# 21             Mit Vergnügen & Co.
# 22       Kremlin Collectables, Co.
# 23              Raanan Stores, Inc

# %%
runSELECT("SELECT max(items), min(items), floor(avg(items)) FROM(SELECT orderNumber, count(orderNumber) AS items FROM orderdetails GROUP BY orderNumber) AS lineitems;")
# Out:
#    max(items)  min(items)  floor(avg(items))
# 0          18           1                9.0

# %%
runSELECT("SELECT orderNumber, COUNT(orderNumber) AS items FROM orderdetails GROUP BY orderNumber;")
# Out:
#      orderNumber  items
# 0          10100      4
# 1          10101      4
# 2          10102      2
# 3          10103     16
# 4          10104     13
# ..           ...    ...
# 321        10421      2
# 322        10422      2
# 323        10423      5
# 324        10424      6
# 325        10425     13
#
# [326 rows x 2 columns]

# %%
runSELECT("SELECT productname, buyprice FROM products AS p1 WHERE buyprice >( SELECT AVG(buyprice) FROM products WHERE productline = p1.productline)")
# Out:
#                                 productname  buyprice
# 0                  1952 Alpine Renault 1300     98.58
# 1                     1996 Moto Guzzi 1100i     68.99
# 2      2003 Harley-Davidson Eagle Drag Bike     91.02
# 3                       1972 Alfa Romeo GTA     85.68
# 4                    1962 LanciaA Delta 16V    103.42
# 5                         1968 Ford Mustang     95.34
# 6                         2001 Ferrari Enzo     95.59
# 7                            1958 Setra Bus     77.90
# 8                          2002 Suzuki XREO     66.27
# 9                        1969 Corvair Monza     89.14
# 10                       1968 Dodge Charger     75.16
# 11                         1969 Ford Falcon     83.05
# 12                   1940 Ford Pickup Truck     58.33
# 13                          1993 Mazda RX-7     83.51
# 14                     1937 Lincoln Berline     60.62
# 15                    1965 Aston Martin DB5     65.96
# 16              1980s Black Hawk Helicopter     77.27
# 17                 1917 Grand Touring Sedan     86.70
# 18                         1995 Honda Civic     93.89
# 19           1998 Chrysler Plymouth Prowler    101.51
# 20                   1964 Mercedes Tour Bus     74.86
# 21                1932 Model A Ford J-Coupe     58.48
# 22                   1928 Mercedes-Benz SSK     72.56
# 23              1913 Ford Model T Speedster     60.78
# 24                   1999 Yamaha Speed Boat     51.61
# 25      18th Century Vintage Horse Carriage     60.74
# 26                        1903 Ford Model A     68.30
# 27              1992 Ferrari 360 Spider red     77.90
# 28                 Collectable Wooden Train     67.56
# 29                 1917 Maxwell Touring Car     57.54
# 30                    1976 Ford Gran Torino     73.49
# 31  1941 Chevrolet Special Deluxe Cabriolet     64.58
# 32                    1970 Triumph Spitfire     91.92
# 33                      1904 Buick Runabout     52.66
# 34                         1940s Ford truck     84.76
# 35                1957 Corvette Convertible     69.93
# 36                        1997 BMW R 1100 S     60.86
# 37         1928 British Royal Navy Airplane     66.74
# 38                    18th century schooner     82.34
# 39                 1962 Volkswagen Microbus     61.34
# 40                        1952 Citroen-15CV     72.82
# 41         1912 Ford Model T Delivery Wagon     46.91
# 42                 1940 Ford Delivery Sedan     48.64
# 43                  1956 Porsche 356A Coupe     98.30
# 44        1992 Porsche Cayenne Turbo Silver     69.78
# 45                    1936 Chrysler Airflow     57.46
# 46                         1997 BMW F650 ST     66.92
# 47                1974 Ducati 350 Mk3 Desmo     56.13
# 48         Diamond T620 Semi-Skirted Tanker     68.29
# 49              American Airlines: B767-300     51.15
# 50           America West Airlines B757-200     68.80
# 51                            ATA: B757-300     59.33
# 52                       F/A 18 Hornet 1/72     54.40
# 53                              The Titanic     51.09
# 54                           The Queen Mary     53.63

# %%
runSELECT("SELECT orderNumber, SUM(priceEach * quantityOrdered) total FROM orderdetails INNER JOIN orders USING (orderNumber) GROUP BY orderNumber HAVING SUM(priceEach * quantityOrdered) > 60000;")
# Out:
#    orderNumber     total
# 0        10165  67392.85
# 1        10287  61402.00
# 2        10310  61234.67

# %%
runSELECT("SELECT customerNumber, customerName FROM customers WHERE EXISTS( SELECT orderNumber, SUM(priceEach * quantityOrdered) FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE customerNumber = customers.customerNumber GROUP BY orderNumber HAVING SUM(priceEach * quantityOrdered) > 60000);")
# Out:
#    customerNumber             customerName
# 0             148  Dragon Souveniers, Ltd.
# 1             259  Toms Spezialitäten, Ltd
# 2             298          Vida Sport, Ltd

# %% [markdown]
# DERIVED TABLE

# %%
runSELECT("SELECT productCode, ROUND(SUM(quantityOrdered * priceEach)) sales FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY productCode ORDER BY sales DESC LIMIT 5;")
# Out:
#   productCode     sales
# 0    S18_3232  103480.0
# 1    S10_1949   67985.0
# 2    S12_1108   59852.0
# 3    S12_3891   57403.0
# 4    S12_1099   56462.0

# %%
runSELECT("SELECT productName, sales FROM (SELECT productCode, ROUND(SUM(quantityOrdered * priceEach)) sales FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY productCode ORDER BY sales DESC LIMIT 5) top5products2003 INNER JOIN products USING (productCode);")
# Out:
#                    productName     sales
# 0  1992 Ferrari 360 Spider red  103480.0
# 1     1952 Alpine Renault 1300   67985.0
# 2            2001 Ferrari Enzo   59852.0
# 3             1969 Ford Falcon   57403.0
# 4            1968 Ford Mustang   56462.0

# %%
runSELECT("SELECT customerNumber,ROUND(SUM(quantityOrdered * priceEach)) sales,(CASE WHEN SUM(quantityOrdered * priceEach) < 10000 THEN 'Silver' WHEN SUM(quantityOrdered * priceEach) BETWEEN 10000 AND 100000 THEN 'Gold' WHEN SUM(quantityOrdered * priceEach) > 100000 THEN 'Platinum'END) customerGroup FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY customerNumber;")
# Out:
#     customerNumber     sales customerGroup
# 0              103   14571.0          Gold
# 1              112   32642.0          Gold
# 2              114   53429.0          Gold
# 3              121   51710.0          Gold
# 4              124  167783.0      Platinum
# ..             ...       ...           ...
# 68             486   25833.0          Gold
# 69             487   29997.0          Gold
# 70             489   22276.0          Gold
# 71             495   59265.0          Gold
# 72             496   55041.0          Gold
#
# [73 rows x 3 columns]

# %%
runSELECT("SELECT customerNumber,ROUND(SUM(quantityOrdered * priceEach)) sales, (CASE WHEN SUM(quantityOrdered * priceEach) < 10000 THEN 'Silver'WHEN SUM(quantityOrdered * priceEach) BETWEEN 10000 AND 100000 THEN 'Gold' WHEN SUM(quantityOrdered * priceEach) > 100000 THEN 'Platinum' END) customerGroup FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY customerNumber;")
# Out:
#     customerNumber     sales customerGroup
# 0              103   14571.0          Gold
# 1              112   32642.0          Gold
# 2              114   53429.0          Gold
# 3              121   51710.0          Gold
# 4              124  167783.0      Platinum
# ..             ...       ...           ...
# 68             486   25833.0          Gold
# 69             487   29997.0          Gold
# 70             489   22276.0          Gold
# 71             495   59265.0          Gold
# 72             496   55041.0          Gold
#
# [73 rows x 3 columns]

# %%
runSELECT("SELECT customerGroup, COUNT(cg.customerGroup) AS groupCount FROM (SELECT customerNumber,ROUND(SUM(quantityOrdered * priceEach)) sales, (CASE WHEN SUM(quantityOrdered * priceEach) < 10000 THEN 'Silver'WHEN SUM(quantityOrdered * priceEach) BETWEEN 10000 AND 100000 THEN 'Gold' WHEN SUM(quantityOrdered * priceEach) > 100000 THEN 'Platinum' END) customerGroup FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY customerNumber) cg GROUP BY cg.customerGroup;")
# Out:
#   customerGroup  groupCount
# 0          Gold          61
# 1      Platinum           4
# 2        Silver           8

# %% [markdown]
# EXISTS

# %%
runSELECT("SELECT productCode, ROUND(SUM(quantityOrdered * priceEach)) sales FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY productCode ORDER BY sales DESC LIMIT 5;")
# Out:
#   productCode     sales
# 0    S18_3232  103480.0
# 1    S10_1949   67985.0
# 2    S12_1108   59852.0
# 3    S12_3891   57403.0
# 4    S12_1099   56462.0

# %%
runSELECT("SELECT productName, sales FROM (SELECT productCode, ROUND(SUM(quantityOrdered * priceEach)) sales FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY productCode ORDER BY sales DESC LIMIT 5) top5products2003 INNER JOIN products USING (productCode);")
# Out:
#                    productName     sales
# 0  1992 Ferrari 360 Spider red  103480.0
# 1     1952 Alpine Renault 1300   67985.0
# 2            2001 Ferrari Enzo   59852.0
# 3             1969 Ford Falcon   57403.0
# 4            1968 Ford Mustang   56462.0

# %%
runSELECT("SELECT customerNumber, ROUND(SUM(quantityOrdered * priceEach)) sales, (CASE WHEN SUM(quantityOrdered * priceEach) < 10000 THEN 'Silver' WHEN SUM(quantityOrdered * priceEach) BETWEEN 10000 AND 100000 THEN 'Gold' WHEN SUM(quantityOrdered * priceEach) > 100000 THEN 'Platinum' END) customerGroup FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY customerNumber;")
# Out:
#     customerNumber     sales customerGroup
# 0              103   14571.0          Gold
# 1              112   32642.0          Gold
# 2              114   53429.0          Gold
# 3              121   51710.0          Gold
# 4              124  167783.0      Platinum
# ..             ...       ...           ...
# 68             486   25833.0          Gold
# 69             487   29997.0          Gold
# 70             489   22276.0          Gold
# 71             495   59265.0          Gold
# 72             496   55041.0          Gold
#
# [73 rows x 3 columns]

# %%
runSELECT("SELECT customerGroup, COUNT(cg.customerGroup) AS groupCount FROM (SELECT customerNumber, ROUND(SUM(quantityOrdered * priceEach)) sales, (CASE WHEN SUM(quantityOrdered * priceEach) < 10000 THEN 'Silver' WHEN SUM(quantityOrdered * priceEach) BETWEEN 10000 AND 100000 THEN 'Gold' WHEN SUM(quantityOrdered * priceEach) > 100000 THEN 'Platinum' END) customerGroup FROM orderdetails INNER JOIN orders USING (orderNumber) WHERE YEAR(shippedDate) = 2003 GROUP BY customerNumber) cg GROUP BY cg.customerGroup;")
# Out:
#   customerGroup  groupCount
# 0          Gold          61
# 1      Platinum           4
# 2        Silver           8

# %%
runSELECT("SELECT customerNumber, customerName FROM customers WHERE EXISTS( SELECT 1 FROM orders WHERE orders.customernumber = customers.customernumber);")
# Out:
#     customerNumber                    customerName
# 0              103               Atelier graphique
# 1              112              Signal Gift Stores
# 2              114      Australian Collectors, Co.
# 3              119               La Rochelle Gifts
# 4              121              Baane Mini Imports
# ..             ...                             ...
# 93             486    Motor Mint Distributors Inc.
# 94             487        Signal Collectibles Ltd.
# 95             489  Double Decker Gift Stores, Ltd
# 96             495            Diecast Collectables
# 97             496               Kelly's Gift Shop
#
# [98 rows x 2 columns]

# %%
runSELECT("SELECT customerNumber, customerName FROM customers WHERE NOT EXISTS( SELECT 1 FROM orders WHERE orders.customernumber = customers.customernumber);")
# Out:
#     customerNumber                    customerName
# 0              125              Havel & Zbyszek Co
# 1              168          American Souvenirs Inc
# 2              169               Porto Imports Co.
# 3              206      Asian Shopping Network, Co
# 4              223                 Natürlich Autos
# 5              237                   ANG Resellers
# 6              247        Messner Shopping Network
# 7              273               Franken Gifts, Co
# 8              293               BG&E Collectables
# 9              303                Schuyler Imports
# 10             307                Der Hund Imports
# 11             335       Cramer Spezialitäten, Ltd
# 12             348           Asian Treasures, Inc.
# 13             356            SAR Distributors, Co
# 14             361                 Kommission Auto
# 15             369          Lisboa Souveniers, Inc
# 16             376           Precious Collectables
# 17             409  Stuttgart Collectable Exchange
# 18             443        Feuer Online Stores, Inc
# 19             459                Warburg Exchange
# 20             465             Anton Designs, Ltd.
# 21             477             Mit Vergnügen & Co.
# 22             480       Kremlin Collectables, Co.
# 23             481              Raanan Stores, Inc

# %%
runSELECT("SELECT employeenumber, firstname, lastname, extension FROM employees WHERE EXISTS( SELECT 1 FROM offices WHERE city = 'San Francisco' AND offices.officeCode = employees.officeCode);")
# Out:
#    employeenumber firstname   lastname extension
# 0            1002     Diane     Murphy     x5800
# 1            1056      Mary  Patterson     x4611
# 2            1076      Jeff   Firrelli     x9273
# 3            1143   Anthony        Bow     x5428
# 4            1165    Leslie   Jennings     x3291
# 5            1166    Leslie   Thompson     x4065

# %%
runSELECT("UPDATE employees SET extension = CONCAT(extension, '1') WHERE EXISTS(SELECT 1 FROM offices WHERE city = 'San Francisco' AND offices.officeCode = employees.officeCode);")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-241-9817c77b721b> in <module>()
# ----> 1 runSELECT("UPDATE employees SET extension = CONCAT(extension, '1') WHERE EXISTS(SELECT 1 FROM offices WHERE city = 'San Francisco' AND offices.officeCode = employees.officeCode);")
#
# <ipython-input-18-d9b7a40ed863> in runSELECT(CMD)
#      13     #DBConn= MySQLdb.connect(hostName,userName,passWord,dbName)
#      14     DBConn= MySQLdb.connect(db='classicmodels') # since local MySQL server, userid, password not needed
# ---> 15     df_mysql = pd.read_sql(CMD, con=DBConn)
#      16     DBConn.close()
#      17     return df_mysql
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     606             coerce_float=coerce_float,
#     607             parse_dates=parse_dates,
# --> 608             chunksize=chunksize,
#     609         )
#     610
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2115         args = _convert_params(sql, params)
#    2116         cursor = self.execute(*args)
# -> 2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#    2119         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
runCMD("CREATE TABLE customers_archive LIKE customers;")
# Out:
# 0

# %%
runCMD("INSERT INTO customers_archive SELECT * FROM customers WHERE NOT EXISTS(SELECT 1 FROM orders WHERE orders.customernumber = customers.customernumber);")
# Out:
# 24

# %%
runSELECT("SELECT * FROM customers_archive;")
# Out:
#     customerNumber                    customerName  contactLastName  \
# 0              125              Havel & Zbyszek Co  Piestrzeniewicz
# 1              168          American Souvenirs Inc           Franco
# 2              169               Porto Imports Co.        de Castro
# 3              206      Asian Shopping Network, Co           Walker
# 4              223                 Natürlich Autos            Kloss
# 5              237                   ANG Resellers           Camino
# 6              247        Messner Shopping Network          Messner
# 7              273               Franken Gifts, Co          Franken
# 8              293               BG&E Collectables         Harrison
# 9              303                Schuyler Imports         Schuyler
# 10             307                Der Hund Imports         Andersen
# 11             335       Cramer Spezialitäten, Ltd           Cramer
# 12             348           Asian Treasures, Inc.          McKenna
# 13             356            SAR Distributors, Co            Kuger
# 14             361                 Kommission Auto          Josephs
# 15             369          Lisboa Souveniers, Inc        Rodriguez
# 16             376           Precious Collectables              Urs
# 17             409  Stuttgart Collectable Exchange           Müller
# 18             443        Feuer Online Stores, Inc            Feuer
# 19             459                Warburg Exchange          Ottlieb
# 20             465             Anton Designs, Ltd.            Anton
# 21             477             Mit Vergnügen & Co.             Moos
# 22             480       Kremlin Collectables, Co.          Semenov
# 23             481              Raanan Stores, Inc      Altagar,G M
#
#    contactFirstName             phone                      addressLine1  \
# 0          Zbyszek      (26) 642-7555                   ul. Filtrowa 68
# 1             Keith        2035557845                 149 Spinnaker Dr.
# 2           Isabel       (1) 356-5555            Estrada da saúde n. 58
# 3            Brydey    +612 9411 1555                Suntec Tower Three
# 4            Horst        0372-555188                  Taucherstraße 10
# 5        Alejandra      (91) 745 6555                       Gran Vía, 1
# 6           Renate        069-0555984                      Magazinweg 7
# 7            Peter        089-0877555                 Berliner Platz 43
# 8                Ed  +41 26 425 50 01              Rte des Arsenaux 41
# 9           Bradley   +31 20 491 9555                  Kingsfordweg 151
# 10              Mel       030-0074555                     Obere Str. 57
# 11          Philip         0555-09555                     Maubelstr. 90
# 12        Patricia           2967 555                  8 Johnstown Road
# 13           Armand   +27 21 550 3555             1250 Pretorius Street
# 14            Karin       0251-555259                     Luisenstr. 48
# 15            Lino       (1) 354-2555            Jardim das rosas n. 32
# 16            Braun       0452-076555                      Hauptstr. 29
# 17            Rita        0711-555361                 Adenauerallee 900
# 18       Alexander        0342-555176                       Heerstr. 22
# 19            Sven        0241-039123                      Walserweg 21
# 20           Carmen    +34 913 728555  c/ Gobelas, 19-1 Urb. La Florida
# 21           Hanna         0621-08555                    Forsterstr. 57
# 22       Alexander    +7 812 293 0521                   2 Pobedy Square
# 23           Raanan  + 972 9 959 8555                    3 Hagalim Blv.
#
#    addressLine2              city     state postalCode       country  \
# 0          None          Warszawa      None     01-012        Poland
# 1     Suite 101         New Haven        CT      97823           USA
# 2          None            Lisboa      None       1756      Portugal
# 3     8 Temasek         Singapore      None     038988     Singapore
# 4          None         Cunewalde      None      01307       Germany
# 5          None            Madrid      None      28001         Spain
# 6          None         Frankfurt      None      60528       Germany
# 7          None           München      None      80805       Germany
# 8          None          Fribourg      None       1700   Switzerland
# 9          None         Amsterdam      None    1043 GR   Netherlands
# 10         None            Berlin      None      12209       Germany
# 11         None       Brandenburg      None      14776       Germany
# 12         None              Cork  Co. Cork       None       Ireland
# 13         None          Hatfield  Pretoria       0028  South Africa
# 14         None           Münster      None      44087       Germany
# 15         None            Lisboa      None       1675      Portugal
# 16         None              Bern      None       3012   Switzerland
# 17         None         Stuttgart      None      70563       Germany
# 18         None           Leipzig      None      04179       Germany
# 19         None            Aachen      None      52066       Germany
# 20         None            Madrid      None      28023         Spain
# 21         None          Mannheim      None      68306       Germany
# 22         None  Saint Petersburg      None     196143        Russia
# 23         None           Herzlia      None      47625        Israel
#
#     salesRepEmployeeNumber  creditLimit
# 0                      NaN          0.0
# 1                   1286.0          0.0
# 2                      NaN          0.0
# 3                      NaN          0.0
# 4                      NaN          0.0
# 5                      NaN          0.0
# 6                      NaN          0.0
# 7                      NaN          0.0
# 8                      NaN          0.0
# 9                      NaN          0.0
# 10                     NaN          0.0
# 11                     NaN          0.0
# 12                     NaN          0.0
# 13                     NaN          0.0
# 14                     NaN          0.0
# 15                     NaN          0.0
# 16                  1702.0          0.0
# 17                     NaN          0.0
# 18                     NaN          0.0
# 19                     NaN          0.0
# 20                     NaN          0.0
# 21                     NaN          0.0
# 22                     NaN          0.0
# 23                     NaN          0.0

# %%
runCMD("DELETE FROM customers WHERE EXISTS(SELECT 1 FROM customers_archive a WHERE a.customernumber = customers.customerNumber);")
# Out:
# 24

# %%
runSELECT("SELECT customerNumber, customerName FROM customers WHERE customerNumber IN(SELECT customerNumber FROM orders);")
# Out:
#     customerNumber                    customerName
# 0              103               Atelier graphique
# 1              112              Signal Gift Stores
# 2              114      Australian Collectors, Co.
# 3              119               La Rochelle Gifts
# 4              121              Baane Mini Imports
# ..             ...                             ...
# 93             486    Motor Mint Distributors Inc.
# 94             487        Signal Collectibles Ltd.
# 95             489  Double Decker Gift Stores, Ltd
# 96             495            Diecast Collectables
# 97             496               Kelly's Gift Shop
#
# [98 rows x 2 columns]

# %%
runSELECT("EXPLAIN SELECT customerNumber, customerName FROM customers WHERE EXISTS(SELECT 1 FROM orders WHERE orders.customernumber = customers.customernumber);")
# Out:
#    id         select_type      table partitions type   possible_keys  \
# 0   1             PRIMARY  customers       None  ALL            None
# 1   2  DEPENDENT SUBQUERY     orders       None  ref  customerNumber
#
#               key key_len                                     ref  rows  \
# 0            None    None                                    None    98
# 1  customerNumber       4  classicmodels.customers.customerNumber     3
#
#    filtered        Extra
# 0     100.0  Using where
# 1     100.0  Using index

# %%
runSELECT("SELECT customerNumber, customerName FROM customers WHERE customerNumber IN(SELECT customerNumber FROM orders);")
# Out:
#     customerNumber                    customerName
# 0              103               Atelier graphique
# 1              112              Signal Gift Stores
# 2              114      Australian Collectors, Co.
# 3              119               La Rochelle Gifts
# 4              121              Baane Mini Imports
# ..             ...                             ...
# 93             486    Motor Mint Distributors Inc.
# 94             487        Signal Collectibles Ltd.
# 95             489  Double Decker Gift Stores, Ltd
# 96             495            Diecast Collectables
# 97             496               Kelly's Gift Shop
#
# [98 rows x 2 columns]

# %%
runSELECT("SELECT employeenumber, firstname, lastname FROM employees WHERE officeCode IN(SELECT officeCode FROM offices WHERE offices.city = 'San Francisco');")
# Out:
#    employeenumber firstname   lastname
# 0            1002     Diane     Murphy
# 1            1056      Mary  Patterson
# 2            1076      Jeff   Firrelli
# 3            1143   Anthony        Bow
# 4            1165    Leslie   Jennings
# 5            1166    Leslie   Thompson

# %% [markdown]
# # Section 7: Common Table Expessions

# %%
# !apt update
# !apt upgrade
#!wget -c https://dev.mysql.com/get/mysql-apt-config_0.8.11-1_all.deb
# !wget https://dev.mysql.com/get/mysql-apt-config_0.8.22-1_all.deb
# !dpkg -i mysql-apt-config_0.8.*
# !sudo apt update
# !sudo apt install mysql-server
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [82.3 kB]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [952 kB]
# Hit:14 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [884 kB]
# Get:17 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,490 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,694 kB]
# Get:20 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,831 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,133 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,268 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [918 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.9 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [12.2 kB]
# Get:28 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [938 kB]
# Get:29 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.2 kB]
# Get:30 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [44.3 kB]
# Fetched 15.6 MB in 5s (3,072 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 96 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   linux-headers-4.15.0-173 linux-headers-4.15.0-173-generic r-cran-rcpp
# Use 'apt autoremove' to remove them.
# The following NEW packages will be installed:
#   linux-headers-4.15.0-175 linux-headers-4.15.0-175-generic
# The following packages have been kept back:
#   libcudnn8 libcudnn8-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   base-files binutils binutils-common binutils-x86-64-linux-gnu gnupg2 gzip
#   libaudit-common libaudit1 libbinutils libc-bin libcublas-dev libcublas10
#   libcudnn7 libcudnn7-dev libfribidi0 libgnutls30 libhogweed4 libkeyutils1
#   libldap-2.4-2 libldap-common liblz4-1 libnettle6 libnvidia-cfg1-510
#   libnvidia-common-510 libnvidia-compute-510 libnvidia-decode-510
#   libnvidia-encode-510 libnvidia-extra-510 libnvidia-fbc1-510 libnvidia-gl-510
#   libp11-kit0 libpam-modules libpam-modules-bin libpam-runtime libpam0g
#   libpython2.7 libpython2.7-dev libpython2.7-minimal libpython2.7-stdlib
#   libpython3.6 libpython3.6-dev libpython3.6-minimal libpython3.6-stdlib
#   libsasl2-2 libsasl2-modules-db libseccomp2 libzstd1 linux-headers-generic
#   linux-libc-dev login nvidia-compute-utils-510 nvidia-dkms-510
#   nvidia-driver-510 nvidia-kernel-common-510 nvidia-kernel-source-510
#   nvidia-utils-510 openjdk-11-jdk-headless openjdk-11-jre
#   openjdk-11-jre-headless openssl passwd python2.7 python2.7-dev
#   python2.7-minimal python3.6 python3.6-dev python3.6-minimal r-cran-cluster
#   r-cran-crayon r-cran-fansi r-cran-gert r-cran-knitr r-cran-magrittr
#   r-cran-mass r-cran-matrix r-cran-mgcv r-cran-nlme r-cran-processx
#   r-cran-readxl r-cran-rprojroot r-cran-sass r-cran-testthat r-cran-tinytex
#   r-cran-tzdb r-cran-vctrs rsync tar tzdata ubuntu-keyring
#   xserver-xorg-video-nvidia-510 zlib1g zlib1g-dev
# 92 upgraded, 2 newly installed, 0 to remove and 4 not upgraded.
# Need to get 1,102 MB of archives.
# After this operation, 160 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas10 10.2.3.254-1 [43.1 MB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ r-cran-cluster 2.1.3-1.1804.0 [543 kB]
# Get:3 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-driver-510 amd64 510.60.02-0ubuntu0.18.04.1 [454 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 base-files amd64 10.1ubuntu2.11 [60.4 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ r-cran-mass 7.3-56-1.1804.0 [1,115 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ r-cran-matrix 1.4-1-1.1804.0 [4,297 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gzip amd64 1.6-5ubuntu1.1 [89.8 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas-dev 10.2.3.254-1 [42.4 MB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ r-cran-nlme 3.1.157-1.1804.0 [2,235 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 login amd64 1:4.5-1ubuntu2.2 [308 kB]
# Get:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-extra-510 amd64 510.60.02-0ubuntu0.18.04.1 [48.7 kB]
# Get:12 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ r-cran-mgcv 1.8-40-1cran1.1804.0 [3,022 kB]
# Get:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-common-510 all 510.60.02-0ubuntu0.18.04.1 [9,828 B]
# Get:14 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  libcudnn7-dev 7.6.5.32-1+cuda10.2 [165 MB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tar amd64 1.29b-2ubuntu0.3 [234 kB]
# Get:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-gl-510 amd64 510.60.02-0ubuntu0.18.04.1 [171 MB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libc-bin amd64 2.27-3ubuntu1.5 [638 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaudit-common all 1:2.8.2-1ubuntu1.1 [4,068 B]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaudit1 amd64 1:2.8.2-1ubuntu1.1 [38.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam0g amd64 1.1.8-3.6ubuntu2.18.04.3 [55.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-modules-bin amd64 1.1.8-3.6ubuntu2.18.04.3 [40.3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-modules amd64 1.1.8-3.6ubuntu2.18.04.3 [252 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 zlib1g-dev amd64 1:1.2.11.dfsg-0ubuntu2.1 [176 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 zlib1g amd64 1:1.2.11.dfsg-0ubuntu2.1 [56.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6-dev amd64 3.6.9-1~18.04ubuntu1.7 [511 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-dev amd64 3.6.9-1~18.04ubuntu1.7 [44.9 MB]
# Get:27 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  libcudnn7 7.6.5.32-1+cuda10.2 [189 MB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6 amd64 3.6.9-1~18.04ubuntu1.7 [1,414 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6 amd64 3.6.9-1~18.04ubuntu1.7 [203 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-stdlib amd64 3.6.9-1~18.04ubuntu1.7 [1,710 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6-minimal amd64 3.6.9-1~18.04ubuntu1.7 [1,610 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-minimal amd64 3.6.9-1~18.04ubuntu1.7 [534 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python2.7-dev amd64 2.7.17-1~18.04ubuntu1.7 [285 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7-dev amd64 2.7.17-1~18.04ubuntu1.7 [28.3 MB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7 amd64 2.7.17-1~18.04ubuntu1.7 [1,054 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python2.7 amd64 2.7.17-1~18.04ubuntu1.7 [248 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7-stdlib amd64 2.7.17-1~18.04ubuntu1.7 [1,917 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python2.7-minimal amd64 2.7.17-1~18.04ubuntu1.7 [1,288 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7-minimal amd64 2.7.17-1~18.04ubuntu1.7 [335 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblz4-1 amd64 0.0~r131-2ubuntu3.1 [48.5 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-runtime all 1.1.8-3.6ubuntu2.18.04.3 [37.1 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzstd1 amd64 1.3.3+dfsg-2ubuntu1.2 [189 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 passwd amd64 1:4.5-1ubuntu2.2 [818 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnettle6 amd64 3.4.1-0ubuntu0.18.04.1 [111 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libhogweed4 amd64 3.4.1-0ubuntu0.18.04.1 [140 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libp11-kit0 amd64 0.23.9-2ubuntu0.1 [187 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgnutls30 amd64 3.5.18-1ubuntu1.5 [646 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libseccomp2 amd64 2.5.1-1ubuntu1~18.04.2 [43.0 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ubuntu-keyring all 2018.09.18.1~18.04.2 [22.3 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libfribidi0 amd64 0.19.7-2ubuntu0.1 [25.2 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openssl amd64 1.1.1-1ubuntu2.1~18.04.15 [614 kB]
# Get:52 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-dkms-510 amd64 510.60.02-0ubuntu0.18.04.1 [28.9 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tzdata all 2022a-0ubuntu0.18.04 [190 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkeyutils1 amd64 1.5.9-9.2ubuntu2.1 [8,764 B]
# Get:55 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 rsync amd64 3.1.2-2.1ubuntu1.4 [334 kB]
# Get:56 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-kernel-source-510 amd64 510.60.02-0ubuntu0.18.04.1 [29.1 MB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.30-21ubuntu1~18.04.7 [1,839 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-common amd64 2.30-21ubuntu1~18.04.7 [197 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils amd64 2.30-21ubuntu1~18.04.7 [3,388 B]
# Get:60 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbinutils amd64 2.30-21ubuntu1~18.04.7 [489 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.4 [15.0 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.4 [49.2 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-175 all 4.15.0-175.184 [10.9 MB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-175-generic amd64 4.15.0-175.184 [1,255 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-generic amd64 4.15.0.175.164 [2,404 B]
# Get:68 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-libc-dev amd64 4.15.0-175.184 [987 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre amd64 11.0.14.1+1-0ubuntu1~18.04 [174 kB]
# Get:70 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-kernel-common-510 amd64 510.60.02-0ubuntu0.18.04.1 [20.7 MB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jdk-headless amd64 11.0.14.1+1-0ubuntu1~18.04 [221 MB]
# Get:72 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-decode-510 amd64 510.60.02-0ubuntu0.18.04.1 [1,253 kB]
# Get:73 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-compute-510 amd64 510.60.02-0ubuntu0.18.04.1 [54.3 MB]
# Get:74 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-compute-utils-510 amd64 510.60.02-0ubuntu0.18.04.1 [106 kB]
# Get:75 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-encode-510 amd64 510.60.02-0ubuntu0.18.04.1 [41.3 kB]
# Get:76 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-utils-510 amd64 510.60.02-0ubuntu0.18.04.1 [385 kB]
# Get:77 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 xserver-xorg-video-nvidia-510 amd64 510.60.02-0ubuntu0.18.04.1 [1,395 kB]
# Get:78 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-fbc1-510 amd64 510.60.02-0ubuntu0.18.04.1 [46.5 kB]
# Get:79 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-cfg1-510 amd64 510.60.02-0ubuntu0.18.04.1 [78.9 kB]
# Get:80 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-crayon all 1.5.1-1cran1.1804.0 [155 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre-headless amd64 11.0.14.1+1-0ubuntu1~18.04 [37.2 MB]
# Get:82 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-fansi amd64 1.0.3-1cran1.1804.0 [293 kB]
# Get:83 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-gert amd64 1.6.0-1cran1.1804.0 [228 kB]
# Get:84 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-knitr all 1.38-1cran1.1804.0 [1,219 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 gnupg2 all 2.2.4-1ubuntu1.4 [5,292 B]
# Get:86 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-magrittr amd64 2.0.3-1cran1.1804.0 [192 kB]
# Get:87 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-processx amd64 3.5.3-1cran1.1804.0 [308 kB]
# Get:88 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-readxl amd64 1.4.0-1cran1.1804.0 [722 kB]
# Get:89 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-rprojroot all 2.0.3-1cran1.1804.0 [96.7 kB]
# Get:90 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-sass amd64 0.4.1-1cran1.1804.0 [2,114 kB]
# Get:91 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-testthat amd64 3.1.3-1cran1.1804.0 [1,451 kB]
# Get:92 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-tinytex all 0.38-1cran1.1804.0 [131 kB]
# Get:93 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-tzdb amd64 0.3.0-1cran1.1804.0 [479 kB]
# Get:94 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-vctrs amd64 0.4.0-1cran1.1804.0 [1,125 kB]
# Fetched 1,102 MB in 40s (27.8 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../base-files_10.1ubuntu2.11_amd64.deb ...
# Unpacking base-files (10.1ubuntu2.11) over (10.1ubuntu2.10) ...
# Setting up base-files (10.1ubuntu2.11) ...
# Installing new version of config file /etc/issue ...
# Installing new version of config file /etc/issue.net ...
# Installing new version of config file /etc/lsb-release ...
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../gzip_1.6-5ubuntu1.1_amd64.deb ...
# Unpacking gzip (1.6-5ubuntu1.1) over (1.6-5ubuntu1) ...
# Setting up gzip (1.6-5ubuntu1.1) ...
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../login_1%3a4.5-1ubuntu2.2_amd64.deb ...
# Unpacking login (1:4.5-1ubuntu2.2) over (1:4.5-1ubuntu2) ...
# Setting up login (1:4.5-1ubuntu2.2) ...
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../tar_1.29b-2ubuntu0.3_amd64.deb ...
# Unpacking tar (1.29b-2ubuntu0.3) over (1.29b-2ubuntu0.1) ...
# Setting up tar (1.29b-2ubuntu0.3) ...
# update-alternatives: warning: forcing reinstallation of alternative /usr/sbin/rmt-tar because link group rmt is broken
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../libc-bin_2.27-3ubuntu1.5_amd64.deb ...
# Unpacking libc-bin (2.27-3ubuntu1.5) over (2.27-3ubuntu1.3) ...
# Setting up libc-bin (2.27-3ubuntu1.5) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../libaudit-common_1%3a2.8.2-1ubuntu1.1_all.deb ...
# Unpacking libaudit-common (1:2.8.2-1ubuntu1.1) over (1:2.8.2-1ubuntu1) ...
# Setting up libaudit-common (1:2.8.2-1ubuntu1.1) ...
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../libaudit1_1%3a2.8.2-1ubuntu1.1_amd64.deb ...
# Unpacking libaudit1:amd64 (1:2.8.2-1ubuntu1.1) over (1:2.8.2-1ubuntu1) ...
# Setting up libaudit1:amd64 (1:2.8.2-1ubuntu1.1) ...
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../libpam0g_1.1.8-3.6ubuntu2.18.04.3_amd64.deb ...
# Unpacking libpam0g:amd64 (1.1.8-3.6ubuntu2.18.04.3) over (1.1.8-3.6ubuntu2.18.04.2) ...
# Setting up libpam0g:amd64 (1.1.8-3.6ubuntu2.18.04.3) ...
# (Reading database ... 156717 files and directories currently installed.)
# Preparing to unpack .../libpam-modules-bin_1.1.8-3.6ubuntu2.18.04.3_amd64.deb ...
# Unpacking libpam-modules-bin (1.1.8-3.6ubuntu2.18.04.3) over (1.1.8-3.6ubuntu2.18.04.2) ...
# Setting up libpam-modules-bin (1.1.8-3.6ubuntu2.18.04.3) ...
# (Reading database ... 156719 files and directories currently installed.)
# Preparing to unpack .../libpam-modules_1.1.8-3.6ubuntu2.18.04.3_amd64.deb ...
# Unpacking libpam-modules:amd64 (1.1.8-3.6ubuntu2.18.04.3) over (1.1.8-3.6ubuntu2.18.04.2) ...
# Setting up libpam-modules:amd64 (1.1.8-3.6ubuntu2.18.04.3) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../zlib1g-dev_1%3a1.2.11.dfsg-0ubuntu2.1_amd64.deb ...
# Unpacking zlib1g-dev:amd64 (1:1.2.11.dfsg-0ubuntu2.1) over (1:1.2.11.dfsg-0ubuntu2) ...
# Preparing to unpack .../zlib1g_1%3a1.2.11.dfsg-0ubuntu2.1_amd64.deb ...
# Unpacking zlib1g:amd64 (1:1.2.11.dfsg-0ubuntu2.1) over (1:1.2.11.dfsg-0ubuntu2) ...
# Setting up zlib1g:amd64 (1:1.2.11.dfsg-0ubuntu2.1) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../00-python3.6-dev_3.6.9-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking python3.6-dev (3.6.9-1~18.04ubuntu1.7) over (3.6.9-1~18.04ubuntu1.6) ...
# Preparing to unpack .../01-libpython3.6-dev_3.6.9-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking libpython3.6-dev:amd64 (3.6.9-1~18.04ubuntu1.7) over (3.6.9-1~18.04ubuntu1.6) ...
# Preparing to unpack .../02-libpython3.6_3.6.9-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking libpython3.6:amd64 (3.6.9-1~18.04ubuntu1.7) over (3.6.9-1~18.04ubuntu1.6) ...
# Preparing to unpack .../03-python3.6_3.6.9-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking python3.6 (3.6.9-1~18.04ubuntu1.7) over (3.6.9-1~18.04ubuntu1.6) ...
# Preparing to unpack .../04-libpython3.6-stdlib_3.6.9-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking libpython3.6-stdlib:amd64 (3.6.9-1~18.04ubuntu1.7) over (3.6.9-1~18.04ubuntu1.6) ...
# Preparing to unpack .../05-python3.6-minimal_3.6.9-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking python3.6-minimal (3.6.9-1~18.04ubuntu1.7) over (3.6.9-1~18.04ubuntu1.6) ...
# Preparing to unpack .../06-libpython3.6-minimal_3.6.9-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking libpython3.6-minimal:amd64 (3.6.9-1~18.04ubuntu1.7) over (3.6.9-1~18.04ubuntu1.6) ...
# Preparing to unpack .../07-python2.7-dev_2.7.17-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking python2.7-dev (2.7.17-1~18.04ubuntu1.7) over (2.7.17-1~18.04ubuntu1.6) ...
# Preparing to unpack .../08-libpython2.7-dev_2.7.17-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking libpython2.7-dev:amd64 (2.7.17-1~18.04ubuntu1.7) over (2.7.17-1~18.04ubuntu1.6) ...
# Preparing to unpack .../09-libpython2.7_2.7.17-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking libpython2.7:amd64 (2.7.17-1~18.04ubuntu1.7) over (2.7.17-1~18.04ubuntu1.6) ...
# Preparing to unpack .../10-python2.7_2.7.17-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking python2.7 (2.7.17-1~18.04ubuntu1.7) over (2.7.17-1~18.04ubuntu1.6) ...
# Preparing to unpack .../11-libpython2.7-stdlib_2.7.17-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking libpython2.7-stdlib:amd64 (2.7.17-1~18.04ubuntu1.7) over (2.7.17-1~18.04ubuntu1.6) ...
# Preparing to unpack .../12-python2.7-minimal_2.7.17-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking python2.7-minimal (2.7.17-1~18.04ubuntu1.7) over (2.7.17-1~18.04ubuntu1.6) ...
# Preparing to unpack .../13-libpython2.7-minimal_2.7.17-1~18.04ubuntu1.7_amd64.deb ...
# Unpacking libpython2.7-minimal:amd64 (2.7.17-1~18.04ubuntu1.7) over (2.7.17-1~18.04ubuntu1.6) ...
# Preparing to unpack .../14-liblz4-1_0.0~r131-2ubuntu3.1_amd64.deb ...
# Unpacking liblz4-1:amd64 (0.0~r131-2ubuntu3.1) over (0.0~r131-2ubuntu3) ...
# Setting up liblz4-1:amd64 (0.0~r131-2ubuntu3.1) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../libpam-runtime_1.1.8-3.6ubuntu2.18.04.3_all.deb ...
# Unpacking libpam-runtime (1.1.8-3.6ubuntu2.18.04.3) over (1.1.8-3.6ubuntu2.18.04.2) ...
# Setting up libpam-runtime (1.1.8-3.6ubuntu2.18.04.3) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../libzstd1_1.3.3+dfsg-2ubuntu1.2_amd64.deb ...
# Unpacking libzstd1:amd64 (1.3.3+dfsg-2ubuntu1.2) over (1.3.3+dfsg-2ubuntu1.1) ...
# Setting up libzstd1:amd64 (1.3.3+dfsg-2ubuntu1.2) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../passwd_1%3a4.5-1ubuntu2.2_amd64.deb ...
# Unpacking passwd (1:4.5-1ubuntu2.2) over (1:4.5-1ubuntu2) ...
# Setting up passwd (1:4.5-1ubuntu2.2) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../libnettle6_3.4.1-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnettle6:amd64 (3.4.1-0ubuntu0.18.04.1) over (3.4-1) ...
# Setting up libnettle6:amd64 (3.4.1-0ubuntu0.18.04.1) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../libhogweed4_3.4.1-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libhogweed4:amd64 (3.4.1-0ubuntu0.18.04.1) over (3.4-1) ...
# Setting up libhogweed4:amd64 (3.4.1-0ubuntu0.18.04.1) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../libp11-kit0_0.23.9-2ubuntu0.1_amd64.deb ...
# Unpacking libp11-kit0:amd64 (0.23.9-2ubuntu0.1) over (0.23.9-2) ...
# Setting up libp11-kit0:amd64 (0.23.9-2ubuntu0.1) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../libgnutls30_3.5.18-1ubuntu1.5_amd64.deb ...
# Unpacking libgnutls30:amd64 (3.5.18-1ubuntu1.5) over (3.5.18-1ubuntu1.4) ...
# Setting up libgnutls30:amd64 (3.5.18-1ubuntu1.5) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../libseccomp2_2.5.1-1ubuntu1~18.04.2_amd64.deb ...
# Unpacking libseccomp2:amd64 (2.5.1-1ubuntu1~18.04.2) over (2.4.3-1ubuntu3.18.04.3) ...
# Setting up libseccomp2:amd64 (2.5.1-1ubuntu1~18.04.2) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../ubuntu-keyring_2018.09.18.1~18.04.2_all.deb ...
# Unpacking ubuntu-keyring (2018.09.18.1~18.04.2) over (2018.09.18.1~18.04.0) ...
# Setting up ubuntu-keyring (2018.09.18.1~18.04.2) ...
# (Reading database ... 156723 files and directories currently installed.)
# Preparing to unpack .../00-libfribidi0_0.19.7-2ubuntu0.1_amd64.deb ...
# Unpacking libfribidi0:amd64 (0.19.7-2ubuntu0.1) over (0.19.7-2) ...
# Preparing to unpack .../01-openssl_1.1.1-1ubuntu2.1~18.04.15_amd64.deb ...
# Unpacking openssl (1.1.1-1ubuntu2.1~18.04.15) over (1.1.1-1ubuntu2.1~18.04.7) ...
# Preparing to unpack .../02-tzdata_2022a-0ubuntu0.18.04_all.deb ...
# Unpacking tzdata (2022a-0ubuntu0.18.04) over (2021e-0ubuntu0.18.04) ...
# Preparing to unpack .../03-libkeyutils1_1.5.9-9.2ubuntu2.1_amd64.deb ...
# Unpacking libkeyutils1:amd64 (1.5.9-9.2ubuntu2.1) over (1.5.9-9.2ubuntu2) ...
# Preparing to unpack .../04-rsync_3.1.2-2.1ubuntu1.4_amd64.deb ...
# Unpacking rsync (3.1.2-2.1ubuntu1.4) over (3.1.2-2.1ubuntu1.3) ...
# Preparing to unpack .../05-binutils-x86-64-linux-gnu_2.30-21ubuntu1~18.04.7_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.7) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../06-binutils-common_2.30-21ubuntu1~18.04.7_amd64.deb ...
# Unpacking binutils-common:amd64 (2.30-21ubuntu1~18.04.7) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../07-binutils_2.30-21ubuntu1~18.04.7_amd64.deb ...
# Unpacking binutils (2.30-21ubuntu1~18.04.7) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../08-libbinutils_2.30-21ubuntu1~18.04.7_amd64.deb ...
# Unpacking libbinutils:amd64 (2.30-21ubuntu1~18.04.7) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../09-libcublas10_10.2.3.254-1_amd64.deb ...
# Unpacking libcublas10 (10.2.3.254-1) over (10.2.1.243-1) ...
# Preparing to unpack .../10-libcublas-dev_10.2.3.254-1_amd64.deb ...
# Unpacking libcublas-dev (10.2.3.254-1) over (10.2.1.243-1) ...
# Preparing to unpack .../11-libcudnn7-dev_7.6.5.32-1+cuda10.2_amd64.deb ...
# update-alternatives: removing manually selected alternative - switching libcudnn to auto mode
# update-alternatives: using /usr/include/x86_64-linux-gnu/cudnn_v8.h to provide /usr/include/cudnn.h (libcudnn) in auto mode
# Unpacking libcudnn7-dev (7.6.5.32-1+cuda10.2) over (7.6.5.32-1+cuda10.1) ...
# Preparing to unpack .../12-libcudnn7_7.6.5.32-1+cuda10.2_amd64.deb ...
# Unpacking libcudnn7 (7.6.5.32-1+cuda10.2) over (7.6.5.32-1+cuda10.1) ...
# Preparing to unpack .../13-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.4_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.4) over (2.1.27~101-g0780600+dfsg-3ubuntu2.1) ...
# Preparing to unpack .../14-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.4_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.4) over (2.1.27~101-g0780600+dfsg-3ubuntu2.1) ...
# Preparing to unpack .../15-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.8) ...
# Preparing to unpack .../16-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.8) ...
# Preparing to unpack .../17-nvidia-driver-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-driver-510 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../18-libnvidia-extra-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-extra-510:amd64 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../19-libnvidia-common-510_510.60.02-0ubuntu0.18.04.1_all.deb ...
# Unpacking libnvidia-common-510 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../20-libnvidia-gl-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-gl-510:amd64 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../21-nvidia-dkms-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Removing all DKMS Modules
# Done.
# Unpacking nvidia-dkms-510 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../22-nvidia-kernel-source-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-source-510 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../23-nvidia-kernel-common-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-common-510 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../24-libnvidia-decode-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-decode-510:amd64 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../25-libnvidia-compute-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-compute-510:amd64 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../26-nvidia-compute-utils-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# System has not been booted with systemd as init system (PID 1). Can't operate.
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Unpacking nvidia-compute-utils-510 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../27-libnvidia-encode-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-encode-510:amd64 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../28-nvidia-utils-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-utils-510 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../29-xserver-xorg-video-nvidia-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-510 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../30-libnvidia-fbc1-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-fbc1-510:amd64 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Preparing to unpack .../31-libnvidia-cfg1-510_510.60.02-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-cfg1-510:amd64 (510.60.02-0ubuntu0.18.04.1) over (510.54-0ubuntu0.18.04.1) ...
# Selecting previously unselected package linux-headers-4.15.0-175.
# Preparing to unpack .../32-linux-headers-4.15.0-175_4.15.0-175.184_all.deb ...
# Unpacking linux-headers-4.15.0-175 (4.15.0-175.184) ...
# Selecting previously unselected package linux-headers-4.15.0-175-generic.
# Preparing to unpack .../33-linux-headers-4.15.0-175-generic_4.15.0-175.184_amd64.deb ...
# Unpacking linux-headers-4.15.0-175-generic (4.15.0-175.184) ...
# Preparing to unpack .../34-linux-headers-generic_4.15.0.175.164_amd64.deb ...
# Unpacking linux-headers-generic (4.15.0.175.164) over (4.15.0.173.162) ...
# Preparing to unpack .../35-linux-libc-dev_4.15.0-175.184_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (4.15.0-175.184) over (4.15.0-128.131) ...
# Preparing to unpack .../36-openjdk-11-jre_11.0.14.1+1-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.14.1+1-0ubuntu1~18.04) over (11.0.14+9-0ubuntu2~18.04) ...
# Preparing to unpack .../37-openjdk-11-jdk-headless_11.0.14.1+1-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-11-jdk-headless:amd64 (11.0.14.1+1-0ubuntu1~18.04) over (11.0.14+9-0ubuntu2~18.04) ...
# Preparing to unpack .../38-openjdk-11-jre-headless_11.0.14.1+1-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.14.1+1-0ubuntu1~18.04) over (11.0.14+9-0ubuntu2~18.04) ...
# Preparing to unpack .../39-r-cran-cluster_2.1.3-1.1804.0_amd64.deb ...
# Unpacking r-cran-cluster (2.1.3-1.1804.0) over (2.1.2-1.1804.0) ...
# Preparing to unpack .../40-r-cran-crayon_1.5.1-1cran1.1804.0_all.deb ...
# Unpacking r-cran-crayon (1.5.1-1cran1.1804.0) over (1.5.0-1cran1.1804.0) ...
# Preparing to unpack .../41-r-cran-fansi_1.0.3-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-fansi (1.0.3-1cran1.1804.0) over (1.0.2-1cran1.1804.0) ...
# Preparing to unpack .../42-r-cran-gert_1.6.0-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-gert (1.6.0-1cran1.1804.0) over (1.5.0-1cran1.1804.0) ...
# Preparing to unpack .../43-r-cran-knitr_1.38-1cran1.1804.0_all.deb ...
# Unpacking r-cran-knitr (1.38-1cran1.1804.0) over (1.37-1cran1.1804.0) ...
# Preparing to unpack .../44-r-cran-magrittr_2.0.3-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-magrittr (2.0.3-1cran1.1804.0) over (2.0.2-1cran1.1804.0) ...
# Preparing to unpack .../45-r-cran-mass_7.3-56-1.1804.0_amd64.deb ...
# Unpacking r-cran-mass (7.3-56-1.1804.0) over (7.3-55-1.1804.0) ...
# Preparing to unpack .../46-r-cran-matrix_1.4-1-1.1804.0_amd64.deb ...
# Unpacking r-cran-matrix (1.4-1-1.1804.0) over (1.4-0-1.1804.0) ...
# Preparing to unpack .../47-r-cran-nlme_3.1.157-1.1804.0_amd64.deb ...
# Unpacking r-cran-nlme (3.1.157-1.1804.0) over (3.1.155-1.1804.0) ...
# Preparing to unpack .../48-r-cran-mgcv_1.8-40-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-mgcv (1.8-40-1cran1.1804.0) over (1.8-39-1cran1.1804.0) ...
# Preparing to unpack .../49-r-cran-processx_3.5.3-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-processx (3.5.3-1cran1.1804.0) over (3.5.2-1cran1.1804.0) ...
# Preparing to unpack .../50-r-cran-readxl_1.4.0-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-readxl (1.4.0-1cran1.1804.0) over (1.3.1-1cran1.1804.0) ...
# Preparing to unpack .../51-r-cran-rprojroot_2.0.3-1cran1.1804.0_all.deb ...
# Unpacking r-cran-rprojroot (2.0.3-1cran1.1804.0) over (2.0.2-1cran1.1804.0) ...
# Preparing to unpack .../52-r-cran-sass_0.4.1-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-sass (0.4.1-1cran1.1804.0) over (0.4.0-1cran1.1804.0) ...
# Preparing to unpack .../53-r-cran-testthat_3.1.3-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-testthat (3.1.3-1cran1.1804.0) over (3.1.2-1cran1.1804.0) ...
# Preparing to unpack .../54-r-cran-tinytex_0.38-1cran1.1804.0_all.deb ...
# Unpacking r-cran-tinytex (0.38-1cran1.1804.0) over (0.37-1cran1.1804.0) ...
# Preparing to unpack .../55-r-cran-tzdb_0.3.0-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-tzdb (0.3.0-1cran1.1804.0) over (0.2.0-1cran1.1804.0) ...
# Preparing to unpack .../56-r-cran-vctrs_0.4.0-1cran1.1804.0_amd64.deb ...
# Unpacking r-cran-vctrs (0.4.0-1cran1.1804.0) over (0.3.8-1cran1.1804.0) ...
# Preparing to unpack .../57-gnupg2_2.2.4-1ubuntu1.4_all.deb ...
# Unpacking gnupg2 (2.2.4-1ubuntu1.4) over (2.2.4-1ubuntu1.3) ...
# Setting up r-cran-tinytex (0.38-1cran1.1804.0) ...
# Setting up libcudnn7 (7.6.5.32-1+cuda10.2) ...
# Setting up r-cran-processx (3.5.3-1cran1.1804.0) ...
# Setting up r-cran-gert (1.6.0-1cran1.1804.0) ...
# Setting up nvidia-kernel-source-510 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up r-cran-matrix (1.4-1-1.1804.0) ...
# Setting up libnvidia-compute-510:amd64 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up r-cran-readxl (1.4.0-1cran1.1804.0) ...
# Setting up tzdata (2022a-0ubuntu0.18.04) ...
#
# Current default time zone: 'Etc/UTC'
# Local time is now:      Sat Apr  9 16:21:10 UTC 2022.
# Universal Time is now:  Sat Apr  9 16:21:10 UTC 2022.
# Run 'dpkg-reconfigure tzdata' if you wish to change it.
#
# Setting up libnvidia-decode-510:amd64 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up r-cran-nlme (3.1.157-1.1804.0) ...
# Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.4) ...
# Setting up r-cran-knitr (1.38-1cran1.1804.0) ...
# Setting up linux-libc-dev:amd64 (4.15.0-175.184) ...
# Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.4) ...
# Setting up libcudnn7-dev (7.6.5.32-1+cuda10.2) ...
# update-alternatives: using /usr/include/x86_64-linux-gnu/cudnn_v7.h to provide /usr/include/cudnn.h (libcudnn) in manual mode
# Setting up libnvidia-fbc1-510:amd64 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up r-cran-fansi (1.0.3-1cran1.1804.0) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.14.1+1-0ubuntu1~18.04) ...
# Setting up r-cran-crayon (1.5.1-1cran1.1804.0) ...
# Setting up openjdk-11-jdk-headless:amd64 (11.0.14.1+1-0ubuntu1~18.04) ...
# Setting up r-cran-sass (0.4.1-1cran1.1804.0) ...
# Setting up r-cran-vctrs (0.4.0-1cran1.1804.0) ...
# Setting up libnvidia-cfg1-510:amd64 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up rsync (3.1.2-2.1ubuntu1.4) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up libpython3.6-minimal:amd64 (3.6.9-1~18.04ubuntu1.7) ...
# Setting up binutils-common:amd64 (2.30-21ubuntu1~18.04.7) ...
# Setting up gnupg2 (2.2.4-1ubuntu1.4) ...
# Setting up linux-headers-4.15.0-175 (4.15.0-175.184) ...
# Setting up libcublas10 (10.2.3.254-1) ...
# Setting up libcublas-dev (10.2.3.254-1) ...
# Setting up r-cran-mgcv (1.8-40-1cran1.1804.0) ...
# Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up nvidia-utils-510 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up openssl (1.1.1-1ubuntu2.1~18.04.15) ...
# Setting up nvidia-kernel-common-510 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up xserver-xorg-video-nvidia-510 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up libfribidi0:amd64 (0.19.7-2ubuntu0.1) ...
# Setting up r-cran-mass (7.3-56-1.1804.0) ...
# Setting up libkeyutils1:amd64 (1.5.9-9.2ubuntu2.1) ...
# Setting up libpython2.7-minimal:amd64 (2.7.17-1~18.04ubuntu1.7) ...
# Setting up libnvidia-extra-510:amd64 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up r-cran-rprojroot (2.0.3-1cran1.1804.0) ...
# Setting up libpython2.7-stdlib:amd64 (2.7.17-1~18.04ubuntu1.7) ...
# Setting up r-cran-magrittr (2.0.3-1cran1.1804.0) ...
# Setting up r-cran-cluster (2.1.3-1.1804.0) ...
# Setting up python2.7-minimal (2.7.17-1~18.04ubuntu1.7) ...
# Setting up r-cran-tzdb (0.3.0-1cran1.1804.0) ...
# Setting up libnvidia-common-510 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up zlib1g-dev:amd64 (1:1.2.11.dfsg-0ubuntu2.1) ...
# Setting up openjdk-11-jre:amd64 (11.0.14.1+1-0ubuntu1~18.04) ...
# Setting up nvidia-compute-utils-510 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up libpython3.6-stdlib:amd64 (3.6.9-1~18.04ubuntu1.7) ...
# Setting up linux-headers-4.15.0-175-generic (4.15.0-175.184) ...
# /etc/kernel/header_postinst.d/dkms:
#  * dkms: running auto installation service for kernel 4.15.0-175-generic
#    ...done.
# Setting up libnvidia-encode-510:amd64 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up libbinutils:amd64 (2.30-21ubuntu1~18.04.7) ...
# Setting up python3.6-minimal (3.6.9-1~18.04ubuntu1.7) ...
# Setting up python2.7 (2.7.17-1~18.04ubuntu1.7) ...
# Setting up nvidia-dkms-510 (510.60.02-0ubuntu0.18.04.1) ...
# Loading new nvidia-510.60.02 DKMS files...
# It is likely that 5.4.144+ belongs to a chroot's host
# Building for 4.15.0-173-generic and 4.15.0-175-generic
# Building for architecture x86_64
# Building initial module for 4.15.0-173-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-173-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-173-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-173-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-173-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-173-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Building initial module for 4.15.0-175-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-175-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-175-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-175-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-175-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-175-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up libpython2.7:amd64 (2.7.17-1~18.04ubuntu1.7) ...
# Setting up libnvidia-gl-510:amd64 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up r-cran-testthat (3.1.3-1cran1.1804.0) ...
# Setting up libpython2.7-dev:amd64 (2.7.17-1~18.04ubuntu1.7) ...
# Setting up python2.7-dev (2.7.17-1~18.04ubuntu1.7) ...
# Setting up libpython3.6:amd64 (3.6.9-1~18.04ubuntu1.7) ...
# Setting up linux-headers-generic (4.15.0.175.164) ...
# Setting up binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.7) ...
# Setting up nvidia-driver-510 (510.60.02-0ubuntu0.18.04.1) ...
# Setting up python3.6 (3.6.9-1~18.04ubuntu1.7) ...
# Setting up libpython3.6-dev:amd64 (3.6.9-1~18.04ubuntu1.7) ...
# Setting up binutils (2.30-21ubuntu1~18.04.7) ...
# Setting up python3.6-dev (3.6.9-1~18.04ubuntu1.7) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for systemd (237-3ubuntu10.53) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# --2022-04-09 16:25:18--  https://dev.mysql.com/get/mysql-apt-config_0.8.22-1_all.deb
# Resolving dev.mysql.com (dev.mysql.com)... 137.254.60.11
# Connecting to dev.mysql.com (dev.mysql.com)|137.254.60.11|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://repo.mysql.com//mysql-apt-config_0.8.22-1_all.deb [following]
# --2022-04-09 16:25:18--  https://repo.mysql.com//mysql-apt-config_0.8.22-1_all.deb
# Resolving repo.mysql.com (repo.mysql.com)... 104.86.185.42
# Connecting to repo.mysql.com (repo.mysql.com)|104.86.185.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18012 (18K) [application/x-debian-package]
# Saving to: ‘mysql-apt-config_0.8.22-1_all.deb’
#
# mysql-apt-config_0. 100%[===================>]  17.59K  --.-KB/s    in 0s
#
# 2022-04-09 16:25:18 (60.7 MB/s) - ‘mysql-apt-config_0.8.22-1_all.deb’ saved [18012/18012]
#
# Selecting previously unselected package mysql-apt-config.
# (Reading database ... 186045 files and directories currently installed.)
# Preparing to unpack mysql-apt-config_0.8.22-1_all.deb ...
# Unpacking mysql-apt-config (0.8.22-1) ...
# Setting up mysql-apt-config (0.8.22-1) ...
# Warning: apt-key should not be used in scripts (called from postinst maintainerscript of the package mysql-apt-config)
# OK
# Get:1 http://repo.mysql.com/apt/ubuntu bionic InRelease [20.0 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:9 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Get:10 http://repo.mysql.com/apt/ubuntu bionic/mysql-5.7 Sources [927 B]
# Get:12 http://repo.mysql.com/apt/ubuntu bionic/mysql-5.7 amd64 Packages [5,669 B]
# Hit:13 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:14 http://repo.mysql.com/apt/ubuntu bionic/mysql-apt-config amd64 Packages [567 B]
# Get:15 http://repo.mysql.com/apt/ubuntu bionic/mysql-tools amd64 Packages [7,001 B]
# Hit:16 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:17 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:18 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:19 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:20 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 34.2 kB in 1s (28.4 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 7 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libcgi-fast-perl libcgi-pm-perl libencode-locale-perl libevent-core-2.1-6
#   libfcgi-perl libhtml-parser-perl libhtml-tagset-perl libhtml-template-perl
#   libhttp-date-perl libhttp-message-perl libio-html-perl
#   liblwp-mediatypes-perl libtimedate-perl liburi-perl linux-headers-4.15.0-173
#   linux-headers-4.15.0-173-generic r-cran-rcpp
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libmecab2 mysql-client mysql-community-client mysql-community-server
# The following packages will be REMOVED:
#   mysql-client-5.7 mysql-client-core-5.7 mysql-server-5.7
#   mysql-server-core-5.7
# The following NEW packages will be installed:
#   libmecab2 mysql-client mysql-community-client mysql-community-server
# The following packages will be upgraded:
#   mysql-server
# 1 upgraded, 4 newly installed, 4 to remove and 6 not upgraded.
# Need to get 51.5 MB of archives.
# After this operation, 161 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab2 amd64 0.996-5 [257 kB]
# Get:2 http://repo.mysql.com/apt/ubuntu bionic/mysql-5.7 amd64 mysql-server amd64 5.7.37-1ubuntu18.04 [70.3 kB]
# Get:3 http://repo.mysql.com/apt/ubuntu bionic/mysql-5.7 amd64 mysql-community-client amd64 5.7.37-1ubuntu18.04 [14.6 MB]
# Get:4 http://repo.mysql.com/apt/ubuntu bionic/mysql-5.7 amd64 mysql-client amd64 5.7.37-1ubuntu18.04 [70.3 kB]
# Get:5 http://repo.mysql.com/apt/ubuntu bionic/mysql-5.7 amd64 mysql-community-server amd64 5.7.37-1ubuntu18.04 [36.5 MB]
# Fetched 51.5 MB in 2s (25.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 5.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 186050 files and directories currently installed.)
# Preparing to unpack .../mysql-server_5.7.37-1ubuntu18.04_amd64.deb ...
# Unpacking mysql-server (5.7.37-1ubuntu18.04) over (5.7.37-0ubuntu0.18.04.1) ...
# (Reading database ... 186052 files and directories currently installed.)
# Removing mysql-server-5.7 (5.7.37-0ubuntu0.18.04.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# update-alternatives: using /etc/mysql/my.cnf.fallback to provide /etc/mysql/my.cnf (my.cnf) in auto mode
# Removing mysql-client-5.7 (5.7.37-0ubuntu0.18.04.1) ...
# Removing mysql-client-core-5.7 (5.7.37-0ubuntu0.18.04.1) ...
# Removing mysql-server-core-5.7 (5.7.37-0ubuntu0.18.04.1) ...
# Selecting previously unselected package mysql-community-client.
# (Reading database ... 185837 files and directories currently installed.)
# Preparing to unpack .../mysql-community-client_5.7.37-1ubuntu18.04_amd64.deb ...
# Unpacking mysql-community-client (5.7.37-1ubuntu18.04) ...
# Selecting previously unselected package mysql-client.
# Preparing to unpack .../mysql-client_5.7.37-1ubuntu18.04_amd64.deb ...
# Unpacking mysql-client (5.7.37-1ubuntu18.04) ...
# Selecting previously unselected package libmecab2:amd64.
# Preparing to unpack .../libmecab2_0.996-5_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-5) ...
# Selecting previously unselected package mysql-community-server.
# Preparing to unpack .../mysql-community-server_5.7.37-1ubuntu18.04_amd64.deb ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# ................
# dpkg: error processing archive /var/cache/apt/archives/mysql-community-server_5.7.37-1ubuntu18.04_amd64.deb (--unpack):
#  new mysql-community-server package pre-installation script subprocess returned error exit status 1
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Errors were encountered while processing:
#  /var/cache/apt/archives/mysql-community-server_5.7.37-1ubuntu18.04_amd64.deb
# E: Sub-process /usr/bin/dpkg returned an error code (1)

# %%
# !mysql classicmodels -e " \
SELECT customerName \
 FROM \
    (select customerName, state from  customers \
     where country = 'USA'\
     ) as customers_in_usa \
 WHERE state = 'CA' ORDER BY customerName \
"
# Out:
# +------------------------------+
# | customerName                 |
# +------------------------------+
# | Boards & Toys Co.            |
# | Collectable Mini Designs Co. |
# | Corporate Gift Ideas Co.     |
# | Men 'R' US Retailers, Ltd.   |
# | Mini Gifts Distributors Ltd. |
# | Mini Wheels Co.              |
# | Signal Collectibles Ltd.     |
# | Technics Stores Inc.         |
# | The Sharp Gifts Warehouse    |
# | Toys4GrownUps.com            |
# | West Coast Collectables Co.  |
# +------------------------------+

# %%
# !mysql classicmodels -e " \
SELECT employeeNumber \
CONCAT (firstName, ' ', lastName) as salesrepName \
 FROM \
    (select jobTitle from  employees \
     where jobTitle = 'Sales Rep'\
     ) as salesrep \"
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
# !mysql classicmodels -e " \
SELECT salesRepEmployeeNumber, employeeNumber, SUM(quantityOrdered*priceEach), sales \ 
FROM  \
( SELECT orderNumber FROM Orders \
 inner join  \
        orderdetails USING (orderNumber) \
        INNER JOIN \
        customers USING (customerNumber) \
        WHERE YEAR(shippedDate) = 2003 AND status = 'Shipped' \
        GROUP BY salesRepEmployeeNumber \
 ) as topsales2003\
 "
# Out:
#   File "<ipython-input-303-e685de18709f>", line 2
#     FROM  ( SELECT orderNumber FROM Orders  inner join          orderdetails USING (orderNumber)         INNER JOIN         customers USING (customerNumber)         WHERE YEAR(shippedDate) = 2003 AND status = 'Shipped'         GROUP BY salesRepEmployeeNumber  ) as topsales2003 "
#                              ^
# SyntaxError: invalid syntax

# %%
# !mysql classicmodels -e 'select * from orders'
# Out:
# +-------------+------------+--------------+-------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# | orderNumber | orderDate  | requiredDate | shippedDate | status     | comments                                                                                                                                                                                      | customerNumber |
# +-------------+------------+--------------+-------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# |       10100 | 2003-01-06 | 2003-01-13   | 2003-01-10  | Shipped    | NULL                                                                                                                                                                                          |            363 |
# |       10101 | 2003-01-09 | 2003-01-18   | 2003-01-11  | Shipped    | Check on availability.                                                                                                                                                                        |            128 |
# |       10102 | 2003-01-10 | 2003-01-18   | 2003-01-14  | Shipped    | NULL                                                                                                                                                                                          |            181 |
# |       10103 | 2003-01-29 | 2003-02-07   | 2003-02-02  | Shipped    | NULL                                                                                                                                                                                          |            121 |
# |       10104 | 2003-01-31 | 2003-02-09   | 2003-02-01  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10105 | 2003-02-11 | 2003-02-21   | 2003-02-12  | Shipped    | NULL                                                                                                                                                                                          |            145 |
# |       10106 | 2003-02-17 | 2003-02-24   | 2003-02-21  | Shipped    | NULL                                                                                                                                                                                          |            278 |
# |       10107 | 2003-02-24 | 2003-03-03   | 2003-02-26  | Shipped    | Difficult to negotiate with customer. We need more marketing materials                                                                                                                        |            131 |
# |       10108 | 2003-03-03 | 2003-03-12   | 2003-03-08  | Shipped    | NULL                                                                                                                                                                                          |            385 |
# |       10109 | 2003-03-10 | 2003-03-19   | 2003-03-11  | Shipped    | Customer requested that FedEx Ground is used for this shipping                                                                                                                                |            486 |
# |       10110 | 2003-03-18 | 2003-03-24   | 2003-03-20  | Shipped    | NULL                                                                                                                                                                                          |            187 |
# |       10111 | 2003-03-25 | 2003-03-31   | 2003-03-30  | Shipped    | NULL                                                                                                                                                                                          |            129 |
# |       10112 | 2003-03-24 | 2003-04-03   | 2003-03-29  | Shipped    | Customer requested that ad materials (such as posters, pamphlets) be included in the shippment                                                                                                |            144 |
# |       10113 | 2003-03-26 | 2003-04-02   | 2003-03-27  | Shipped    | NULL                                                                                                                                                                                          |            124 |
# |       10114 | 2003-04-01 | 2003-04-07   | 2003-04-02  | Shipped    | NULL                                                                                                                                                                                          |            172 |
# |       10115 | 2003-04-04 | 2003-04-12   | 2003-04-07  | Shipped    | NULL                                                                                                                                                                                          |            424 |
# |       10116 | 2003-04-11 | 2003-04-19   | 2003-04-13  | Shipped    | NULL                                                                                                                                                                                          |            381 |
# |       10117 | 2003-04-16 | 2003-04-24   | 2003-04-17  | Shipped    | NULL                                                                                                                                                                                          |            148 |
# |       10118 | 2003-04-21 | 2003-04-29   | 2003-04-26  | Shipped    | Customer has worked with some of our vendors in the past and is aware of their MSRP                                                                                                           |            216 |
# |       10119 | 2003-04-28 | 2003-05-05   | 2003-05-02  | Shipped    | NULL                                                                                                                                                                                          |            382 |
# |       10120 | 2003-04-29 | 2003-05-08   | 2003-05-01  | Shipped    | NULL                                                                                                                                                                                          |            114 |
# |       10121 | 2003-05-07 | 2003-05-13   | 2003-05-13  | Shipped    | NULL                                                                                                                                                                                          |            353 |
# |       10122 | 2003-05-08 | 2003-05-16   | 2003-05-13  | Shipped    | NULL                                                                                                                                                                                          |            350 |
# |       10123 | 2003-05-20 | 2003-05-29   | 2003-05-22  | Shipped    | NULL                                                                                                                                                                                          |            103 |
# |       10124 | 2003-05-21 | 2003-05-29   | 2003-05-25  | Shipped    | Customer very concerned about the exact color of the models. There is high risk that he may dispute the order because there is a slight color mismatch                                        |            112 |
# |       10125 | 2003-05-21 | 2003-05-27   | 2003-05-24  | Shipped    | NULL                                                                                                                                                                                          |            114 |
# |       10126 | 2003-05-28 | 2003-06-07   | 2003-06-02  | Shipped    | NULL                                                                                                                                                                                          |            458 |
# |       10127 | 2003-06-03 | 2003-06-09   | 2003-06-06  | Shipped    | Customer requested special shippment. The instructions were passed along to the warehouse                                                                                                     |            151 |
# |       10128 | 2003-06-06 | 2003-06-12   | 2003-06-11  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10129 | 2003-06-12 | 2003-06-18   | 2003-06-14  | Shipped    | NULL                                                                                                                                                                                          |            324 |
# |       10130 | 2003-06-16 | 2003-06-24   | 2003-06-21  | Shipped    | NULL                                                                                                                                                                                          |            198 |
# |       10131 | 2003-06-16 | 2003-06-25   | 2003-06-21  | Shipped    | NULL                                                                                                                                                                                          |            447 |
# |       10132 | 2003-06-25 | 2003-07-01   | 2003-06-28  | Shipped    | NULL                                                                                                                                                                                          |            323 |
# |       10133 | 2003-06-27 | 2003-07-04   | 2003-07-03  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10134 | 2003-07-01 | 2003-07-10   | 2003-07-05  | Shipped    | NULL                                                                                                                                                                                          |            250 |
# |       10135 | 2003-07-02 | 2003-07-12   | 2003-07-03  | Shipped    | NULL                                                                                                                                                                                          |            124 |
# |       10136 | 2003-07-04 | 2003-07-14   | 2003-07-06  | Shipped    | Customer is interested in buying more Ferrari models                                                                                                                                          |            242 |
# |       10137 | 2003-07-10 | 2003-07-20   | 2003-07-14  | Shipped    | NULL                                                                                                                                                                                          |            353 |
# |       10138 | 2003-07-07 | 2003-07-16   | 2003-07-13  | Shipped    | NULL                                                                                                                                                                                          |            496 |
# |       10139 | 2003-07-16 | 2003-07-23   | 2003-07-21  | Shipped    | NULL                                                                                                                                                                                          |            282 |
# |       10140 | 2003-07-24 | 2003-08-02   | 2003-07-30  | Shipped    | NULL                                                                                                                                                                                          |            161 |
# |       10141 | 2003-08-01 | 2003-08-09   | 2003-08-04  | Shipped    | NULL                                                                                                                                                                                          |            334 |
# |       10142 | 2003-08-08 | 2003-08-16   | 2003-08-13  | Shipped    | NULL                                                                                                                                                                                          |            124 |
# |       10143 | 2003-08-10 | 2003-08-18   | 2003-08-12  | Shipped    | Can we deliver the new Ford Mustang models by end-of-quarter?                                                                                                                                 |            320 |
# |       10144 | 2003-08-13 | 2003-08-21   | 2003-08-14  | Shipped    | NULL                                                                                                                                                                                          |            381 |
# |       10145 | 2003-08-25 | 2003-09-02   | 2003-08-31  | Shipped    | NULL                                                                                                                                                                                          |            205 |
# |       10146 | 2003-09-03 | 2003-09-13   | 2003-09-06  | Shipped    | NULL                                                                                                                                                                                          |            447 |
# |       10147 | 2003-09-05 | 2003-09-12   | 2003-09-09  | Shipped    | NULL                                                                                                                                                                                          |            379 |
# |       10148 | 2003-09-11 | 2003-09-21   | 2003-09-15  | Shipped    | They want to reevaluate their terms agreement with Finance.                                                                                                                                   |            276 |
# |       10149 | 2003-09-12 | 2003-09-18   | 2003-09-17  | Shipped    | NULL                                                                                                                                                                                          |            487 |
# |       10150 | 2003-09-19 | 2003-09-27   | 2003-09-21  | Shipped    | They want to reevaluate their terms agreement with Finance.                                                                                                                                   |            148 |
# |       10151 | 2003-09-21 | 2003-09-30   | 2003-09-24  | Shipped    | NULL                                                                                                                                                                                          |            311 |
# |       10152 | 2003-09-25 | 2003-10-03   | 2003-10-01  | Shipped    | NULL                                                                                                                                                                                          |            333 |
# |       10153 | 2003-09-28 | 2003-10-05   | 2003-10-03  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10154 | 2003-10-02 | 2003-10-12   | 2003-10-08  | Shipped    | NULL                                                                                                                                                                                          |            219 |
# |       10155 | 2003-10-06 | 2003-10-13   | 2003-10-07  | Shipped    | NULL                                                                                                                                                                                          |            186 |
# |       10156 | 2003-10-08 | 2003-10-17   | 2003-10-11  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10157 | 2003-10-09 | 2003-10-15   | 2003-10-14  | Shipped    | NULL                                                                                                                                                                                          |            473 |
# |       10158 | 2003-10-10 | 2003-10-18   | 2003-10-15  | Shipped    | NULL                                                                                                                                                                                          |            121 |
# |       10159 | 2003-10-10 | 2003-10-19   | 2003-10-16  | Shipped    | NULL                                                                                                                                                                                          |            321 |
# |       10160 | 2003-10-11 | 2003-10-17   | 2003-10-17  | Shipped    | NULL                                                                                                                                                                                          |            347 |
# |       10161 | 2003-10-17 | 2003-10-25   | 2003-10-20  | Shipped    | NULL                                                                                                                                                                                          |            227 |
# |       10162 | 2003-10-18 | 2003-10-26   | 2003-10-19  | Shipped    | NULL                                                                                                                                                                                          |            321 |
# |       10163 | 2003-10-20 | 2003-10-27   | 2003-10-24  | Shipped    | NULL                                                                                                                                                                                          |            424 |
# |       10164 | 2003-10-21 | 2003-10-30   | 2003-10-23  | Resolved   | This order was disputed, but resolved on 11/1/2003; Customer doesn't like the colors and precision of the models.                                                                             |            452 |
# |       10165 | 2003-10-22 | 2003-10-31   | 2003-12-26  | Shipped    | This order was on hold because customers's credit limit had been exceeded. Order will ship when payment is received                                                                           |            148 |
# |       10166 | 2003-10-21 | 2003-10-30   | 2003-10-27  | Shipped    | NULL                                                                                                                                                                                          |            462 |
# |       10167 | 2003-10-23 | 2003-10-30   | NULL        | Cancelled  | Customer called to cancel. The warehouse was notified in time and the order didn't ship. They have a new VP of Sales and are shifting their sales model. Our VP of Sales should contact them. |            448 |
# |       10168 | 2003-10-28 | 2003-11-03   | 2003-11-01  | Shipped    | NULL                                                                                                                                                                                          |            161 |
# |       10169 | 2003-11-04 | 2003-11-14   | 2003-11-09  | Shipped    | NULL                                                                                                                                                                                          |            276 |
# |       10170 | 2003-11-04 | 2003-11-12   | 2003-11-07  | Shipped    | NULL                                                                                                                                                                                          |            452 |
# |       10171 | 2003-11-05 | 2003-11-13   | 2003-11-07  | Shipped    | NULL                                                                                                                                                                                          |            233 |
# |       10172 | 2003-11-05 | 2003-11-14   | 2003-11-11  | Shipped    | NULL                                                                                                                                                                                          |            175 |
# |       10173 | 2003-11-05 | 2003-11-15   | 2003-11-09  | Shipped    | Cautious optimism. We have happy customers here, if we can keep them well stocked.  I need all the information I can get on the planned shippments of Porches                                 |            278 |
# |       10174 | 2003-11-06 | 2003-11-15   | 2003-11-10  | Shipped    | NULL                                                                                                                                                                                          |            333 |
# |       10175 | 2003-11-06 | 2003-11-14   | 2003-11-09  | Shipped    | NULL                                                                                                                                                                                          |            324 |
# |       10176 | 2003-11-06 | 2003-11-15   | 2003-11-12  | Shipped    | NULL                                                                                                                                                                                          |            386 |
# |       10177 | 2003-11-07 | 2003-11-17   | 2003-11-12  | Shipped    | NULL                                                                                                                                                                                          |            344 |
# |       10178 | 2003-11-08 | 2003-11-16   | 2003-11-10  | Shipped    | Custom shipping instructions sent to warehouse                                                                                                                                                |            242 |
# |       10179 | 2003-11-11 | 2003-11-17   | 2003-11-13  | Cancelled  | Customer cancelled due to urgent budgeting issues. Must be cautious when dealing with them in the future. Since order shipped already we must discuss who would cover the shipping charges.   |            496 |
# |       10180 | 2003-11-11 | 2003-11-19   | 2003-11-14  | Shipped    | NULL                                                                                                                                                                                          |            171 |
# |       10181 | 2003-11-12 | 2003-11-19   | 2003-11-15  | Shipped    | NULL                                                                                                                                                                                          |            167 |
# |       10182 | 2003-11-12 | 2003-11-21   | 2003-11-18  | Shipped    | NULL                                                                                                                                                                                          |            124 |
# |       10183 | 2003-11-13 | 2003-11-22   | 2003-11-15  | Shipped    | We need to keep in close contact with their Marketing VP. He is the decision maker for all their purchases.                                                                                   |            339 |
# |       10184 | 2003-11-14 | 2003-11-22   | 2003-11-20  | Shipped    | NULL                                                                                                                                                                                          |            484 |
# |       10185 | 2003-11-14 | 2003-11-21   | 2003-11-20  | Shipped    | NULL                                                                                                                                                                                          |            320 |
# |       10186 | 2003-11-14 | 2003-11-20   | 2003-11-18  | Shipped    | They want to reevaluate their terms agreement with the VP of Sales                                                                                                                            |            489 |
# |       10187 | 2003-11-15 | 2003-11-24   | 2003-11-16  | Shipped    | NULL                                                                                                                                                                                          |            211 |
# |       10188 | 2003-11-18 | 2003-11-26   | 2003-11-24  | Shipped    | NULL                                                                                                                                                                                          |            167 |
# |       10189 | 2003-11-18 | 2003-11-25   | 2003-11-24  | Shipped    | They want to reevaluate their terms agreement with Finance.                                                                                                                                   |            205 |
# |       10190 | 2003-11-19 | 2003-11-29   | 2003-11-20  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10191 | 2003-11-20 | 2003-11-30   | 2003-11-24  | Shipped    | We must be cautions with this customer. Their VP of Sales resigned. Company may be heading down.                                                                                              |            259 |
# |       10192 | 2003-11-20 | 2003-11-29   | 2003-11-25  | Shipped    | NULL                                                                                                                                                                                          |            363 |
# |       10193 | 2003-11-21 | 2003-11-28   | 2003-11-27  | Shipped    | NULL                                                                                                                                                                                          |            471 |
# |       10194 | 2003-11-25 | 2003-12-02   | 2003-11-26  | Shipped    | NULL                                                                                                                                                                                          |            146 |
# |       10195 | 2003-11-25 | 2003-12-01   | 2003-11-28  | Shipped    | NULL                                                                                                                                                                                          |            319 |
# |       10196 | 2003-11-26 | 2003-12-03   | 2003-12-01  | Shipped    | NULL                                                                                                                                                                                          |            455 |
# |       10197 | 2003-11-26 | 2003-12-02   | 2003-12-01  | Shipped    | Customer inquired about remote controlled models and gold models.                                                                                                                             |            216 |
# |       10198 | 2003-11-27 | 2003-12-06   | 2003-12-03  | Shipped    | NULL                                                                                                                                                                                          |            385 |
# |       10199 | 2003-12-01 | 2003-12-10   | 2003-12-06  | Shipped    | NULL                                                                                                                                                                                          |            475 |
# |       10200 | 2003-12-01 | 2003-12-09   | 2003-12-06  | Shipped    | NULL                                                                                                                                                                                          |            211 |
# |       10201 | 2003-12-01 | 2003-12-11   | 2003-12-02  | Shipped    | NULL                                                                                                                                                                                          |            129 |
# |       10202 | 2003-12-02 | 2003-12-09   | 2003-12-06  | Shipped    | NULL                                                                                                                                                                                          |            357 |
# |       10203 | 2003-12-02 | 2003-12-11   | 2003-12-07  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10204 | 2003-12-02 | 2003-12-10   | 2003-12-04  | Shipped    | NULL                                                                                                                                                                                          |            151 |
# |       10205 | 2003-12-03 | 2003-12-09   | 2003-12-07  | Shipped    |  I need all the information I can get on our competitors.                                                                                                                                     |            141 |
# |       10206 | 2003-12-05 | 2003-12-13   | 2003-12-08  | Shipped    | Can we renegotiate this one?                                                                                                                                                                  |            202 |
# |       10207 | 2003-12-09 | 2003-12-17   | 2003-12-11  | Shipped    | Check on availability.                                                                                                                                                                        |            495 |
# |       10208 | 2004-01-02 | 2004-01-11   | 2004-01-04  | Shipped    | NULL                                                                                                                                                                                          |            146 |
# |       10209 | 2004-01-09 | 2004-01-15   | 2004-01-12  | Shipped    | NULL                                                                                                                                                                                          |            347 |
# |       10210 | 2004-01-12 | 2004-01-22   | 2004-01-20  | Shipped    | NULL                                                                                                                                                                                          |            177 |
# |       10211 | 2004-01-15 | 2004-01-25   | 2004-01-18  | Shipped    | NULL                                                                                                                                                                                          |            406 |
# |       10212 | 2004-01-16 | 2004-01-24   | 2004-01-18  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10213 | 2004-01-22 | 2004-01-28   | 2004-01-27  | Shipped    | Difficult to negotiate with customer. We need more marketing materials                                                                                                                        |            489 |
# |       10214 | 2004-01-26 | 2004-02-04   | 2004-01-29  | Shipped    | NULL                                                                                                                                                                                          |            458 |
# |       10215 | 2004-01-29 | 2004-02-08   | 2004-02-01  | Shipped    | Customer requested that FedEx Ground is used for this shipping                                                                                                                                |            475 |
# |       10216 | 2004-02-02 | 2004-02-10   | 2004-02-04  | Shipped    | NULL                                                                                                                                                                                          |            256 |
# |       10217 | 2004-02-04 | 2004-02-14   | 2004-02-06  | Shipped    | NULL                                                                                                                                                                                          |            166 |
# |       10218 | 2004-02-09 | 2004-02-16   | 2004-02-11  | Shipped    | Customer requested that ad materials (such as posters, pamphlets) be included in the shippment                                                                                                |            473 |
# |       10219 | 2004-02-10 | 2004-02-17   | 2004-02-12  | Shipped    | NULL                                                                                                                                                                                          |            487 |
# |       10220 | 2004-02-12 | 2004-02-19   | 2004-02-16  | Shipped    | NULL                                                                                                                                                                                          |            189 |
# |       10221 | 2004-02-18 | 2004-02-26   | 2004-02-19  | Shipped    | NULL                                                                                                                                                                                          |            314 |
# |       10222 | 2004-02-19 | 2004-02-27   | 2004-02-20  | Shipped    | NULL                                                                                                                                                                                          |            239 |
# |       10223 | 2004-02-20 | 2004-02-29   | 2004-02-24  | Shipped    | NULL                                                                                                                                                                                          |            114 |
# |       10224 | 2004-02-21 | 2004-03-02   | 2004-02-26  | Shipped    | Customer has worked with some of our vendors in the past and is aware of their MSRP                                                                                                           |            171 |
# |       10225 | 2004-02-22 | 2004-03-01   | 2004-02-24  | Shipped    | NULL                                                                                                                                                                                          |            298 |
# |       10226 | 2004-02-26 | 2004-03-06   | 2004-03-02  | Shipped    | NULL                                                                                                                                                                                          |            239 |
# |       10227 | 2004-03-02 | 2004-03-12   | 2004-03-08  | Shipped    | NULL                                                                                                                                                                                          |            146 |
# |       10228 | 2004-03-10 | 2004-03-18   | 2004-03-13  | Shipped    | NULL                                                                                                                                                                                          |            173 |
# |       10229 | 2004-03-11 | 2004-03-20   | 2004-03-12  | Shipped    | NULL                                                                                                                                                                                          |            124 |
# |       10230 | 2004-03-15 | 2004-03-24   | 2004-03-20  | Shipped    | Customer very concerned about the exact color of the models. There is high risk that he may dispute the order because there is a slight color mismatch                                        |            128 |
# |       10231 | 2004-03-19 | 2004-03-26   | 2004-03-25  | Shipped    | NULL                                                                                                                                                                                          |            344 |
# |       10232 | 2004-03-20 | 2004-03-30   | 2004-03-25  | Shipped    | NULL                                                                                                                                                                                          |            240 |
# |       10233 | 2004-03-29 | 2004-04-04   | 2004-04-02  | Shipped    | Customer requested special shippment. The instructions were passed along to the warehouse                                                                                                     |            328 |
# |       10234 | 2004-03-30 | 2004-04-05   | 2004-04-02  | Shipped    | NULL                                                                                                                                                                                          |            412 |
# |       10235 | 2004-04-02 | 2004-04-12   | 2004-04-06  | Shipped    | NULL                                                                                                                                                                                          |            260 |
# |       10236 | 2004-04-03 | 2004-04-11   | 2004-04-08  | Shipped    | NULL                                                                                                                                                                                          |            486 |
# |       10237 | 2004-04-05 | 2004-04-12   | 2004-04-10  | Shipped    | NULL                                                                                                                                                                                          |            181 |
# |       10238 | 2004-04-09 | 2004-04-16   | 2004-04-10  | Shipped    | NULL                                                                                                                                                                                          |            145 |
# |       10239 | 2004-04-12 | 2004-04-21   | 2004-04-17  | Shipped    | NULL                                                                                                                                                                                          |            311 |
# |       10240 | 2004-04-13 | 2004-04-20   | 2004-04-20  | Shipped    | NULL                                                                                                                                                                                          |            177 |
# |       10241 | 2004-04-13 | 2004-04-20   | 2004-04-19  | Shipped    | NULL                                                                                                                                                                                          |            209 |
# |       10242 | 2004-04-20 | 2004-04-28   | 2004-04-25  | Shipped    | Customer is interested in buying more Ferrari models                                                                                                                                          |            456 |
# |       10243 | 2004-04-26 | 2004-05-03   | 2004-04-28  | Shipped    | NULL                                                                                                                                                                                          |            495 |
# |       10244 | 2004-04-29 | 2004-05-09   | 2004-05-04  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10245 | 2004-05-04 | 2004-05-12   | 2004-05-09  | Shipped    | NULL                                                                                                                                                                                          |            455 |
# |       10246 | 2004-05-05 | 2004-05-13   | 2004-05-06  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10247 | 2004-05-05 | 2004-05-11   | 2004-05-08  | Shipped    | NULL                                                                                                                                                                                          |            334 |
# |       10248 | 2004-05-07 | 2004-05-14   | NULL        | Cancelled  | Order was mistakenly placed. The warehouse noticed the lack of documentation.                                                                                                                 |            131 |
# |       10249 | 2004-05-08 | 2004-05-17   | 2004-05-11  | Shipped    | Can we deliver the new Ford Mustang models by end-of-quarter?                                                                                                                                 |            173 |
# |       10250 | 2004-05-11 | 2004-05-19   | 2004-05-15  | Shipped    | NULL                                                                                                                                                                                          |            450 |
# |       10251 | 2004-05-18 | 2004-05-24   | 2004-05-24  | Shipped    | NULL                                                                                                                                                                                          |            328 |
# |       10252 | 2004-05-26 | 2004-06-04   | 2004-05-29  | Shipped    | NULL                                                                                                                                                                                          |            406 |
# |       10253 | 2004-06-01 | 2004-06-09   | 2004-06-02  | Cancelled  | Customer disputed the order and we agreed to cancel it. We must be more cautions with this customer going forward, since they are very hard to please. We must cover the shipping fees.       |            201 |
# |       10254 | 2004-06-03 | 2004-06-13   | 2004-06-04  | Shipped    | Customer requested that DHL is used for this shipping                                                                                                                                         |            323 |
# |       10255 | 2004-06-04 | 2004-06-12   | 2004-06-09  | Shipped    | NULL                                                                                                                                                                                          |            209 |
# |       10256 | 2004-06-08 | 2004-06-16   | 2004-06-10  | Shipped    | NULL                                                                                                                                                                                          |            145 |
# |       10257 | 2004-06-14 | 2004-06-24   | 2004-06-15  | Shipped    | NULL                                                                                                                                                                                          |            450 |
# |       10258 | 2004-06-15 | 2004-06-25   | 2004-06-23  | Shipped    | NULL                                                                                                                                                                                          |            398 |
# |       10259 | 2004-06-15 | 2004-06-22   | 2004-06-17  | Shipped    | NULL                                                                                                                                                                                          |            166 |
# |       10260 | 2004-06-16 | 2004-06-22   | NULL        | Cancelled  | Customer heard complaints from their customers and called to cancel this order. Will notify the Sales Manager.                                                                                |            357 |
# |       10261 | 2004-06-17 | 2004-06-25   | 2004-06-22  | Shipped    | NULL                                                                                                                                                                                          |            233 |
# |       10262 | 2004-06-24 | 2004-07-01   | NULL        | Cancelled  | This customer found a better offer from one of our competitors. Will call back to renegotiate.                                                                                                |            141 |
# |       10263 | 2004-06-28 | 2004-07-04   | 2004-07-02  | Shipped    | NULL                                                                                                                                                                                          |            175 |
# |       10264 | 2004-06-30 | 2004-07-06   | 2004-07-01  | Shipped    | Customer will send a truck to our local warehouse on 7/1/2004                                                                                                                                 |            362 |
# |       10265 | 2004-07-02 | 2004-07-09   | 2004-07-07  | Shipped    | NULL                                                                                                                                                                                          |            471 |
# |       10266 | 2004-07-06 | 2004-07-14   | 2004-07-10  | Shipped    | NULL                                                                                                                                                                                          |            386 |
# |       10267 | 2004-07-07 | 2004-07-17   | 2004-07-09  | Shipped    | NULL                                                                                                                                                                                          |            151 |
# ...
# |       10370 | 2005-01-20 | 2005-02-01   | 2005-01-25  | Shipped    | NULL                                                                                                                                                                                          |            276 |
# |       10371 | 2005-01-23 | 2005-02-03   | 2005-01-25  | Shipped    | NULL                                                                                                                                                                                          |            124 |
# |       10372 | 2005-01-26 | 2005-02-05   | 2005-01-28  | Shipped    | NULL                                                                                                                                                                                          |            398 |
# |       10373 | 2005-01-31 | 2005-02-08   | 2005-02-06  | Shipped    | NULL                                                                                                                                                                                          |            311 |
# |       10374 | 2005-02-02 | 2005-02-09   | 2005-02-03  | Shipped    | NULL                                                                                                                                                                                          |            333 |
# |       10375 | 2005-02-03 | 2005-02-10   | 2005-02-06  | Shipped    | NULL                                                                                                                                                                                          |            119 |
# |       10376 | 2005-02-08 | 2005-02-18   | 2005-02-13  | Shipped    | NULL                                                                                                                                                                                          |            219 |
# |       10377 | 2005-02-09 | 2005-02-21   | 2005-02-12  | Shipped    | Cautious optimism. We have happy customers here, if we can keep them well stocked.  I need all the information I can get on the planned shippments of Porches                                 |            186 |
# |       10378 | 2005-02-10 | 2005-02-18   | 2005-02-11  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10379 | 2005-02-10 | 2005-02-18   | 2005-02-11  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10380 | 2005-02-16 | 2005-02-24   | 2005-02-18  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10381 | 2005-02-17 | 2005-02-25   | 2005-02-18  | Shipped    | NULL                                                                                                                                                                                          |            321 |
# |       10382 | 2005-02-17 | 2005-02-23   | 2005-02-18  | Shipped    | Custom shipping instructions sent to warehouse                                                                                                                                                |            124 |
# |       10383 | 2005-02-22 | 2005-03-02   | 2005-02-25  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10384 | 2005-02-23 | 2005-03-06   | 2005-02-27  | Shipped    | NULL                                                                                                                                                                                          |            321 |
# |       10385 | 2005-02-28 | 2005-03-09   | 2005-03-01  | Shipped    | NULL                                                                                                                                                                                          |            124 |
# |       10386 | 2005-03-01 | 2005-03-09   | 2005-03-06  | Resolved   | Disputed then Resolved on 3/15/2005. Customer doesn't like the craftsmaship of the models.                                                                                                    |            141 |
# |       10387 | 2005-03-02 | 2005-03-09   | 2005-03-06  | Shipped    | We need to keep in close contact with their Marketing VP. He is the decision maker for all their purchases.                                                                                   |            148 |
# |       10388 | 2005-03-03 | 2005-03-11   | 2005-03-09  | Shipped    | NULL                                                                                                                                                                                          |            462 |
# |       10389 | 2005-03-03 | 2005-03-09   | 2005-03-08  | Shipped    | NULL                                                                                                                                                                                          |            448 |
# |       10390 | 2005-03-04 | 2005-03-11   | 2005-03-07  | Shipped    | They want to reevaluate their terms agreement with Finance.                                                                                                                                   |            124 |
# |       10391 | 2005-03-09 | 2005-03-20   | 2005-03-15  | Shipped    | NULL                                                                                                                                                                                          |            276 |
# |       10392 | 2005-03-10 | 2005-03-18   | 2005-03-12  | Shipped    | NULL                                                                                                                                                                                          |            452 |
# |       10393 | 2005-03-11 | 2005-03-22   | 2005-03-14  | Shipped    | They want to reevaluate their terms agreement with Finance.                                                                                                                                   |            323 |
# |       10394 | 2005-03-15 | 2005-03-25   | 2005-03-19  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10395 | 2005-03-17 | 2005-03-24   | 2005-03-23  | Shipped    | We must be cautions with this customer. Their VP of Sales resigned. Company may be heading down.                                                                                              |            250 |
# |       10396 | 2005-03-23 | 2005-04-02   | 2005-03-28  | Shipped    | NULL                                                                                                                                                                                          |            124 |
# |       10397 | 2005-03-28 | 2005-04-09   | 2005-04-01  | Shipped    | NULL                                                                                                                                                                                          |            242 |
# |       10398 | 2005-03-30 | 2005-04-09   | 2005-03-31  | Shipped    | NULL                                                                                                                                                                                          |            353 |
# |       10399 | 2005-04-01 | 2005-04-12   | 2005-04-03  | Shipped    | NULL                                                                                                                                                                                          |            496 |
# |       10400 | 2005-04-01 | 2005-04-11   | 2005-04-04  | Shipped    | Customer requested that DHL is used for this shipping                                                                                                                                         |            450 |
# |       10401 | 2005-04-03 | 2005-04-14   | NULL        | On Hold    | Customer credit limit exceeded. Will ship when a payment is received.                                                                                                                         |            328 |
# |       10402 | 2005-04-07 | 2005-04-14   | 2005-04-12  | Shipped    | NULL                                                                                                                                                                                          |            406 |
# |       10403 | 2005-04-08 | 2005-04-18   | 2005-04-11  | Shipped    | NULL                                                                                                                                                                                          |            201 |
# |       10404 | 2005-04-08 | 2005-04-14   | 2005-04-11  | Shipped    | NULL                                                                                                                                                                                          |            323 |
# |       10405 | 2005-04-14 | 2005-04-24   | 2005-04-20  | Shipped    | NULL                                                                                                                                                                                          |            209 |
# |       10406 | 2005-04-15 | 2005-04-25   | 2005-04-21  | Disputed   | Customer claims container with shipment was damaged during shipping and some items were missing. I am talking to FedEx about this.                                                            |            145 |
# |       10407 | 2005-04-22 | 2005-05-04   | NULL        | On Hold    | Customer credit limit exceeded. Will ship when a payment is received.                                                                                                                         |            450 |
# |       10408 | 2005-04-22 | 2005-04-29   | 2005-04-27  | Shipped    | NULL                                                                                                                                                                                          |            398 |
# |       10409 | 2005-04-23 | 2005-05-05   | 2005-04-24  | Shipped    | NULL                                                                                                                                                                                          |            166 |
# |       10410 | 2005-04-29 | 2005-05-10   | 2005-04-30  | Shipped    | NULL                                                                                                                                                                                          |            357 |
# |       10411 | 2005-05-01 | 2005-05-08   | 2005-05-06  | Shipped    | NULL                                                                                                                                                                                          |            233 |
# |       10412 | 2005-05-03 | 2005-05-13   | 2005-05-05  | Shipped    | NULL                                                                                                                                                                                          |            141 |
# |       10413 | 2005-05-05 | 2005-05-14   | 2005-05-09  | Shipped    | Customer requested that DHL is used for this shipping                                                                                                                                         |            175 |
# |       10414 | 2005-05-06 | 2005-05-13   | NULL        | On Hold    | Customer credit limit exceeded. Will ship when a payment is received.                                                                                                                         |            362 |
# |       10415 | 2005-05-09 | 2005-05-20   | 2005-05-12  | Disputed   | Customer claims the scales of the models don't match what was discussed. I keep all the paperwork though to prove otherwise                                                                   |            471 |
# |       10416 | 2005-05-10 | 2005-05-16   | 2005-05-14  | Shipped    | NULL                                                                                                                                                                                          |            386 |
# |       10417 | 2005-05-13 | 2005-05-19   | 2005-05-19  | Disputed   | Customer doesn't like the colors and precision of the models.                                                                                                                                 |            141 |
# |       10418 | 2005-05-16 | 2005-05-24   | 2005-05-20  | Shipped    | NULL                                                                                                                                                                                          |            412 |
# |       10419 | 2005-05-17 | 2005-05-28   | 2005-05-19  | Shipped    | NULL                                                                                                                                                                                          |            382 |
# |       10420 | 2005-05-29 | 2005-06-07   | NULL        | In Process | NULL                                                                                                                                                                                          |            282 |
# |       10421 | 2005-05-29 | 2005-06-06   | NULL        | In Process | Custom shipping instructions were sent to warehouse                                                                                                                                           |            124 |
# |       10422 | 2005-05-30 | 2005-06-11   | NULL        | In Process | NULL                                                                                                                                                                                          |            157 |
# |       10423 | 2005-05-30 | 2005-06-05   | NULL        | In Process | NULL                                                                                                                                                                                          |            314 |
# |       10424 | 2005-05-31 | 2005-06-08   | NULL        | In Process | NULL                                                                                                                                                                                          |            141 |
# |       10425 | 2005-05-31 | 2005-06-07   | NULL        | In Process | NULL                                                                                                                                                                                          |            119 |
# +-------------+------------+--------------+-------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+

# %% [markdown]
# # Secion 8: Set Operators

# %% [markdown]
# UNION AND UNION ALL

# %%
runCMD("DROP TABLE IF EXISTS t1;DROP TABLE IF EXISTS t2;CREATE TABLE t1 (id INT PRIMARY KEY);CREATE TABLE t2 (id INT PRIMARY KEY);INSERT INTO t1 VALUES (1),(2),(3);INSERT INTO t2 VALUES (2),(3),(4);")
# Out:
# 0
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-442-19842df5ae84> in <module>()
# ----> 1 runCMD("DROP TABLE IF EXISTS t1;DROP TABLE IF EXISTS t2;CREATE TABLE t1 (id INT PRIMARY KEY);CREATE TABLE t2 (id INT PRIMARY KEY);INSERT INTO t1 VALUES (1),(2),(3);INSERT INTO t2 VALUES (2),(3),(4);")
#
# <ipython-input-18-d9b7a40ed863> in runCMD(DDL)
#       6     retcode = myCursor.execute(DDL)
#       7     print (retcode)
# ----> 8     DBConn.commit()
#       9     DBConn.close()
#      10
#
# ProgrammingError: (2014, "Commands out of sync; you can't run this command now")

# %%
runSELECT("SELECT firstName, lastName FROM employees UNION SELECT contactFirstName, contactLastName FROM customers;")
# Out:
#     firstName   lastName
# 0       Diane     Murphy
# 1        Mary  Patterson
# 2        Jeff   Firrelli
# 3     William  Patterson
# 4      Gerard     Bondur
# ..        ...        ...
# 140      Rosa    Salazar
# 141       Sue     Taylor
# 142   Thomas       Smith
# 143   Valarie     Franco
# 144      Tony    Snowden
#
# [145 rows x 2 columns]

# %%
runSELECT("SELECT CONCAT(firstName,' ',lastName) fullname FROM employees UNION SELECT CONCAT(contactFirstName,' ',contactLastName) FROM customers;")
# Out:
#               fullname
# 0         Diane Murphy
# 1       Mary Patterson
# 2        Jeff Firrelli
# 3    William Patterson
# 4        Gerard Bondur
# ..                 ...
# 140       Rosa Salazar
# 141         Sue Taylor
# 142      Thomas  Smith
# 143     Valarie Franco
# 144       Tony Snowden
#
# [145 rows x 1 columns]

# %%
runSELECT("SELECT concat(firstName,' ',lastName) fullname FROM employees UNION SELECT concat(contactFirstName,' ',contactLastName) FROM customers ORDER BY fullname;")
# Out:
#                      fullname
# 0               Adrian Huxley
# 1             Akiko Shimamura
# 2           Alejandra  Camino
# 3            Alexander  Feuer
# 4          Alexander  Semenov
# ..                        ...
# 140                Wing Huang
# 141             Yoshi  Tamuri
# 142              Yoshimi Kato
# 143                   Yu Choi
# 144  Zbyszek  Piestrzeniewicz
#
# [145 rows x 1 columns]

# %%
runSELECT("SELECT CONCAT(firstName, ' ', lastName) fullname,'Employee' as contactType FROM employees UNION SELECT CONCAT(contactFirstName, ' ', contactLastName),'Customer' as contactType FROM customers ORDER BY fullname")
# Out:
#                      fullname contactType
# 0               Adrian Huxley    Customer
# 1             Akiko Shimamura    Customer
# 2           Alejandra  Camino    Customer
# 3            Alexander  Feuer    Customer
# 4          Alexander  Semenov    Customer
# ..                        ...         ...
# 140                Wing Huang    Customer
# 141             Yoshi  Tamuri    Customer
# 142              Yoshimi Kato    Employee
# 143                   Yu Choi    Customer
# 144  Zbyszek  Piestrzeniewicz    Customer
#
# [145 rows x 2 columns]

# %%
runSELECT("SELECT CONCAT(firstName,' ',lastName) fullname FROM employees UNION SELECT CONCAT(contactFirstName,' ',contactLastName) FROM customers ORDER BY 1;")
# Out:
#                      fullname
# 0               Adrian Huxley
# 1             Akiko Shimamura
# 2           Alejandra  Camino
# 3            Alexander  Feuer
# 4          Alexander  Semenov
# ..                        ...
# 140                Wing Huang
# 141             Yoshi  Tamuri
# 142              Yoshimi Kato
# 143                   Yu Choi
# 144  Zbyszek  Piestrzeniewicz
#
# [145 rows x 1 columns]

# %%
runCMD("CREATE TABLE IF NOT EXISTS t11 (id INT PRIMARY KEY);CREATE TABLE t2 LIKE t11;INSERT INTO t11(id) VALUES(1),(2),(3);INSERT INTO t2(id) VALUES(2),(3),(4);")
# Out:
# 0
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-441-57ccd1eec661> in <module>()
# ----> 1 runCMD("CREATE TABLE IF NOT EXISTS t11 (id INT PRIMARY KEY);CREATE TABLE t2 LIKE t11;INSERT INTO t11(id) VALUES(1),(2),(3);INSERT INTO t2(id) VALUES(2),(3),(4);")
#
# <ipython-input-18-d9b7a40ed863> in runCMD(DDL)
#       6     retcode = myCursor.execute(DDL)
#       7     print (retcode)
# ----> 8     DBConn.commit()
#       9     DBConn.close()
#      10
#
# ProgrammingError: (2014, "Commands out of sync; you can't run this command now")

# %% [markdown]
# # SECTION 9: MODIFYING DATA IN MYSQL

# %% [markdown]
# INSERT

# %%
runCMD("CREATE TABLE IF NOT EXISTS tasks (\
    task_id INT AUTO_INCREMENT,\
    title VARCHAR(255) NOT NULL,\
    start_date DATE,\
    due_date DATE,\
    priority TINYINT NOT NULL DEFAULT 3,\
    description TEXT,\
    PRIMARY KEY (task_id));")
# Out:
# 0

# %%
runCMD("INSERT INTO tasks(title,priority) VALUES('Learn MySQL INSERT Statement',1);")
# Out:
# 1

# %% [markdown]
# INSERT MULTIPLE ROWS

# %%
runCMD("CREATE TABLE IF NOT EXISTS projects(project_id INT AUTO_INCREMENT, name VARCHAR(100) NOT NULL,start_date DATE,end_date DATE,PRIMARY KEY(project_id));")
# Out:
# 0

# %% [markdown]
# INSERT INTO SELECT

# %%
runCMD("CREATE TABLE IF NOT EXISTS suppliers1 (\
    supplierNumber INT AUTO_INCREMENT,\
    supplierName VARCHAR(50) NOT NULL,\
    phone VARCHAR(50),\
    addressLine1 VARCHAR(50),\
    addressLine2 VARCHAR(50),\
    city VARCHAR(50),\
    state VARCHAR(50),\
    postalCode VARCHAR(50),\
    country VARCHAR(50),\
    customerNumber INT,\
    PRIMARY KEY (supplierNumber));")
# Out:
# 0

# %%
runSELECT("SELECT customerNumber, customerName, phone, addressLine1, addressLine2, city, state, postalCode, country FROM customers WHERE country = 'USA' AND state = 'CA';")
# Out:
#     customerNumber                  customerName       phone  \
# 0              124  Mini Gifts Distributors Ltd.  4155551450
# 1              129               Mini Wheels Co.  6505555787
# 2              161          Technics Stores Inc.  6505556809
# 3              205             Toys4GrownUps.com  6265557265
# 4              219             Boards & Toys Co.  3105552373
# 5              239  Collectable Mini Designs Co.  7605558146
# 6              321      Corporate Gift Ideas Co.  6505551386
# 7              347    Men 'R' US Retailers, Ltd.  2155554369
# 8              450     The Sharp Gifts Warehouse  4085553659
# 9              475   West Coast Collectables Co.  3105553722
# 10             487      Signal Collectibles Ltd.  4155554312
#
#                  addressLine1 addressLine2           city state postalCode  \
# 0             5677 Strong St.         None     San Rafael    CA      97562
# 1   5557 North Pendale Street         None  San Francisco    CA      94217
# 2           9408 Furth Circle         None     Burlingame    CA      94217
# 3          78934 Hillside Dr.         None       Pasadena    CA      90003
# 4            4097 Douglas Av.         None       Glendale    CA      92561
# 5            361 Furth Circle         None      San Diego    CA      91217
# 6             7734 Strong St.         None  San Francisco    CA      94217
# 7            6047 Douglas Av.         None    Los Angeles    CA      91003
# 8              3086 Ingle Ln.         None       San Jose    CA      94217
# 9           3675 Furth Circle         None        Burbank    CA      94019
# 10          2793 Furth Circle         None       Brisbane    CA      94217
#
#    country
# 0      USA
# 1      USA
# 2      USA
# 3      USA
# 4      USA
# 5      USA
# 6      USA
# 7      USA
# 8      USA
# 9      USA
# 10     USA

# %%
runCMD("INSERT INTO suppliers1 ( supplierName, phone,  addressLine1, addressLine2, city, state, postalCode, country, customerNumber) SELECT  customerName, phone, addressLine1, addressLine2, city, state , postalCode, country, customerNumber FROM customers WHERE country = 'USA' AND state = 'CA';")
# Out:
# 11

# %%
runSELECT("SELECT * FROM suppliers1")
# Out:
#     supplierNumber                  supplierName       phone  \
# 0               31  Mini Gifts Distributors Ltd.  4155551450
# 1               32               Mini Wheels Co.  6505555787
# 2               33          Technics Stores Inc.  6505556809
# 3               34             Toys4GrownUps.com  6265557265
# 4               35             Boards & Toys Co.  3105552373
# 5               36  Collectable Mini Designs Co.  7605558146
# 6               37      Corporate Gift Ideas Co.  6505551386
# 7               38    Men 'R' US Retailers, Ltd.  2155554369
# 8               39     The Sharp Gifts Warehouse  4085553659
# 9               40   West Coast Collectables Co.  3105553722
# 10              41      Signal Collectibles Ltd.  4155554312
#
#                  addressLine1 addressLine2           city state postalCode  \
# 0             5677 Strong St.         None     San Rafael    CA      97562
# 1   5557 North Pendale Street         None  San Francisco    CA      94217
# 2           9408 Furth Circle         None     Burlingame    CA      94217
# 3          78934 Hillside Dr.         None       Pasadena    CA      90003
# 4            4097 Douglas Av.         None       Glendale    CA      92561
# 5            361 Furth Circle         None      San Diego    CA      91217
# 6             7734 Strong St.         None  San Francisco    CA      94217
# 7            6047 Douglas Av.         None    Los Angeles    CA      91003
# 8              3086 Ingle Ln.         None       San Jose    CA      94217
# 9           3675 Furth Circle         None        Burbank    CA      94019
# 10          2793 Furth Circle         None       Brisbane    CA      94217
#
#    country  customerNumber
# 0      USA             124
# 1      USA             129
# 2      USA             161
# 3      USA             205
# 4      USA             219
# 5      USA             239
# 6      USA             321
# 7      USA             347
# 8      USA             450
# 9      USA             475
# 10     USA             487

# %%
runCMD("CREATE TABLE IF NOT EXISTS stats (totalProduct INT, totalCustomer INT, totalOrder INT);")
# Out:
# 0

# %%
runCMD("INSERT INTO stats(totalProduct, totalCustomer, totalOrder)\
VALUES(\
	(SELECT COUNT(*) FROM products),\
	(SELECT COUNT(*) FROM customers),\
	(SELECT COUNT(*) FROM orders)\
);")
# Out:
# 1

# %%
runSELECT("select * from stats")
# Out:
#    totalProduct  totalCustomer  totalOrder
# 0           110            122         326

# %%
runSELECT("show processlist")
# Out:
#     Id  User       Host             db Command  Time     State  \
# 0  291  root  localhost  classicmodels   Query     0  starting
#
#                Info
# 0  show processlist

# %%
runCMD("kill 287")
# Out:
# 0

# %% [markdown]
# INSERT IGNORE

# %%
runCMD("CREATE TABLE subscribers (id INT PRIMARY KEY AUTO_INCREMENT,email VARCHAR(50) NOT NULL UNIQUE);")
# Out:
# 0

# %%
runCMD("INSERT INTO subscribers(email) VALUES('john.doe@gmail.com');")
# Out:
# 1

# %%
runCMD("CREATE TABLE tokens (s VARCHAR(6));")
# Out:
# 0

# %%
runCMD("INSERT INTO tokens VALUES('abcdef');")
# Out:
# 1

# %%
runCMD("INSERT IGNORE INTO tokens VALUES('abcdefg');")
# Out:
# 1

# %% [markdown]
# UPDATE

# %%
runSELECT("SELECT firstname, lastname, email FROM employees WHERE employeeNumber = 1056;")
# Out:
#   firstname   lastname                           email
# 0      Mary  Patterson  mpatterso@classicmodelcars.com

# %%
runCMD("UPDATE employees SET email = 'mary.patterson@classicmodelcars.com' WHERE employeeNumber = 1056;")
# Out:
# 0

# %%
runCMD("UPDATE employees SET email = 'mary.patterson@classicmodelcars.com' WHERE employeeNumber = 1056;")
# Out:
# 1

# %%
runCMD("UPDATE employees SET email = REPLACE(email,'@classicmodelcars.com','@mysqltutorial.org') WHERE jobTitle = 'Sales Rep' AND officeCode = 6;")
# Out:
# 3

# %%
runSELECT("SELECT customername, salesRepEmployeeNumber FROM customers WHERE salesRepEmployeeNumber IS NULL;")
# Out:
#                       customername salesRepEmployeeNumber
# 0               Havel & Zbyszek Co                   None
# 1                Porto Imports Co.                   None
# 2       Asian Shopping Network, Co                   None
# 3                  Natürlich Autos                   None
# 4                    ANG Resellers                   None
# 5         Messner Shopping Network                   None
# 6                Franken Gifts, Co                   None
# 7                BG&E Collectables                   None
# 8                 Schuyler Imports                   None
# 9                 Der Hund Imports                   None
# 10       Cramer Spezialitäten, Ltd                   None
# 11           Asian Treasures, Inc.                   None
# 12            SAR Distributors, Co                   None
# 13                 Kommission Auto                   None
# 14          Lisboa Souveniers, Inc                   None
# 15  Stuttgart Collectable Exchange                   None
# 16        Feuer Online Stores, Inc                   None
# 17                Warburg Exchange                   None
# 18             Anton Designs, Ltd.                   None
# 19             Mit Vergnügen & Co.                   None
# 20       Kremlin Collectables, Co.                   None
# 21              Raanan Stores, Inc                   None

# %%
runSELECT("SELECT employeeNumber FROM employees WHERE jobtitle = 'Sales Rep' ORDER BY RAND() LIMIT 1;")
# Out:
#    employeeNumber
# 0            1188

# %%
runCMD("UPDATE customers SET salesRepEmployeeNumber = (SELECT employeeNumber FROM employees WHERE jobtitle = 'Sales Rep' ORDER BY RAND() LIMIT 1) WHERE salesRepEmployeeNumber IS NULL;")
# Out:
# 22

# %%
runSELECT("SELECT salesRepEmployeeNumber FROM customers WHERE salesRepEmployeeNumber IS NULL;")
# Out:
#    salesRepEmployeeNumber
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# 5                    None
# 6                    None
# 7                    None
# 8                    None
# 9                    None
# 10                   None
# 11                   None
# 12                   None
# 13                   None
# 14                   None
# 15                   None
# 16                   None
# 17                   None
# 18                   None
# 19                   None
# 20                   None
# 21                   None

# %%
runSELECT("SELECT employeeNumber FROM employees WHERE jobtitle = 'Sales Rep' ORDER BY RAND() LIMIT 1;")
# Out:
#    employeeNumber
# 0            1702

# %%
runCMD("UPDATE customers SET salesRepEmployeeNumber = (SELECT employeeNumber FROM employees WHERE jobtitle = 'Sales Rep' ORDER BY RAND() LIMIT 1) WHERE salesRepEmployeeNumber IS NULL;")
# Out:
# 0

# %%
runCMD("UPDATE employees1 INNER JOIN merits ON employees1.performance = merits.performance SET salary = salary + salary * percentage;")
# Out:
# 6

# %% [markdown]
# UPDATE JOIN

# %%
runCMD("CREATE DATABASE IF NOT EXISTS empdb;")
# Out:
# 1

# %%
runCMD("Use empdb")
# Out:
# 0

# %%
runCMD("CREATE TABLE merits ( performance INT(11) NOT NULL, percentage FLOAT NOT NULL, PRIMARY KEY (performance));")
# Out:
# 0

# %%
runCMD("CREATE TABLE employees1 ( emp_id INT(11) NOT NULL AUTO_INCREMENT, emp_name VARCHAR(255) NOT NULL, performance INT(11) DEFAULT NULL, salary FLOAT DEFAULT NULL, PRIMARY KEY (emp_id), CONSTRAINT fk_performance FOREIGN KEY (performance) REFERENCES merits (performance));")
# Out:
# 0

# %%
runCMD("INSERT INTO merits(performance,percentage) VALUES(1,0), (2,0.01), (3,0.03), (4,0.05), (5,0.08);")
# Out:
# 5

# %%
runCMD("INSERT INTO employees1 (emp_name,performance,salary) VALUES('Mary Doe', 1, 50000), ('Cindy Smith', 3, 65000), ('Sue Greenspan', 4, 75000), ('Grace Dell', 5, 125000), ('Nancy Johnson', 3, 85000), ('John Doe', 2, 45000), ('Lily Bush', 3, 55000);")
# Out:
# 7

# %%
runCMD("INSERT INTO employees1 (emp_name,performance,salary) VALUES('Jack William',NULL,43000), ('Ricky Bond',NULL,52000);")
# Out:
# 2

# %%
runCMD("UPDATE employees1 LEFT JOIN merits ON employees1.performance = merits.performance SET salary = salary + salary * 0.015 WHERE merits.percentage IS NULL;")
# Out:
# 2

# %%
runCMD("UPDATE employees1 INNER JOIN merits ON employees1.performance = merits.performance SET salary = salary + salary * percentage;")
# Out:
# 6

# %%
runCMD("UPDATE employees1 LEFT JOIN merits ON employees1.performance = merits.performance SET salary = salary + salary * 0.015 WHERE merits.percentage IS NULL;")
# Out:
# 2

# %% [markdown]
# DELETE

# %%
runCMD("DELETE FROM employees WHERE officeCode = 4;")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-428-9aa0ccbefc5d> in <module>()
# ----> 1 runCMD("DELETE FROM employees WHERE officeCode = 4;")
#
# <ipython-input-18-d9b7a40ed863> in runCMD(DDL)
#       4     DBConn= MySQLdb.connect(db='classicmodels')  # since local MySQL server, userid, password not needed
#       5     myCursor = DBConn.cursor()
# ----> 6     retcode = myCursor.execute(DDL)
#       7     print (retcode)
#       8     DBConn.commit()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     317         db = self._get_db()
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#     321         self._post_get_result()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     252         if isinstance(query, bytearray):
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#     256     def _bytes_literal(self, bs):
#
# IntegrityError: (1451, 'Cannot delete or update a parent row: a foreign key constraint fails (`classicmodels`.`employees`, CONSTRAINT `employees_ibfk_1` FOREIGN KEY (`reportsTo`) REFERENCES `employees` (`employeeNumber`))')

# %%
runCMD("DELETE FROM employees;")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-422-ae365854723e> in <module>()
# ----> 1 runCMD("DELETE FROM employees;")
#
# <ipython-input-18-d9b7a40ed863> in runCMD(DDL)
#       4     DBConn= MySQLdb.connect(db='classicmodels')  # since local MySQL server, userid, password not needed
#       5     myCursor = DBConn.cursor()
# ----> 6     retcode = myCursor.execute(DDL)
#       7     print (retcode)
#       8     DBConn.commit()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/cursors.py in _query(self, q)
#     317         db = self._get_db()
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#     321         self._post_get_result()
#
# /usr/local/lib/python3.7/dist-packages/MySQLdb/connections.py in query(self, query)
#     252         if isinstance(query, bytearray):
#     253             query = bytes(query)
# --> 254         _mysql.connection.query(self, query)
#     255
#     256     def _bytes_literal(self, bs):
#
# IntegrityError: (1451, 'Cannot delete or update a parent row: a foreign key constraint fails (`classicmodels`.`employees`, CONSTRAINT `employees_ibfk_1` FOREIGN KEY (`reportsTo`) REFERENCES `employees` (`employeeNumber`))')

# %% [markdown]
# DELETE CASCADE

# %%
runCMD("DELETE FROM buildings WHERE building_no = 2;")
# Out:
# 1

# %%
runCMD("CREATE TABLE buildings1 (building_no INT PRIMARY KEY AUTO_INCREMENT,building_name VARCHAR(255) NOT NULL,address VARCHAR(255) NOT NULL);")
# Out:
# 0

# %%
runCMD("CREATE TABLE rooms (room_no INT PRIMARY KEY AUTO_INCREMENT,room_name VARCHAR(255) NOT NULL,building_no INT NOT NULL, FOREIGN KEY (building_no) REFERENCES buildings (building_no) ON DELETE CASCADE);")
# Out:
# 0

# %%
runCMD("INSERT INTO buildings(building_name,address) VALUES('ACME Headquaters','3950 North 1st Street CA 95134'), ('ACME Sales','5000 North 1st Street CA 95134');")
# Out:
# 2

# %%
runCMD("INSERT INTO rooms(room_name,building_no) VALUES('Amazon',1), ('War Room',1), ('Office of CEO',1), ('Marketing',2), ('Showroom',2);")
# Out:
# 5

# %% [markdown]
# DELETE JOIN

# %%
runCMD("SELECT  c.customerNumber, c.customerName,  orderNumber FROM customers c LEFT JOIN orders o ON c.customerNumber = o.customerNumber WHERE orderNumber IS NULL;")
# Out:
# 24

# %% [markdown]
# REPLACE

# %%
runCMD("CREATE TABLE cities (id INT AUTO_INCREMENT PRIMARY KEY,name VARCHAR(50),population INT NOT NULL);")
# Out:
# 0

# %%
runCMD("INSERT INTO cities(name,population)\
VALUES('New York',8008278),('Los Angeles',3694825),('San Diego',1223405);")
# Out:
# 3

# %%
runSELECT("SELECT * FROM cities;")
# Out:
#    id         name  population
# 0   1     New York     8008278
# 1   2  Los Angeles     3694825
# 2   3    San Diego     1223405

# %%
runSELECT("show processlist")
# Out:
#     Id  User       Host             db Command  Time     State  \
# 0  397  root  localhost  classicmodels   Sleep   147
# 1  402  root  localhost  classicmodels   Sleep    46
# 2  403  root  localhost  classicmodels   Sleep    33
# 3  404  root  localhost  classicmodels   Sleep    18
# 4  405  root  localhost  classicmodels   Query     0  starting
#
#                Info
# 0              None
# 1              None
# 2              None
# 3              None
# 4  show processlist

# %%
runCMD("KILL 404")
# Out:
# 0
